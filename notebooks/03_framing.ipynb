# %%
# !pip install estnltk==1.7.2
# Out:
# Collecting estnltk==1.7.2
#   Downloading estnltk-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (70.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 MB 5.7 MB/s eta 0:00:00
# Collecting estnltk-core>=1.7.2 (from estnltk==1.7.2)
#   Downloading estnltk_core-1.7.2-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.2/222.2 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.4.1 in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (3.8.1)
# Requirement already satisfied: regex>=2015.07.19 in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (2023.12.25)
# Collecting python-crfsuite>=0.8.3 (from estnltk==1.7.2)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.4 MB/s eta 0:00:00
# Collecting cached-property>=1.2.0 (from estnltk==1.7.2)
#   Downloading cached_property-1.5.2-py2.py3-none-any.whl (7.6 kB)
# Collecting bs4 (from estnltk==1.7.2)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (1.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (4.9.4)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (3.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (3.7.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (4.66.4)
# Requirement already satisfied: ipython in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (7.34.0)
# Collecting conllu (from estnltk==1.7.2)
#   Downloading conllu-4.5.3-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from estnltk==1.7.2) (2.0.3)
# Collecting pyahocorasick (from estnltk==1.7.2)
#   Downloading pyahocorasick-2.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.1->estnltk==1.7.2) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.4.1->estnltk==1.7.2) (1.4.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->estnltk==1.7.2) (4.12.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib->estnltk==1.7.2) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib->estnltk==1.7.2) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (67.7.2)
# Collecting jedi>=0.16 (from ipython->estnltk==1.7.2)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (3.0.43)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython->estnltk==1.7.2) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->estnltk==1.7.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->estnltk==1.7.2) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->estnltk==1.7.2) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->estnltk==1.7.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->estnltk==1.7.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->estnltk==1.7.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->estnltk==1.7.2) (2024.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython->estnltk==1.7.2) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython->estnltk==1.7.2) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->estnltk==1.7.2) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->estnltk==1.7.2) (2.5)
# Installing collected packages: python-crfsuite, cached-property, pyahocorasick, jedi, conllu, bs4, estnltk-core, estnltk
# Successfully installed bs4-0.0.2 cached-property-1.5.2 conllu-4.5.3 estnltk-1.7.2 estnltk-core-1.7.2 jedi-0.19.1 pyahocorasick-2.1.0 python-crfsuite-0.9.10

# %%
import numpy as np
import pandas as pd

from estnltk import Text

from nltk.util import ngrams
from nltk.probability import *

# %%
# connect to drive
from google.colab import drive
from google.colab import files

drive.mount("/content/drive")
data = pd.read_csv("/content/drive/MyDrive/EstonianStanceDetection/notebooks/data.csv")

data["morph_analysis"] = data["sentence"].apply(lambda s: Text(s).tag_layer())

for feature in ["named_entities", "noun_phrases", "adjectives", "quoted_words", "diminutives", "superlatives", "conditionals", "translatives", "indirects", "stopwords", "unique_stopwords"]:
  data[feature] = data[feature].apply(eval)
# Out:
# Mounted at /content/drive
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# local
data = pd.read_csv("data.csv")

# %% [markdown]
# # Bigram Analysis

# %%
url_stopwords = "https://raw.githubusercontent.com/kristel-/estonian-stopwords/master/estonian-stopwords.txt"
stopwords = pd.read_csv(url_stopwords, header=None, names=['stopword'])
stopword_list = list(stopwords.stopword)

bw_words = ["kõik", "kõige", "kunagi", "eales", "iial", "alati", "igavesti", "tervenisti", "täiesti", "üleni", "täitsa", "täielikult", "üdini", "läbinisti", "läbini", "absoluutne", "absoluutselt", "totaalne", "totaalselt", "ainult", "ainus", "kogu"]

for word in bw_words:
  if word in stopword_list:
    stopword_list.remove(word)

# %%
def get_ngrams(morph_layer, n=2):
  lemmas = list(morph_layer.lemma)
  lemma_list = [lemma[0].lower() for lemma in lemmas if lemma[0] not in stopword_list and len(lemma[0]) >= 2]
  res = list(ngrams(lemma_list, n))
  return res

# %%
against_bigrams = []
neutral_bigrams = []
support_bigrams = []

for i, row in data.iterrows():
  bigrams = get_ngrams(row["morph_analysis"], 2)
  if row["stance"] == "against":
    against_bigrams += bigrams
  elif row["stance"] == "neutral":
    neutral_bigrams += bigrams
  elif row["stance"] == "supportive":
    support_bigrams += bigrams

# %%
bi_freq_against = FreqDist(against_bigrams).most_common()
bi_freq_neutral = FreqDist(neutral_bigrams).most_common()
bi_freq_support = FreqDist(support_bigrams).most_common()

# %%
bi_against = []
for bigram, count in bi_freq_against:
  if count >= 5:
    print(f"{count: <3} {bigram}")
    bi_against += [" ".join(bigram)]
# Out:
# 38  ('euroopa', 'liit')
# 18  ('mart', 'helme')
# 18  ('eesti', 'keel')
# 14  ('konservatiivne', 'rahvaerakond')
# 13  ('illegaalne', 'immigrant')
# 12  ('kogu', 'euroopa')
# 11  ('martin', 'helme')
# 11  ('tooma', 'kaasa')
# 10  ('eesti', 'konservatiivne')
# 10  ('neeger', 'araablane')
# 10  ('helme', 'sõna')
# 10  ('2015.', 'aasta')
# 9   ('kogu', 'maailm')
# 9   ('eesti', 'riik')
# 8   ('pagulane', 'vastuvõtmine')
# 8   ('eesti', 'rahvas')
# 8   ('euroopa', 'komisjon')
# 8   ('odav', 'tööjõud')
# 8   ('2016.', 'aasta')
# 8   ('donald', 'trump')
# 7   ('uus', 'uudis')
# 6   ('üro', 'rändelepe')
# 6   ('pagulane', 'võtma')
# 6   ('eesti', 'valitsus')
# 6   ('ütlema', 'helme')
# 6   ('el', 'liikmesriik')
# 6   ('eesti', 'euroopa')
# 6   ('itaalia', 'sadam')
# 6   ('neeger', 'moslem')
# 6   ('massiline', 'sisseränne')
# 6   ('illegaalne', 'immigratsioon')
# 6   ('värk', 'ütlema')
# 6   ('välismaalane', 'seadus')
# 6   ('kaasa', 'tooma')
# 6   ('usa', 'president')
# 6   ('helme', '.„')
# 5   ('globalism', 'multikultuursus')
# 5   ('kolmas', 'maailm')
# 5   ('keel', 'kultuur')
# 5   ('lääs', 'ühiskond')
# 5   ('euroopalik', 'väärtus')
# 5   ('migrant', 'võtma')
# 5   ('sõna', 'eesti')
# 5   ('euroopa', 'kultuur')
# 5   ('ebaseaduslik', 'migrant')
# 5   ('ebaseaduslik', 'migratsioon')
# 5   ('lähis-ida', 'aafrika')
# 5   ('angela', 'merkel')
# 5   ('henn', 'põlluaas')
# 5   ('suur', 'probleem')
# 5   ('matteo', 'salvini')
# 5   ('rootsi', 'värk')
# 5   ('põlema', 'panema')
# 5   ('parem', 'elu')
# 5   ('eesti', 'ühiskond')

# %%
bi_support = []
for bigram, count in bi_freq_support:
  if count >= 5:
    print(f"{count: <3} {bigram}")
    bi_support += [" ".join(bigram)]
# Out:
# 29  ('euroopa', 'liit')
# 11  ('eesti', 'keel')
# 8   ('euroopa', 'komisjon')
# 7   ('miljon', 'euro')
# 6   ('välismaalane', 'seadus')
# 6   ('süüria', 'põgenik')
# 5   ('eesti', 'pagulasabi')
# 5   ('aafrika', 'päritolu')
# 5   ('sisseränne', 'piirarv')
# 5   ('globaalne', 'ränderaamistik')
# 5   ('rahvusvaheline', 'kaitse')

# %%
bi_neutral = []
for bigram, count in bi_freq_neutral:
  if count >= 5:
    print(f"{count: <3} {bigram}")
    bi_neutral += [" ".join(bigram)]
# Out:
# 104 ('euroopa', 'liit')
# 25  ('politsei', 'piirivalveamet')
# 19  ('2015.', 'aasta')
# 15  ('euroopa', 'komisjon')
# 14  ('euroopa', 'riik')
# 13  ('illegaalne', 'immigrant')
# 13  ('välismaalane', 'seadus')
# 13  ('illegaalne', 'immigratsioon')
# 12  ('tähtajaline', 'elamisluba')
# 11  ('suur', 'osa')
# 11  ('2017.', 'aasta')
# 11  ('ebaseaduslik', 'ränne')
# 11  ('piirivalveamet', 'ppa')
# 11  ('2016.', 'aasta')
# 11  ('sisseränne', 'piirarv')
# 10  ('viimane', 'aasta')
# 9   ('2014.', 'aasta')
# 9   ('kümme', 'tuhat')
# 8   ('eesti', 'riik')
# 8   ('eesti', 'ühiskond')
# 8   ('aasta', 'lõpp')
# 8   ('lühiajaline', 'töötamine')
# 8   ('islamiriik', 'võitleja')
# 8   ('mart', 'helme')
# 8   ('eesti', 'kodanik')
# 8   ('2018.', 'aasta')
# 7   ('pagulane', 'vastuvõtmine')
# 7   ('tuhat', 'migrant')
# 7   ('liit', 'riik')
# 7   ('aitama', 'kaasa')
# 7   ('kreeka', 'saar')
# 7   ('varjupaigataotleja', 'majutuskeskus')
# 7   ('riik', 'kodanik')
# 7   ('rahvusvaheline', 'kaitse')
# 7   ('kolmas', 'riik')
# 7   ('välismaalane', 'eesti')
# 7   ('itaalia', 'kreeka')
# 7   ('vahendama', 'bns')
# 7   ('riik', 'võtma')
# 6   ('2020.', 'aasta')
# 6   ('aasta', 'eesti')
# 6   ('kreeka', 'itaalia')
# 6   ('miljon', 'inimene')
# 6   ('kaks', 'aasta')
# 6   ('viibiv', 'välismaalane')
# 6   ('viimane', 'kuu')
# 6   ('miljard', 'euro')
# 6   ('jõudma', 'euroopa')
# 6   ('2019.', 'aasta')
# 6   ('liit', 'liikmesriik')
# 6   ('illegaalne', 'migrant')
# 6   ('kolmas', 'maailm')
# 6   ('eesti', 'elamisluba')
# 6   ('elamisluba', 'andmine')
# 5   ('donald', 'trump')
# 5   ('ebaseaduslik', 'migrant')
# 5   ('saabunud', 'migrant')
# 5   ('tartu', 'ülikool')
# 5   ('rändekava', 'raames')
# 5   ('el', 'riik')
# 5   ('viimane', 'aeg')
# 5   ('suurem', 'osa')
# 5   ('riik', 'sisenemine')
# 5   ('liit', 'türgi')
# 5   ('liit', 'rändekava')
# 5   ('türgi', 'kreeka')
# 5   ('elamisluba', 'andma')
# 5   ('ebaseaduslik', 'sisseränne')
# 5   ('ebaseaduslik', 'sisserändaja')
# 5   ('ebaseaduslik', 'piiriületus')
# 5   ('euroopa', 'jõudma')
# 5   ('eesti', 'keel')
# 5   ('lääne-euroopa', 'riik')
# 5   ('migrant', 'põgenik')
# 5   ('süüria', 'põgenik')
# 5   ('miljon', 'pagulane')
# 5   ('kaks', 'kolmandik')
# 5   ('kogu', 'euroopa')
# 5   ('pagulane', 'võtma')

# %%
fil_bg_against = [bigram for bigram in bi_against if bigram not in bi_neutral and bigram not in bi_support]
fil_bg_support = [bigram for bigram in bi_support if bigram not in bi_neutral and bigram not in bi_against]

# %%
def contains_bigram(morph_layer, bigrams=[]):
  lemmas = list(morph_layer.lemma)
  lemma_list = [lemma[0].lower() for lemma in lemmas if lemma[0] not in stopword_list and len(lemma[0]) >= 2]
  lemma_string = " ".join(lemma_list)

  for pair in bigrams:
    if pair in lemma_string:
      return 1

  return 0

# %%
data["has_against_bigram"] = data["morph_analysis"].apply(contains_bigram, bigrams=fil_bg_against)
data["has_support_bigram"] = data["morph_analysis"].apply(contains_bigram, bigrams=fil_bg_support)

# %%
data[data["has_against_bigram"] == 1]["stance"].value_counts()
# Out:
# stance
# against       193
# neutral        59
# supportive     25
# Name: count, dtype: int64

# %%
data[data["has_support_bigram"] == 1]["stance"].value_counts()
# Out:
# stance
# supportive    19
# neutral       12
# Name: count, dtype: int64

# %% [markdown]
# #Adjective-based Framing

# %%
adj_noun_list = []

for i, row in data.iterrows():

  if row["stanceConsolidated"] != 3:
    continue

  prev_pos, prev_word = "-", "-"
  for pos, word in zip(row["morph_analysis"].partofspeech, row["morph_analysis"].words.text):
    pos = pos[0]
    word = word.lower()
    if prev_pos in "ACU" and pos in "S":
      adj_noun_list += [(prev_word, word)]
    prev_pos = pos
    prev_word = word

neutral_pairs = FreqDist(adj_noun_list)

# %%
for pair, count in neutral_pairs.most_common():
  print(f"{count: <3} {pair}")
# Out:
# 10  ('eelmisel', 'nädalal')
# 8   ('eelmisel', 'aastal')
# 7   ('viimastel', 'aastatel')
# 7   ('tähtajalise', 'elamisloa')
# 6   ('ebaseadusliku', 'rände')
# 6   ('suur', 'osa')
# 6   ('lühiajalise', 'töötamise')
# 6   ('rahvusvahelise', 'kaitse')
# 6   ('illegaalse', 'immigratsiooni')
# 5   ('viimasel', 'ajal')
# 5   ('viimastel', 'kuudel')
# 4   ('eelmise', 'aasta')
# 4   ('suurem', 'osa')
# 4   ('kogu', 'aeg')
# 3   ('keskmist', 'brutokuupalka')
# 3   ('ebaseadusliku', 'sisserände')
# 3   ('eitava', 'vastuse')
# 3   ('illegaalsele', 'immigratsioonile')
# 3   ('terve', 'mõistuse')
# 2   ('suure', 'osa')
# 2   ('ebaseaduslike', 'migrantide')
# 2   ('kiiremas', 'korras')
# 2   ('noorte', 'meeste')
# 2   ('tähtajalist', 'elamisluba')
# 2   ('saabunud', 'riiki')
# 2   ('suurel', 'hulgal')
# 2   ('loomuliku', 'iibe')
# 2   ('võimaliku', 'rändekriisi')
# 2   ('viibivad', 'välismaalased')
# 2   ('rahvusvahelist', 'õigust')
# 2   ('praegusel', 'hetkel')
# 2   ('illegaalsed', 'immigrandid')
# 2   ('puudutavaid', 'ümberkorraldusi')
# 2   ('eelmise', 'nädala')
# 2   ('möödunud', 'aasta')
# 2   ('illegaalseid', 'immigrante')
# 2   ('süütutele', 'inimestele')
# 2   ('illegaalsete', 'sisserändajate')
# 2   ('ümberpaigutatav', 'pagulaspere')
# 2   ('antud', 'd-viisat')
# 2   ('ebaseaduslikke', 'migrante')
# 2   ('tööealise', 'elanikkonna')
# 2   ('rahvusvahelise', 'migratsiooniorganisatsiooni')
# 2   ('ebaseaduslike', 'piiriületuste')
# 2   ('illegaalset', 'migranti')
# 2   ('vajaduspõhist', 'õppetoetust')
# 2   ('pikka', 'aega')
# 2   ('ebaseaduslikke', 'sisserändajaid')
# 2   ('illegaalset', 'töötajat')
# 2   ('illegaalsetele', 'immigrantidele')
# 2   ('illegaalset', 'immigranti')
# 2   ('uus', 'seadus')
# 2   ('saabunud', 'migrantide')
# 2   ('ebaseaduslik', 'ränne')
# 2   ('täiendava', 'kaitse')
# 2   ('ühtset', 'immigratsioonipoliitikat')
# 2   ('möödunud', 'aastal')
# 2   ('viimaste', 'aastate')
# 2   ('avaliku', 'arvamuse')
# 2   ('illegaalsete', 'immigrantide')
# 2   ('avatud', 'uste')
# 2   ('uute', 'tulijate')
# 2   ('väike', 'osa')
# 2   ('suletud', 'piiride')
# 2   ('järgmisel', 'aastal')
# 2   ('seadusliku', 'aluseta')
# 2   ('praegusel', 'ajal')
# 2   ('suurimaks', 'probleemiks')
# 2   ('suurima', 'ohuna')
# 2   ('viimastel', 'nädalatel')
# 2   ('ebavõrdne', 'kohtlemine')
# 2   ('saabuvate', 'põgenike')
# 2   ('järgmisel', 'nädalal')
# 2   ('riikliku', 'julgeoleku')
# 2   ('kõrgeim', 'kohus')
# 2   ('demokraatlik', 'partei')
# 2   ('illegaalsete', 'migrantide')
# 2   ('tänase', 'päeva')
# 2   ('viibivatel', 'välismaalastel')
# 2   ('tähtajaline', 'elamisluba')
# 2   ('illegaalset', 'immigratsiooni')
# 2   ('kogu', 'maailmas')
# 2   ('vastasel', 'juhul')
# 2   ('avalike', 'teenuste')
# 1   ('patriootlikud', 'eurooplased')
# 1   ('uut', 'olukorda')
# 1   ('kaetud', 'tegevuskava')
# 1   ('konkreetsete', 'väljakutsetega')
# 1   ('mustanahaliste', 'valijate')
# 1   ('mustanahaliste', 'häältest')
# 1   ('suure', 'toetuseta')
# 1   ('kohustuslikud', 'kvoodid')
# 1   ('poliitilisse', 'diskussiooni')
# 1   ('avalikus', 'diskursuses')
# 1   ('sallimatu', 'vaenukõne')
# 1   ('peamisteks', 'sihtmärkideks')
# 1   ('praeguse', 'valitsuse')
# 1   ('juriidilist', 'abi')
# 1   ('fikseeritud', 'reeglid')
# 1   ('selge', 'rahastamine')
# 1   ('pehme', 'kvoot')
# 1   ('poolelioleva', 'tööd')
# 1   ('toimuvatele', 'ekskursioonidele')
# 1   ('suurest', 'osast')
# 1   ('normaalne', 'mõistus')
# 1   ('vaktsiinivastane', 'liikumine')
# 1   ('noort', 'naist')
# 1   ('elavast', 'lambakasvatajast')
# 1   ('saabunud', 'migrandid')
# 1   ('suurimat', 'ohtu')
# 1   ('radikaalsest', 'islamipropagandast')
# 1   ('pikaajaline', 'piiramine')
# 1   ('kaudseid', 'kulutusi')
# 1   ('piiriülese', 'julgeolekuga')
# 1   ('suur', 'koorem')
# 1   ('tavalisest', 'rändepoliitikast')
# 1   ('väiksema', 'kvalifikatsiooniga')
# 1   ('olev', 'moslem')
# 1   ('suunatud', 'maakohtadesse')
# 1   ('kõrgema', 'immigrantpäritolu')
# 1   ('kestnud', 'okupatsioonide')
# 1   ('murranguliste', 'sündmuste')
# 1   ('lühiajalise', 'tööloaga')
# 1   ('võimaliku', 'migratsioonisurvega')
# 1   ('nähtav', 'numbrikombinatsioon')
# 1   ('taoline', 'numbriseeria')
# 1   ('tänases', 'ühiskonnas')
# 1   ('piirülese', 'kuritegevuse')
# 1   ('läbipõdenud', 'inimeste')
# 1   ('jõudva', 'seadusemuudatuse')
# 1   ('uute', 'kvoodipagulaste')
# 1   ('kogu', 'ühiskond')
# 1   ('relvastatud', 'isikut')
# 1   ('tulevasi', 'migrante')
# 1   ('valge', 'pilve')
# 1   ('iseseisev', 'riik')
# 1   ('mandrisiseseid', 'migrante')
# 1   ('ajutist', 'laagrit')
# 1   ('veriseima', 'rünnakuga')
# 1   ('vanemaealiste', 'tööhõive')
# 1   ('suure', 'väljarändega')
# 1   ('vabatahtlikel', 'tegemist')
# 1   ('lugupidamatut', 'tähendust')
# 1   ('olevate', 'teoste')
# 1   ('positiivne', 'rändesaldo')
# 1   ('antud', 'raha')
# 1   ('lihtsustatud', 'korras')
# 1   ('kogutud', 'annetuste')
# 1   ('töötava', 'valgusti')
# 1   ('rahalisi', 'toetusi')
# 1   ('külastavaid', 'välismaalasi')
# 1   ('halva', 'sõnaga')
# 1   ('kogu', 'väliskülalise')
# 1   ('nendevastasele', 'aktsioonile')
# 1   ('keeruline', 'olukord')
# 1   ('lõdvemaid', 'reegleid')
# 1   ('immigratsioonimeelse', 'argumendiga')
# 1   ('õige', 'aeg')
# 1   ('asuvatel', 'asutustel')
# 1   ('võimaliku', 'kriisi')
# 1   ('hoidev', 'polt')
# 1   ('valitsustevahelisel', 'konverentsil')
# 1   ('kohaliku', 'riigi')
# 1   ('eri', 'rasside')
# 1   ('erinevate', 'inimeste')
# 1   ('riiklikul', 'tasandil')
# 1   ('rahvusvahelise', 'ärikorralduse')
# 1   ('akadeemilist', 'kraadi')
# 1   ('peetud', 'aiandusfoorumil')
# 1   ('seotud', 'teemasid')
# 1   ('äraütleva', 'vastuse')
# 1   ('negatiivse', 'välisrändega')
# 1   ('käesoleva', 'aasta')
# 1   ('tegelev', 'tööandja')
# 1   ('oluliseks', 'faktoriks')
# 1   ('uut', 'seaduseelnõu')
# 1   ('negatiivse', 'koroonatesti')
# 1   ('taotlevad', 'süürlased')
# 1   ('rajatavas', 'majutuskeskuses')
# 1   ('mustanahaliste', 'vaenlaseks')
# 1   ('ortodokssetel', 'juutidel')
# 1   ('suurema', 'keelu')
# 1   ('kommunaalalaseid', 'küsimusi')
# 1   ('halvas', 'kuulsuses')
# 1   ('18-aastase', 'itaallanna')
# 1   ('jõhkrat', 'tapmist')
# 1   ('reedesest', 'uudisest')
# 1   ('võimalik', 'migratsioonipoliitikat')
# 1   ('välismaist', 'päritolu')
# 1   ('alaealisi', 'tütarlapsi')
# 1   ('väidetava', 'ründaja')
# 1   ('14-17-aastastele', 'immigrantidele')
# 1   ('olulisem', 'probleem')
# 1   ('erinevate', 'rasside')
# 1   ('keeruline', 'filmi')
# 1   ('noortest', 'araablastest')
# 1   ('tegelev', 'mõttekoda')
# 1   ('sunniitlik', 'äärmusrühmitus')
# 1   ('hõivatud', 'aladest')
# 1   ('siiral', 'soovil')
# 1   ('seotud', 'varjupaigataotlejatega')
# 1   ('rassistlik', 'paroodianumber')
# 1   ('tuntud', 'isiksuste')
# 1   ('varasemale', 'otsusele')
# 1   ('senine', 'kogemus')
# 1   ('kohustuslikke', 'pagulaskvoote')
# 1   ('omas', 'ühiskonnas')
# 1   ('määratlemata', 'väärtused')
# 1   ('antud', 'küsimus')
# 1   ('märkimisväärset', 'nihet')
# 1   ('karmi', 'immigratsioonipoliitika')
# 1   ('rahvusvahelisele', 'seadusandlusele')
# 1   ('võõraste', 'laevade')
# 1   ('senise', 'korra')
# 1   ('võimalik', 'varjupaigataotlejad')
# 1   ('valge', 'ettepanekuteks')
# 1   ('lühiajalistele', 'töötajatele')
# 1   ('lühiajalist', 'töötamist')
# 1   ('järjestikuse', 'päeva')
# 1   ('ilmaliku', 'staatuse')
# 1   ('saabunud', 'islamiriigi')
# 1   ('rahvarohketes', 'kuurordipiirkondades')
# 1   ('populaarsed', 'venelaste')
# 1   ('erilist', 'huvi')
# 1   ('poolsõjalist', 'rühmitust')
# 1   ('sunniitliku', 'terrorirorganisatsiooni')
# 1   ('tegeva', 'teate')
# 1   ('kõrgemasse', 'valmisolekusse')
# 1   ('eestikeelse', 'hariduse')
# 1   ('auväärsete', 'külalistena')
# 1   ('viidud', 'uuringu')
# 1   ('ühtset', 'migratsioonipoliitikat')
# 1   ('käesoleval', 'eelarveaastal')
# 1   ('suur', 'vahemik')
# 1   ('kindlakstehtud', 'juhtumite')
# 1   ('avastamata', 'juhtumeid')
# 1   ('immigrantidevastaseid', 'plakateid')
# 1   ('rangemad', 'piirangud')
# 1   ('mittekuuluvate', 'riikide')
# 1   ('antavat', 'toetust')
# 1   ('viibivate', 'välismaalaste')
# 1   ('täiendava', 'õiguskaitse')
# 1   ('suunduva', 'veoauto')
# 1   ('turvalise', 'liikumise')
# 1   ('uutest', 'pagulastest')
# 1   ('erinevad', 'migratsioonivaldkonnad')
# 1   ('eelnevatest', 'teadetest')
# 1   ('praegune', 'valitsuskoalitsioon')
# 1   ('ajutise', 'välistööjõu')
# 1   ('riiklik', 'ideoloogia')
# 1   ('erinevad', 'kogukonnad')
# 1   ('suurema', 'sisseränderiskiga')
# 1   ('suletud', 'kogukonnaga')
# 1   ('üliharv', 'nähtus')
# 1   ('uut', 'varjupaigataotlejat')
# 1   ('järgnenud', 'kokkuleppega')
# 1   ('mustanahaline', 'kommentaator')
# 1   ('suurim', 'ametiühing')
# 1   ('esmane', 'prioriteet')
# 1   ('täiendava', 'kontrolli')
# 1   ('elektroonilisi', 'teenuseid')
# 1   ('madalapalgalisi', 'töötajaid')
# 1   ('kolmekuune', 'tüdruk')
# 1   ('saabuvate', 'asüülitaotlejate')
# 1   ('venekeelset', 'elanikkonda')
# 1   ('vabaks', 'poolakate')
# 1   ('ilmalikku', 'ühiskonda')
# 1   ('relvastatud', 'konfliktid')
# 1   ('sõnakuulmatu', 'riik')
# 1   ('uusi', 'telgi')
# 1   ('mustalt', 'turult')
# 1   ('globalistliku', 'integratsiooni')
# 1   ('rahvusriiklik', 'suveräänsus')
# 1   ('suunatud', 'islamiriigi')
# 1   ('mässuliste', 'rühmitusi')
# 1   ('erinevatest', 'ideoloogiatest')
# 1   ('islamistlikud', 'terroriorganisatsioonid')
# 1   ('häälekas', 'kriitik')
# 1   ('vastaste', 'sõnavõttude')
# 1   ('madalate', 'naftahindade')
# 1   ('majanduslik', 'kitsikus')
# 1   ('seotud', 'pagulastele')
# 1   ('uurivad', 'ajakirjanikud')
# 1   ('kaasaegsed', 'noored')
# 1   ('klassikalise', 'islami')
# 1   ('90-eurose', 'toetuse')
# 1   ('vältimatud', 'juhtumid')
# 1   ('käiva', 'inimkaubanduse')
# 1   ('rahvusvaheliste', 'kohustuste')
# 1   ('erinevaid', 'samme')
# 1   ('traagilisele', 'juhtumile')
# 1   ('rassistliku', 'linna')
# 1   ('illegaalse', 'immigratsiooniga')
# 1   ('populaarne', 'siseminister')
# 1   ('lahkuvates', 'põgenikepaatides')
# 1   ('juhtiv', 'piirivalvekapten')
# 1   ('tehtud', 'uuringust')
# 1   ('tehtud', 'märkused')
# 1   ('terves', 'riigis')
# 1   ('saabunud', 'süürlasele')
# 1   ('kolmeaastase', 'vangistuse')
# 1   ('demokraatliku', 'partei')
# 1   ('rassistliku', 'mõttemalli')
# 1   ('vabatahtlikul', 'alusel')
# 1   ('saabunud', 'asüülitaotlejad')
# 1   ('rahvusmeelsetelt', 'relvad')
# 1   ('antud', 'migrantidele')
# 1   ('mässuliste', 'tegevuse')
# 1   ('varastatud', 'kalalaev')
# 1   ('ebaseadusliku', 'piiriületaja')
# 1   ('peamised', 'rändeteed')
# 1   ('suurvõimudevahelisest', 'mängust')
# 1   ('taktikaline', 'grupp')
# 1   ('ebaseadusliku', 'rännet')
# 1   ('valitsusvälised', 'organisatsioonid')
# 1   ('seadusevastaseks', 'sisenemiseks')
# 1   ('poliitilist', 'tahet')
# 1   ('kõrgeima', 'klassi')
# 1   ('erilisi', 'teeneid')
# 1   ('digitaalsete', 'ettevõtete')
# 1   ('uut', 'maksustamist')
# 1   ('suuremat', 'toetust')
# 1   ('tihedamat', 'koostööd')
# 1   ('ühist', 'lähenemist')
# 1   ('kohalike', 'ametnikega')
# 1   ('vastane', 'võitlus')
# 1   ('suurim', 'hulk')
# 1   ('vastuvõtva', 'riigi')
# 1   ('saabunud', 'pea')
# 1   ('keerulisemate', 'punktidega')
# 1   ('vaatavatele', 'valvuritele')
# 1   ('asuv', 'migrantide')
# 1   ('erakorralisel', 'ülemkogul')
# 1   ('paiknevat', 'pagulast')
# 1   ('imporditud', 'nähtus')
# 1   ('teatud', 'hirmudest')
# 1   ('nõutud', 'tasemele')
# 1   ('otsiv', 'afaasiaga')
# 1   ('esinevaid', 'vääritimõistmisi')
# 1   ('viimase', 'näol')
# 1   ('praegune', 'vasakvalitsus')
# 1   ('tõrjuva', 'poliitika')
# 1   ('suletud', 'rändetee')
# 1   ('lähematel', 'kuudel')
# 1   ('uus', 'rändepoliitika')
# 1   ('jõuka', 'linnaosa')
# 1   ('26-aastastest', 'töötajatest')
# 1   ('rassilist', 'kodusõda')
# 1   ('lähtuv', 'migratsioonilaine')
# 1   ('eri', 'kultuuridest')
# 1   ('usaldusväärse', 'suhte')
# 1   ('rahvusvahelises', 'inimkaubanduses')
# 1   ('tegelikust', 'puudujäägist')
# 1   ('kindlal', 'perioodil')
# 1   ('eelmise', 'kalendriaasta')
# 1   ('tähtsaimaks', 'tungipunktis')
# 1   ('nimetatud', 'seadusel')
# 1   ('39-aastane', 'usbekk')
# 1   ('kannatanud', 'inimestele')
# 1   ('mitmekülgset', 'toetust')
# 1   ('eitavale', 'vastusele')
# 1   ('väliste', 'ohtudega')
# 1   ('edasiste', 'migratsioonikriiside')
# 1   ('jätvad', 'inimesed')
# 1   ('seotud', 'protseduurid')
# 1   ('esmase', 'koha')
# 1   ('suuremad', 'grupid')
# 1   ('kogu', 'ühiskonnas')
# 1   ('väikestes', 'kohtades')
# 1   ('parema', 'elukvaliteedi')
# 1   ('ülerahvastatud', 'suurlinnades')
# 1   ('ebaseaduslike', 'sisserändajate')
# 1   ('olevad', 'illegaalid')
# 1   ('esitatud', 'statistika')
# 1   ('seotud', 'rikkumiste')
# 1   ('erinevate', 'liikide')
# 1   ('lühiajaliste', 'töötajate')
# 1   ('suuremahulise', 'sisserände')
# 1   ('uutesse', 'laagritesse')
# 1   ('seadusandlikku', 'lähenemisviisi')
# 1   ('kiiret', 'lahendust')
# 1   ('kohalike', 'suhteid')
# 1   ('halvas', 'valguses')
# 1   ('võõraviha', 'õhutajad')
# 1   ('euroopalikud', 'väärtused')
# 1   ('viimaste', 'nädalate')
# 1   ('sisepoliitiline', 'karussell')
# 1   ('ajakirjanduslikke', 'valvekoeri')
# 1   ('suured', 'lõhed')
# 1   ('suure', 'arvu')
# 1   ('välismaise', 'päritoluga')
# 1   ('suuremasse', 'laagrisse')
# 1   ('illegaalse', 'tööjõu')
# 1   ('suuri', 'probleeme')
# 1   ('jäigema', 'hoiaku')
# 1   ('ainsad', 'kohad')
# 1   ('tavapärasteks', 'kogunemiskohtadeks')
# 1   ('rassistliku', 'alatooni')
# 1   ('piiratud', 'osas')
# 1   ('suurema', 'vastuvõtu')
# 1   ('terroristlike', 'rühmituste')
# 1   ('tõsine', 'julgeolekuprobleem')
# 1   ('saabunud', 'immigrandid')
# 1   ('uues', 'raportis')
# 1   ('kõlbmatutel', 'paatidel')
# 1   ('ootavate', 'päästjateni')
# 1   ('suurimaid', 'maasikakasvatajaid')
# 1   ('paiknevat', 'aastas')
# 1   ('küündiva', 'rändesaldo')
# 1   ('rääkivate', 'inimeste')
# 1   ('teemalise', 'debati')
# 1   ('lahutamatu', 'osa')
# 1   ('paremat', 'elu')
# 1   ('hoolimatute', 'inimsmugeldajate')
# 1   ('tulutoovat', 'äri')
# 1   ('teravate', 'vastuoludega')
# 1   ('kohalikud', 'inimesed')
# 1   ('kiire', 'reageerimise')
# 1   ('rassistlike', 'postituste')
# 1   ('väikeseid', 'mini-marketi')
# 1   ('terve', 'nädala')
# 1   ('rassistlike', 'väljaastumiste')
# 1   ('kummaline', 'jaotus')
# 1   ('mõrvatud', 'sakslasest')
# 1   ('endist', 'toakaaslast')
# 1   ('kõrge', 'liikme')
# 1   ('valge', 'maja')
# 1   ('suure', 'majanduse')
# 1   ('olulist', 'rolli')
# 1   ('mõnetunnilise', 'otsimise')
# 1   ('leitudki', 'põgenikud')
# 1   ('kohalikke', 'elanikke')
# 1   ('uute', 'pagulaste')
# 1   ('laevaliste', 'passid')
# 1   ('uues', 'kohas')
# 1   ('kohaliku', 'fotograafi')
# 1   ('alalist', 'mehhanismi')
# 1   ('radikaalse', 'islamiga')
# 1   ('seotud', 'inimeste')
# 1   ('alalise', 'elamisloa')
# 1   ('ajutiste', 'elamislubade')
# 1   ('tänasest', 'hommikupoolikust')
# 1   ('lähenevast', 'migrandihordist')
# 1   ('seatavatest', 'kohustustest')
# 1   ('suuri', 'põgeniketulvasid')
# 1   ('suuremaid', 'põgenikemasse')
# 1   ('endine', 'välisminister')
# 1   ('rahvusvahelisi', 'hoobasid')
# 1   ('reguleeritud', 'migratsiooni')
# 1   ('vajavat', 'migrante')
# 1   ('teavitatud', 'linna')
# 1   ('alaealised', 'sõjapõgenikud')
# 1   ('poliitilise', 'avalduse')
# 1   ('rändealane', 'koostöö')
# 1   ('õiguslike', 'kohustuste')
# 1   ('odavat', 'võõrtööjõudu')
# 1   ('immigratsioonivastase', 'kursi')
# 1   ('jääva', 'rände')
# 1   ('räigete', 'rünnakute')
# 1   ('mustast', 'merest')
# 1   ('püüdvate', 'migrantide')
# 1   ('uus', 'liikumiskoridor')
# 1   ('puudutavaid', 'seadusi')
# 1   ('siirdunud', 'vaost')
# 1   ('mitteametlikeks', 'immigrantideks')
# 1   ('tugeva', 'toetusega')
# 1   ('puudutavaid', 'dokumente')
# 1   ('arvatava', 'pühasõdalasega')
# 1   ('silmakirjalikke', 'õpetusi')
# 1   ('kohalik', 'meedia')
# 1   ('suures', 'plaanis')
# 1   ('sõlmitud', 'rändekokkulepe')
# 1   ('ultrakonservatiivse', 'suuna')
# 1   ('esitatud', 'resolutsiooni')
# 1   ('rahvusvahelise', 'õigusega')
# 1   ('traagilist', 'juhtumit')
# 1   ('suunuduvate', 'põgenike')
# 1   ('järsku', 'kasvu')
# 1   ('ohtlik', 'ettevõtmine')
# 1   ('keerulises', 'pagulasteemas')
# 1   ('esitatud', 'süüdistus')
# 1   ('riikliku', 'juurdlusbüroo')
# 1   ('negatiivse', 'vastuse')
# 1   ('võimalikku', 'ohtu')
# 1   ('noort', 'välisriigi')
# 1   ('kohalik', 'politseiallikas')
# 1   ('kahtlustatavate', 'tabamise')
# 1   ('suure', 'sõidutee')
# 1   ('erinevatel', 'hinnangutel')
# 1   ('multikultuurne', 'pilt')
# 1   ('rahvusliku', 'identiteedi')
# 1   ('riikliku', 'kaitse')
# 1   ('rahvuslikke', 'huve')
# 1   ('järgiva', 'kodakondsuse')
# 1   ('juhitud', 'koalitsiooniga')
# 1   ('sunniviisiliselt', 'ääremaadele')
# 1   ('küüditatud', 'migrandid')
# 1   ('välise', 'riigi')
# 1   ('illegaalne', 'ületamine')
# 1   ('roheliste', 'valijad')
# 1   ('järgnevad', 'sotsiaaldemokraadid')
# 1   ('arvatavat', 'islamiriigi')
# 1   ('multikultuurses', 'ühiskonnas')
# 1   ('tõsisema', 'eksaleerumiseni')
# 1   ('rohkemate', 'inimeste')
# 1   ('keskne', 'termine')
# 1   ('punast', 'joont')
# 1   ('hiljutist', 'sõnumit')
# 1   ('suurest', 'pagulasi')
# 1   ('toetavast', 'miitingust')
# 1   ('kajastamata', 'rahvuslust')
# 1   ('kaitsev', 'meeleavaldus')
# 1   ('kogu', 'maailm')
# 1   ('suuremaid', 'mõõtmeid')
# 1   ('võtva', 'sisserändega')
# 1   ('noor', 'migrant')
# 1   ('endiste', 'islamiriigi')
# 1   ('tulevate', 'sisserändajate')
# 1   ('pikaajalised', 'elamisload')
# 1   ('rassivägivallavastase', 'vastupanu')
# 1   ('rassismivastase', 'võitluse')
# 1   ('juhtivaid', 'islamiuuringute')
# 1   ('kõrgeim', 'sunni')
# 1   ('rassistlikud', 'avaldused')
# 1   ('kogu', 'maailma')
# 1   ('konstruktiivsele', 'dialoogile')
# 1   ('asuv', 'pagulaskeskus')
# 1   ('ukraina-meelsete', 'vaadetega')
# 1   ('etniliste', 'ukrainlaste')
# 1   ('arvukad', 'faktid')
# 1   ('kibekiired', 'kevadtööd')
# 1   ('ühendavasse', 'eurotunnelisse')
# 1   ('sõitvatesse', 'rongidesse')
# 1   ('illegaalse', 'immigrandi')
# 1   ('vabastatavate', 'isikute')
# 1   ('rahvusvahelist', 'kaitset')
# 1   ('õigusliku', 'aluseta')
# 1   ('mahapõlenud', 'laagri')
# 1   ('ebapiisava', 'kütte')
# 1   ('rangetele', 'reeglitele')
# 1   ('teatud', 'perioodi')
# 1   ('ametlik', 'staatus')
# 1   ('euroopa-ülest', 'küsimust')
# 1   ('digiteemalisel', 'tippkohtumisel')
# 1   ('digitaalse', 'arengu')
# 1   ('avaldatud', 'küsitluse')
# 1   ('võimelised', 'vägivalda')
# 1   ('olev', 'riik')
# 1   ('uus', 'algatus')
# 1   ('välismaised', 'töötajad')
# 1   ('uusi', 'lapsi')
# 1   ('uusi', 'lasteaedu')
# 1   ('puuduvaid', 'kasvatajaid')
# 1   ('uut', 'välistööjõudu')
# 1   ('saadetud', 'ukrainlasi')
# 1   ('kahenädalase', 'isolatsiooni')
# 1   ('tegelikku', 'olukorda')
# 1   ('noorte', 'pagulaste')
# 1   ('lühiajalist', 'tööluba')
# 1   ('pideva', 'politsei')
# 1   ('reaalseid', 'rünnakuid')
# 1   ('90-kohalises', 'parlamendis')
# 1   ('turvalistest', 'riikidest')
# 1   ('tugev', 'tugisüsteemsõjapõgenikest')
# 1   ('elaval', 'välismaalasel')
# 1   ('varases', 'eas')
# 1   ('seaduslik', 'migratsioon')
# 1   ('ebaseaduslik', 'sisseränne')
# 1   ('eiravat', 'sisserändajat')
# 1   ('suurema', 'osa')
# 1   ('ohvriterohkete', 'rünnakute')
# 1   ('kuum', 'teema')
# 1   ('viivaid', 'busse')
# 1   ('asuvast', 'põgenikelaagrist')
# 1   ('piiriäärsetel', 'aladel')
# 1   ('suurima', 'põgenikelaagri')
# 1   ('suveräänne', 'otsus')
# 1   ('väidetavat', 'rassismijuhtumit')
# 1   ('valminud', 'raporti')
# 1   ('esialgse', 'rahvaarvu')
# 1   ('esialgsete', 'andmetega')
# 1   ('rassistlikule', 'teele')
# 1   ('kõrvalehoidvad', 'ettevõtted')
# 1   ('lühikese', 'ajaga')
# 1   ('napi', 'sisserände')
# 1   ('tegutsevatele', 'firmadele')
# 1   ('kurva', 'tõsiasja')
# 1   ('islamifilosoofiline', 'liikumine')
# 1   ('senisel', 'tasemel')
# 1   ('kestnud', 'läbirääkimised')
# 1   ('kõrge', 'sündimuse')
# 1   ('suurem', 'rändepiirkond')
# 1   ('rahvusvaheline', 'vahistamismäärus')
# 1   ('õigel', 'pühasõdalasel')
# 1   ('tegelikku', 'tausta')
# 1   ('illegaalse', 'rändega')
# 1   ('uued', 'asüülimenetlused')
# 1   ('meeletu', 'kasv')
# 1   ('etnilise', 'taustaga')
# 1   ('olevale', 'tehnikale')
# 1   ('kõrgel', 'tasemel')
# 1   ('suuremad', 'probleemid')
# 1   ('demograafiline', 'andmestik')
# 1   ('populistliku', 'põlissoomlaste')
# 1   ('vastuolulist', 'retoorikat')
# 1   ('püsiv', 'elukoht')
# 1   ('vallalised', 'lapsed')
# 1   ('demograafilise', 'muutusega')
# 1   ('eesti-suunalise', 'aktiivsuse')
# 1   ('algne', 'kaklus')
# 1   ('erinevates', 'kuritegudes')
# 1   ('inimlikku', 'lahendust')
# 1   ('avaldatud', 'numbrid')
# 1   ('varasemale', 'teatele')
# 1   ('seotud', 'varjupaigataotlejate')
# 1   ('seotud', 'probleemidega')
# 1   ('peamiseks', 'kahtlusaluseks')
# 1   ('kergema', 'elu')
# 1   ('senise', 'paturegistri')
# 1   ('võimaliku', 'karistuse')
# 1   ('sotsiaaldemokraatliku', 'partei')
# 1   ('vaheline', 'vaidlus')
# 1   ('täieliku', 'pagulase')
# 1   ('huvitaval', 'ajal')
# 1   ('erinevad', 'riigid')
# 1   ('kohustusliku', 'eluaseme')
# 1   ('aktiivseid', 'terroriste')
# 1   ('väike', 'hulk')
# 1   ('märkimisväärne', 'osa')
# 1   ('kohustuslik', 'keeleõpe')
# 1   ('töötaval', 'pagulasel')
# 1   ('elavatest', 'inimestest')
# 1   ('otsese', 'julgeolekuküsimusega')
# 1   ('perekondlikke', 'kontakte')
# 1   ('tollane', 'sotsist')
# 1   ('tagune', 'ajaleht')
# 1   ('tollane', 'tervise-')
# 1   ('ultraparempoolsed', 'parteid')
# 1   ('rahvuslike-religioossete', 'vähemustega')
# 1   ('geopoliitilises', 'plaanis')
# 1   ('vanad', 'tülid')
# 1   ('võimalikke', 'viirusekandjaid')
# 1   ('saabuvatel', 'migrantidel')
# 1   ('ühiseid', 'riigipiire')
# 1   ('asutatud', 'partei')
# 1   ('antud', 'usutluses')
# 1   ('poliitilist', 'ettepanekut')
# 1   ('valdaval', 'enamikul')
# 1   ('kodumaiste', 'kogukondade')
# 1   ('väike', 'uus-kodumaa')
# 1   ('erinevate', 'välismaalaste')
# 1   ('rassismivastase', 'võrgustiku')
# 1   ('migratsiooniskeptilisemaks', 'rahvaks')
# 1   ('vajalikke', 'arenguid')
# 1   ('pragmaatiliste', 'põgenikeküsimustega')
# 1   ('valdkondlikust', 'eesmärgist')
# 1   ('siseriikliku', 'õigusregulatsiooni')
# 1   ('rahvusvaheliste', 'lepingute')
# 1   ('suureks', 'väljakutseks')
# 1   ('suurt', 'osa')
# 1   ('ametlikud', 'andmed')
# 1   ('lühiajaliseks', 'töötamiseks')
# 1   ('väikse', 'abiraha')
# 1   ('külma', 'ilma')
# 1   ('tänane', 'päev')
# 1   ('traagilisi', 'teateid')
# 1   ('uppunud', 'põgenikest')
# 1   ('illegaalsest', 'piiriületajast')
# 1   ('seotud', 'asüülitaotlejad')
# 1   ('lühikese', 'ajaperioodi')
# 1   ('peamine', 'mure')
# 1   ('kirjaliku', 'küsimuse')
# 1   ('korraldatud', 'rünnak')
# 1   ('tugeva', 'põgenikesurve')
# 1   ('kolmapäevasele', 'massiimmigratsioonivastasele')
# 1   ('valget', 't-särki')
# 1   ('kohalike', 'elanike')
# 1   ('kristlik', 'kultuur')
# 1   ('immigratsioonivastaste', 'erakondadade')
# 1   ('paremat', 'tulemust')
# 1   ('suur', 'hoogustumine')
# 1   ('ootavaid', 'pagulasi')
# 1   ('pealtkuulatud', 'telefonikõnedest')
# 1   ('ennetava', 'sammuna')
# 1   ('radikaalsete', 'moslemite')
# 1   ('patrullivate', 'sõdurite')
# 1   ('tunnustatud', 'pagulasena')
# 1   ('ajutise', 'kaitse')
# 1   ('suunduvate', 'migrantide')
# 1   ('ulatuvat', 'abi')
# 1   ('vastastikune', 'lubadus')
# 1   ('võimaliku', 'piirikontrolli')
# 1   ('üldist', 'korda')
# 1   ('eelmisest', 'kolmapäevast')
# 1   ('uued', 'põgenikud')
# 1   ('asuvat', 'põgenikelaagrit')
# 1   ('saabunud', 'kvoodipagulast')
# 1   ('tähtajalise', 'elamisloaga')
# 1   ('viibival', 'välismaalasel')
# 1   ('illegaalset', 'võõrtööjõudu')
# 1   ('vasakpoolne', 'valitsus')
# 1   ('üheainsa', 'nädala')
# 1   ('rahvusvaheliste', 'sanktsioonide')
# 1   ('suurt', 'kasu')
# 1   ('erinevaid', 'mõjutusvahendeid')
# 1   ('pürgivatele', 'põgenikele')
# 1   ('peetud', 'ettekandes')
# 1   ('lubatud', 'riiki')
# 1   ('kibedamal', 'korjeajal')
# 1   ('tõusvas', 'trendis')
# 1   ('lühiajalisi', 'töötajaid')
# 1   ('ainsatki', 'pagulast')
# 1   ('otsese', 'väljakutse')
# 1   ('ümberjaotatavatest', 'pagulastest')
# 1   ('radikaalsetel', 'rühmitustel')
# 1   ('tõsisem', 'probleem')
# 1   ('saabunud', 'kvoodiimmigrandil')
# 1   ('isetehtud', 'keemiarelva')
# 1   ('pikk', 'reis')
# 1   ('positiivset', 'mõju')
# 1   ('endise', 'piirivalvekoloneli')
# 1   ('illegaalsele', 'rändele')
# 1   ('hiinakeelsed', 'moslemid')
# 1   ('iseseisev', 'keel')
# 1   ('viivitamatut', 'arstiabi')
# 1   ('psühholoogilist', 'tuge')
# 1   ('tulevatele', 'pagulastele')
# 1   ('intensiivsed', 'keelekursused')
# 1   ('kutsuva', 'tööandja')
# 1   ('edasistes', 'välismaalaste')
# 1   ('seotud', 'menetlustes')
# 1   ('ebausaldusväärseks', 'tunnistamine')
# 1   ('ennetav', 'meede')
# 1   ('ebaausa', 'konkurentsi')
# 1   ('rikkuva', 'tööandja')
# 1   ('haige', 'olukord')
# 1   ('praeguse', 'pendelrändekriisi')
# 1   ('tegelik', 'algpõhjus')
# 1   ('parim', 'näide')
# 1   ('seotud', 'õiguskuulekust')
# 1   ('võõraks', 'probleemiks')
# 1   ('vajalikuks', 'pagulasi')
# 1   ('avaldatud', 'uuringu')
# 1   ('rahalisi', 'ressursse')
# 1   ('erinevatele', 'valdkondadele')
# 1   ('tehtud', 'kulutuste')
# 1   ('seadusvastaste', 'migrantide')
# 1   ('poliitilises', 'opositsioonis')
# 1   ('ühiskondliku', 'suhtumise')
# 1   ('füüsilist', 'jõudu')
# 1   ('edasise', 'toimumise')
# 1   ('ebainimlikes', 'tingimustes')
# 1   ('kõnealused', 'ukrainlased')
# 1   ('reaalse', 'piirikontrollivõimekuse')
# 1   ('kerjamisvastastele', 'reklaamidele')
# 1   ('immigratsioonivastane', 'erakond')
# 1   ('ametliku', 'sisserände')
# 1   ('elava', 'isiku')
# 1   ('are', 'the')
# 1   ('reguleerivast', 'kvoodisüsteemist')
# 1   ('piirkondlikeks', 'lahkumisplatvormideks')
# 1   ('nimetatud', 'asutustes')
# 1   ('põhjendatud', 'asüülitaotlejaid')
# 1   ('viimase', 'võimalusena')
# 1   ('otsene', 'tegevus')
# 1   ('kuritegelike', 'ühenduste')
# 1   ('illegaalse', 'migratsiooniga')
# 1   ('tohutu', 'legitiimsuse')
# 1   ('islamivastasel', 'suunal')
# 1   ('rahvusvaheline', 'rändeamet')
# 1   ('vahelistesse', 'piiripunktidesse')
# 1   ('antud', 'vahistamismäärus')
# 1   ('laialdast', 'pahameelt')
# 1   ('konkreetseid', 'näiteid')
# 1   ('pagulasvastaseid', 'meeleolusid')
# 1   ('peamine', 'katalüsaator')
# 1   ('välist', 'survet')
# 1   ('tegelev', 'ettevõte')
# 1   ('saabuvate', 'pagulaste')
# 1   ('kahesuunaline', 'tee')
# 1   ('aktiivset', 'pingutust')
# 1   ('uute', 'põgenikelaagrite')
# 1   ('tegutsevatel', 'päästelaevadel')
# 1   ('esmase', 'reaktsioonina')
# 1   ('tohutu', 'rahvastikukasv')
# 1   ('pretsedenditu', 'massiimmigratsiooni')
# 1   ('rändevastased', 'erakonnad')
# 1   ('tulevaid', 'põgenikke')
# 1   ('elavaid', 'venelasi')
# 1   ('avalike', 'suhete')
# 1   ('täielikus', 'valmiduses')
# 1   ('kontrollimatud', 'rändevood')
# 1   ('tollase', 'korralageduse')
# 1   ('rassistlikuks', 'saluneem')
# 1   ('valdav', 'osa')
# 1   ('puhkenud', 'skandaal')
# 1   ('sisserändeteemalise', 'luuletuse')
# 1   ('peamiseks', 'migrantide')
# 1   ('raudne', 'eesriie')
# 1   ('sügav', 'vaesus')
# 1   ('suurt', 'ebavõrdsust')
# 1   ('saadud', 'informatsiooni')
# 1   ('tihedama', 'kontrolli')
# 1   ('määravad', 'kodakondsusseadus')
# 1   ('tööealised', 'inimesed')
# 1   ('ettejuhtuvate', 'rongide')
# 1   ('30-aastane', 'peret')
# 1   ('omav', 'mees')
# 1   ('suurde', 'stressi')
# 1   ('suurem', 'arv')
# 1   ('vabatahtlike', 'tööks')
# 1   ('sagenud', 'rünnete')
# 1   ('suurte', 'islamikogukondadega')
# 1   ('juhitud', 'siseministeeriumi')
# 1   ('ettevalmistatud', 'migrantide')
# 1   ('emotsionaalsele', 'nõudlusele')
# 1   ('erilist', 'lisaväärtust')
# 1   ('suunduvaid', 'migrante')
# 1   ('siirast', 'huvi')
# 1   ('peamine', 'hirm')
# 1   ('vaadeldud', 'riikides')
# 1   ('karme', 'rände')
# 1   ('teatavaks', 'kavatsuse')
# 1   ('seotud', 'põgenikega')
# 1   ('alusetuid', 'hirmujutte')
# 1   ('lihtsast', 'asjast')
# 1   ('poliitilist', 'olukorda')
# 1   ('parema', 'süsteemi')
# 1   ('majanduslikule', 'õitsengule')
# 1   ('demokraatliku', 'kontrolli')
# 1   ('sügavad', 'erimeelsused')
# 1   ('mõtleva', 'inimese')
# 1   ('smugeldamisvastases', 'operatsioonis')
# 1   ('relvastatud', 'kurjategijad')
# 1   ('rahvusvahelises', 'sadamas')
# 1   ('kohaliku', 'aja')
# 1   ('rasedat', 'naist')
# 1   ('kehvades', 'tingimustes')
# 1   ('rahvusvaheline', 'üldsus')
# 1   ('erinevate', 'ministrite')
# 1   ('tugevatele', 'jõupingutustele')
# 1   ('läbikukkunud', 'vaktsineerimisprojekti')
# 1   ('ühiste', 'asüülireeglitega')
# 1   ('automaatset', 'jaotamist')
# 1   ('tumedast', 'prognoosist')
# 1   ('haritute', 'väljaränne')
# 1   ('karm', 'reaalsus')
# 1   ('uute', 'varjupaigataotlejate')
# 1   ('iga-aastases', 'raportis')
# 1   ('tehtud', 'kontrolli')
# 1   ('vastuvõetud', 'põgenikud')
# 1   ('sisserändevastane', 'erakond')
# 1   ('konservatiivne', 'rahvaerakond')
# 1   ('lühikese', 'aja')
# 1   ('positiivse', 'rändesaldo')
# 1   ('suurima', 'riigi')
# 1   ('pidurdav', 'algatus')
# 1   ('kindlameelset', 'vastuseisu')
# 1   ('poliitiline', 'eliit')
# 1   ('üldisemas', 'plaanis')
# 1   ('piiriäärsetele', 'aladele')
# 1   ('eri', 'rassist')
# 1   ('võrdse', 'kohtlemisega')
# 1   ('tänavuse', 'aasta')
# 1   ('plaanitav', 'rändekriisi')
# 1   ('rahvusvaheliste', 'kohustustega')
# 1   ('avalikule', 'korrale')
# 1   ('sotsiaalsele', 'toimimisele')
# 1   ('pealiskaudne', 'suhtumine')
# 1   ('tuttavaid', 'poliitikuid')
# 1   ('tuntud', 'institutsioone')
# 1   ('inglisekeelset', 'õpet')
# 1   ('kohapealne', 'info')
# 1   ('uued', 'migrandid')
# 1   ('kohalikke', 'kombeid')
# 1   ('rahvustevastased', 'vaenutegevused')
# 1   ('elavate', 'sugulaste')
# 1   ('suurt', 'vahet')
# 1   ('tänasel', 'võidupüha')
# 1   ('enim', 'erimeelsusi')
# 1   ('tekitavaid', 'teemasid')
# 1   ('saabunud', 'ukrainlased')
# 1   ('väidetav', 'nõrgenemine')
# 1   ('immigratsioonivastane', 'poliitika')
# 1   ('vägivaldsesse', 'kokkupõrkedesse')
# 1   ('suunatud', 'rünnakute')
# 1   ('kujutatud', 'parasiitide')
# 1   ('koosnevates', 'gruppides')
# 1   ('seotud', 'nõuetes')
# 1   ('väiksema', 'koguse')
# 1   ('vanade', 'riikide')
# 1   ('uute', 'kaela')
# 1   ('biomeetrilisi', 'andmeid')
# 1   ('kohalikud', 'võimuorganid')
# 1   ('seltskondliku', 'vestluse')
# 1   ('lõputu', 'immigratsioonijama')
# 1   ('positiivsete', 'varjupaiga')
# 1   ('suurt', 'arvu')
# 1   ('rassilise', 'eristamise')
# 1   ('vägivaldse', 'ajalooga')
# 1   ('alanud', 'rändekriisi')
# 1   ('väär', 'arusaam')
# 1   ('poliitiline', 'õpe')
# 1   ('õigete', 'religioonitõdede')
# 1   ('turvaline', 'riik')
# 1   ('itaalia-välistes', 'otsingu-')
# 1   ('võimekate', 'otsingu-')
# 1   ('poliitilise', 'vihkamise')
# 1   ('suurenev', 'huvi')
# 1   ('möödunud', 'nädalal')
# 1   ('rutiinse', 'kontrolli')
# 1   ('soojade', 'ilmade')
# 1   ('illegaalsete', 'piiriületuste')
# 1   ('ohtlikul', 'mereteel')
# 1   ('lärmavat', 'meest')
# 1   ('värske', 'statistika')
# 1   ('tuntav', 'tõus')
# 1   ('juriidilise', 'komitee')
# 1   ('poliitiliste', 'oponentide')
# 1   ('odava', 'tööjõu')
# 1   ('peamised', 'päritoluriigid')
# 1   ('suure', 'tõenäosusega')
# 1   ('hoogsam', 'tagasiränne')
# 1   ('migratsioonivastane', 'poliitika')
# 1   ('avaldavale', 'tõusule')
# 1   ('mustanahaliste', 'rohkust')
# 1   ('läbivaid', 'karavane')
# 1   ('suurt', 'ärevust')
# 1   ('lähedastes', 'põgenikelaagrites')
# 1   ('kontekstuaalsed', 'faktorid')
# 1   ('olulised', 'eelarvamuste')
# 1   ('illegaalset', 'migratsiooni')
# 1   ('seonduvaid', 'otsuseid')
# 1   ('saabunud', 'inimeste')
# 1   ('valge', 'inimesena')
# 1   ('hea', 'meelega')
# 1   ('ebausaldusväärseks', 'õppeasutuseks')
# 1   ('uutele', 'välisüliõpilastele')
# 1   ('avalikke', 'teenuseid')
# 1   ('kohalike', 'võimude')
# 1   ('järsu', 'kasvu')
# 1   ('saabuvaid', 'lapsi')
# 1   ('suurenev', 'arv')
# 1   ('kokkukorjatud', 'migrantidega')
# 1   ('parempoolsed', 'massiimmigratsiooni')
# 1   ('vastustavad', 'erakonnad')
# 1   ('peamise', 'nõudmise')
# 1   ('põhimõttelised', 'otsused')
# 1   ('kriitilistes', 'situatsioonides')
# 1   ('tänane', 'rändekriis')
# 1   ('viimaste', 'kuude')
# 1   ('kahtlastele', 'alustele')
# 1   ('peamiseks', 'probleemiks')
# 1   ('regionaalsete', 'liitlaste')
# 1   ('õõvastava', 'vaenulikkuse')
# 1   ('otsest', 'sidet')
# 1   ('etnilise', 'päritolu')
# 1   ('lihtne', 'teema')
# 1   ('erakondlikku', 'eelistust')
# 1   ('22-aastane', 'pärnakas')
# 1   ('uue', 'immigratsioonipoliitika')
# 1   ('tajutav', 'võõraviha')
# 1   ('kasvav', 'ksenofoobia-')
# 1   ('elavate', 'välismaalaste')
# 1   ('negatiivset', 'mõju')
# 1   ('reaalset', 'ohtu')
# 1   ('väiksema', 'maakooliga')
# 1   ('mitteseaduslike', 'sisserändajate')
# 1   ('perekondlike', 'sidemete')
# 1   ('seotud', 'välismaalase')
# 1   ('kaasneva', 'riive')
# 1   ('tõelisi', 'muudatusi')
# 1   ('viibiv', 'isik')
# 1   ('enneolematu', 'migrantide')
# 1   ('tohutud', 'rahad')
# 1   ('peamised', 'punktid')
# 1   ('ohtlikule', 'mereretkele')
# 1   ('rangete', 'seaduste')
# 1   ('ressursimahuka', 'ettevõtmisega')
# 1   ('tulevatele', 'immigrantidele')
# 1   ('suurem', 'liikumine')
# 1   ('aastaste', 'kodanike')
# 1   ('terroristliku', 'agressiooni')
# 1   ('otsene', 'tagajärg')
# 1   ('pealetungivat', 'islamit')
# 1   ('rahvuslikke', 'jõude')
# 1   ('sündivate', 'laste')
# 1   ('eri', 'meelt')
# 1   ('ebaseaduslikku', 'sisserännet')
# 1   ('selge', 'poliitika')
# 1   ('rangeid', 'kvaliteedinõudeid')
# 1   ('rahvusvaheliste', 'partneritega')
# 1   ('suure', 'sissevoolu')
# 1   ('kerge', 'taganttõuge')
# 1   ('vinduvale', 'majandusele')
# 1   ('kasvavat', 'vaenulikkust')
# 1   ('poliitilist', 'survet')
# 1   ('suurem', 'soov')
# 1   ('tõelist', 'kodakondsust')
# 1   ('illegaalset', 'piiriületamise')
# 1   ('esitatud', 'pagulaste')
# 1   ('uus', 'jaotusvalem')
# 1   ('viibivad', 'võõrtöölised')
# 1   ('ajutiste', 'piirangute')
# 1   ('illegaalsete', 'piiriületuskatsete')
# 1   ('uut', 'migratsioonilainet')
# 1   ('levinud', 'infot')
# 1   ('alusetu', 'kuulujutuga')
# 1   ('13-aastase', 'tüdruku')
# 1   ('range', 'pagulaspoliitika')
# 1   ('sisserändevastane', 'retoorika')
# 1   ('kuuluvad', 'inimesed')
# 1   ('globalistliku', 'suuna')
# 1   ('multikultuurne', 'ühiskond')
# 1   ('rahvusüleste', 'organisatsioonide')
# 1   ('potentsiaalseid', 'terroriste')
# 1   ('kavandatav', 'varjupaigataotlejate')
# 1   ('ratsionaalsem', 'lahendus')
# 1   ('põhjendatud', 'küsimusi')
# 1   ('iseeneslik', 'protsess')
# 1   ('sarnased', 'reklaamid')
# 1   ('ebaseaduslikku', 'sisserändajat')
# 1   ('teatud', 'aspektid')
# 1   ('teatud', 'olukorrad')
# 1   ('tormavatele', 'rändlejatele')
# 1   ('olulisemaid', 'põhimõtteid')
# 1   ('järgmised', 'välisministri')
# 1   ('esitatud', 'seisukohad')
# 1   ('ühinenud', 'rahvaste')
# 1   ('globaalse', 'ränderaamistiku')
# 1   ('globaalse', 'pagulasraamistiku')
# 1   ('haritud', 'inimesed')
# 1   ('lihtsamaid', 'võimalusi')
# 1   ('üritavad', 'illegaalid')
# 1   ('päästvaid', 'organisatsioone')
# 1   ('andvaid', 'firmasid')
# 1   ('rassistlikke', 'kuritegusid')
# 1   ('paremateks', 'võimalusteks')
# 1   ('saabuva', 'rändevoolu')
# 1   ('senistel', 'tööandjatel')
# 1   ('tuleva', 'aasta')
# 1   ('alalisest', 'elanikkonnast')
# 1   ('suunatud', 'massiimmigratsiooni')
# 1   ('täielik', 'konsensus')
# 1   ('duaalne', 'tööturg')
# 1   ('suuremaid', 'oskusi')
# 1   ('nõudvatel', 'ametikohtadel')
# 1   ('väiksemaid', 'oskusi')
# 1   ('nõudvates', 'ametites')
# 1   ('tõhusamale', 'piirikontrollile')
# 1   ('ebaseadusliku', 'migratsiooni')
# 1   ('poliitilise', 'surve')
# 1   ('vajaliku', 'tervishoiu')
# 1   ('tõeliste', 'põgenike')
# 1   ('valitsevate', 'probleemide')
# 1   ('siinsetele', 'õiguskaitseorganitele')
# 1   ('sisemise', 'tugevuse')
# 1   ('välised', 'probleemid')
# 1   ('poliitilised', 'jõud')
# 1   ('valmis', 'kremliga')
# 1   ('edasine', 'uurimine')
# 1   ('rohelisele', 'piirile')
# 1   ('ajutise', 'reisidokumendiga')
# 1   ('senised', 'eelarveeraldised')
# 1   ('järgmine', 'koalitsioon')
# 1   ('alalist', 'elamisluba')
# 1   ('sõlmitud', 'kokkuleppe')
# 1   ('viisavaba', 'sisenemise')
# 1   ('tüüpiline', 'pagulane')
# 1   ('noore', 'mehe')
# 1   ('igapäevane', 'töö')
# 1   ('uue', 'nädala')
# 1   ('segregeerivasse', 'süsteemi')
# 1   ('viimasel', 'hetkel')
# 1   ('ajutise', 'iseloomuga')
# 1   ('globaalse', 'ränderaamistikuga')
# 1   ('viidud', 'küsitlusest')
# 1   ('vanu', 'tõdesid')
# 1   ('ametlikku', 'vastuvõtmist')
# 1   ('peetud', 'kõnelustelt')
# 1   ('arenenud', 'maades')
# 1   ('seonduvad', 'probleemid')
# 1   ('viimase', 'ööpäeva')
# 1   ('noor', 'varjupaigataotleja')
# 1   ('negatiivse', 'otsuse')
# 1   ('tuntud', 'islamiäärmuslane')
# 1   ('rahvarohkes', 'piirkonnas')
# 1   ('ebaseaduslike', 'rändajate')
# 1   ('massilist', 'kinnipidamist')
# 1   ('viimasel', 'ööpäeval')
# 1   ('kummastavate', 'väidetega')
# 1   ('rikastavaid', 'pagulasi')
# 1   ('haavatavamad', 'põgenikud')
# 1   ('ebaseaduslikud', 'sisserändajad')
# 1   ('relvastatud', 'piirivalvurite')
# 1   ('võrdväärne', 'kinnipidamisega')
# 1   ('poliitilisi', 'parteisid')
# 1   ('tühja', 'lootuse')
# 1   ('immigratsioonivastaste', 'äärmusparteide')
# 1   ('enim', 'põgenikke')
# 1   ('rahvusvahelise', 'koostöö')
# 1   ('erinevaid', 'tahke')
# 1   ('vastuvõetamatu', 'läänemaailma')
# 1   ('multikultuurne', 'tsivilisatsioon')
# 1   ('üldised', 'sarnasused')
# 1   ('saabunud', 'põgenike')
# 1   ('tugeva', 'surve')
# 1   ('samanimelisel', 'romaanil')
# 1   ('vastaste', 'protestide')
# 1   ('tulevane', 'elukoht')
# 1   ('globaalne', 'pagulasraamistik')
# 1   ('globaalne', 'ränderaamistik')
# 1   ('viitavaid', 'sõnu')
# 1   ('uue', 'vasakvalitsuse')
# 1   ('valitud', 'leiboristist')
# 1   ('rassistatud', 'grupist')
# 1   ('ulatuslikke', 'õhurünnakuid')
# 1   ('peamistele', 'põhjustele')
# 1   ('haavatavas', 'olukorras')
# 1   ('ühist', 'põgenikepoliitikat')
# 1   ('tohutu', 'laviiniga')
# 1   ('seotud', 'allikad')
# 1   ('asuvate', 'piiripunktide')
# 1   ('ebaseadusliku', 'immigratsiooni')
# 1   ('massilises', 'sisseveos')
# 1   ('putinimeelsed', 'venelased')
# 1   ('konkreetse', 'legendi')
# 1   ('jõulised', 'pidurid')
# 1   ('ühe-aastane', 'elamisluba')
# 1   ('ülemöödunud', 'aastal')
# 1   ('rahvusvahelise', 'politseiorganisatsiooni')
# 1   ('eri', 'bürood')
# 1   ('väiksem', 'osa')
# 1   ('vastav', 'näitaja')
# 1   ('nüüdseks', 'immigratsiooni')
# 1   ('murelikum', 'rahvas')
# 1   ('avaldatud', 'auditis')
# 1   ('suurt', 'hulka')
# 1   ('mustalt', 'mandrilt')
# 1   ('uueks', 'elukohaks')
# 1   ('vastavaid', 'spetsialiste')
# 1   ('tugevast', 'politseist')
# 1   ('järgmise', 'aasta')
# 1   ('uue', 'seaduseelnõude')
# 1   ('illegaalsele', 'immigrandile')
# 1   ('saabunud', 'isikule')
# 1   ('reaalse', 'vanglakaristuse')
# 1   ('pidev', 'rikkumine')
# 1   ('rahaline', 'toetamine')
# 1   ('aastane', 'vanglakaristus')
# 1   ('julmematest', 'smugeldajatest')
# 1   ('halvenevaid', 'ilmastikuolusid')
# 1   ('ülerahvastatud', 'kummipaatidesse')
# 1   ('suurt', 'tulu')
# 1   ('kehtivat', 'tavaõigust')
# 1   ('olematuks', 'tõsiasja')
# 1   ('globaalne', 'ränne')
# 1   ('soovivate', 'riikide')
# 1   ('ohtliku', 'välismaalase')
# 1   ('kehtetuks', 'tunnistamise')
# 1   ('üldohtliku', 'kuriteo')
# 1   ('saabunud', 'migrante')
# 1   ('võimalik', 'inimkaubanduse')
# 1   ('teatud', 'piirkondadesse')
# 1   ('suuri', 'kogukondi')
# 1   ('kohalike', 'seaduste')
# 1   ('järsk', 'pagulaste')
# 1   ('kõrget', 'hinda')
# 1   ('religioossele', 'vähemusele')
# 1   ('võõraid', 'sisserändajaid')
# 1   ('teatavate', 'sisserändajate')
# 1   ('noored', 'tütarlapsed')
# 1   ('tagasilükatud', 'asüülitaotlustega')
# 1   ('eraldaval', 'veteväljal')
# 1   ('edukat', 'kasvu')
# 1   ('uus', 'valitsus')
# 1   ('vajalikud', 'reformid')
# 1   ('kuueaastasest', 'majanduslangusest')
# 1   ('tulevas', 'riigis')
# 1   ('traumaatilised', 'kogemused')
# 1   ('oluline', 'teemat')
# 1   ('uusimate', 'arengutega')
# 1   ('sealsetest', 'elanikest')
# 1   ('vägivaldse', 'käitumise')
# 1   ('mustanahaline', 'mees')
# 1   ('vaba', 'juurdepääsu')
# 1   ('okupatsiooniaegse', 'sisserände')
# 1   ('keskmist', 'taset')
# 1   ('töötavat', 'ukrainlast')
# 1   ('kohustuslikust', 'õppemahust')
# 1   ('külastavatelt', 'põgenikelt')
# 1   ('väärt', 'oskustööliste')
# 1   ('õigusliku', 'alusega')
# 1   ('hooajalisele', 'tööle')
# 1   ('ettenähtud', 'korras')
# 1   ('seotud', 'inimkaubandusega')
# 1   ('illegaalse', 'piiriületusega')
# 1   ('diskrimineerimisvastast', 'seadust')
# 1   ('seksuaalse', 'orientatsiooni')
# 1   ('varasema', 'aastaga')
# 1   ('koostatud', 'raportis')
# 1   ('rahvusvahelise', 'hukkamõistuga')
# 1   ('tegelik', 'võõrtööliste')
# 1   ('kaheksalapselises', 'peres')
# 1   ('demograafilises', 'kriisis')
# 1   ('väike', 'sündimus')
# 1   ('suur', 'väljaränne')
# 1   ('illegaalse', 'migratsiooni')
# 1   ('tehnoloogilisest', 'arengust')
# 1   ('lubatud', 'migrantidele')
# 1   ('šokeeriv', 'küsitlus')
# 1   ('vankumatus', 'toetuses')
# 1   ('uueks', 'ametiajaks')
# 1   ('asustatud', 'piirkondadest')
# 1   ('kuuluv', 'poliitik')
# 1   ('tähtajatu', 'elamisluba')
# 1   ('rohelisel', 'piiril')
# 1   ('madala', 'palgaga')
# 1   ('täieliku', 'kaotamise')
# 1   ('tagakiusatumaid', 'inimgruppe')
# 1   ('tumedanahaline', 'staar')
# 1   ('rassistliku', 'ründe')
# 1   ('valdav', 'enamus')
# 1   ('võimalike', 'eluruumide')
# 1   ('võimalike', 'töökohtade')
# 1   ('mustanahaliste', 'olukorda')
# 1   ('venekeelsete', 'olukorraga')
# 1   ('uue', 'rändepaktiga')
# 1   ('alternatiivseid', 'teid')
# 1   ('intensiivsemal', 'ajal')
# 1   ('elavatest', 'välismaalastest')
# 1   ('praegusel', 'tasemel')
# 1   ('suurima', 'moslemikogukonnaga')
# 1   ('ebaloomulike', 'riigipiiride')
# 1   ('sõjalist', 'toetust')
# 1   ('islamistlike', 'rühmituste')
# 1   ('alaline', 'eesistuja')
# 1   ('vahelisele', 'kokkuleppele')
# 1   ('saabunud', 'põgenikud')
# 1   ('vajalik', 'rahasumma')
# 1   ('tavatutel', 'töötingimustel')
# 1   ('arulage', 'rumalus')
# 1   ('idealistlik', 'suhtumine')
# 1   ('segarassilised', 'lapsed')
# 1   ('katkise', 'maailma')
# 1   ('kaleidoskoopilised', 'tooted')
# 1   ('ülemaailmse', 'orjaturu')
# 1   ('jätkuvast', 'toimimisest')
# 1   ('uue', 'põgenikelainega')
# 1   ('asuvat', 'armeebaasi')
# 1   ('julma', 'korra')
# 1   ('julge', 'intervjuu')
# 1   ('mustanahaline', 'laps')
# 1   ('lahkuvate', 'eestlaste')
# 1   ('tüütu', 'vingumine')
# 1   ('järjekordsete', 'valimiste')
# 1   ('uute', 'vastuvõtmise')
# 1   ('ilmuvas', 'faktikontrolli')
# 1   ('töötavaid', 'eestlasi')
# 1   ('tänase', 'seisuga')
# 1   ('viimase', 'nädala')
# 1   ('illegaalseid', 'migrante')
# 1   ('eraldi', 'tingimused')
# 1   ('pikaajaliseks', 'kohustuseks')
# 1   ('vaesematest', 'piirkondadest')
# 1   ('saabunud', 'migrantidest')
# 1   ('antud', 'põgenikustaatus')
# 1   ('ajutiseks', 'lahenduseks')
# 1   ('moraalne', 'kohus')
# 1   ('sotsiaalne', 'kohus')
# 1   ('seaduslikke', 'teid')
# 1   ('eelmisel', 'ööpäeval')
# 1   ('suuremad', 'rahvastiku')
# 1   ('vastavatest', 'näitajatest')
# 1   ('peamised', 'lähteriigid')
# 1   ('iseseisvat', 'immigratsioonipoliitikat')
# 1   ('rahvusvahelistele', 'normidele')
# 1   ('avalikus', 'ruumis')
# 1   ('kopsaka', 'summa')
# 1   ('vaikiva', 'heakskiidu')
# 1   ('täiendavaid', 'patrulle')
# 1   ('sisenevaid', 'sõidukeid')
# 1   ('ebaseaduslikku', 'rännet')
# 1   ('islamistliku', 'lääne-vastasuse')
# 1   ('tegelikku', 'sõnumit')
# 1   ('okkaline', 'teema')
# 1   ('suur', 'probleem')
# 1   ('saadud', 'tulusid')
# 1   ('avaliku', 'korra')
# 1   ('õiglasest', 'nördimusest')
# 1   ('vasak-liberaalsed', 'ringkonnad')
# 1   ('valitsusmeelsed', 'ajalehed')
# 1   ('pikkuse', 'puhvertsooni')
# 1   ('uuele', 'kriisile')
# 1   ('pingeliste', 'suhete')
# 1   ('määramatu', 'ulatusega')
# 1   ('keerulised', 'suhted')
# 1   ('möödunud', 'neljapäeval')
# 1   ('ebaseaduslikku', 'läbirännet')
# 1   ('pakutud', 'lisamiljardi')
# 1   ('radikaalsed', 'muudatused')
# 1   ('föderaalsele', 'sisserände-')
# 1   ('viidud', 'juurdluse')
# 1   ('praeguseidki', 'migrante')
# 1   ('jõuka', 'lääne')
# 1   ('kahanevaid', 'võlusid')
# 1   ('kristlik-sotsiaalset', 'liitu')
# 1   ('alast', 'sisevõitlust')
# 1   ('olulisi', 'piiranguid')
# 1   ('varmad', 'seadustest')
# 1   ('möödunud', 'kuul')
# 1   ('rassismivastane', 'konverents')
# 1   ('antud', 'valgetele')
# 1   ('negatiivseid', 'reaktsioone')
# 1   ('illegaalse', 'emigratsiooni')
# 1   ('ebaseaduslikku', 'immigratsiooni')
# 1   ('tihedaim', 'ränne')
# 1   ('aktiivse', 'välispoliitika')
# 1   ('kahepoolseid', 'suhteid')
# 1   ('senise', 'põgenikevoo')
# 1   ('tulevaid', 'pagulasi')
# 1   ('sulast', 'teele')
# 1   ('seotud', 'ohtudest')
# 1   ('rassismivastastel', 'meeleavaldustel')
# 1   ('sotsiaalse', 'distantseerumise')
# 1   ('ajaline', 'jaotus')
# 1   ('eelmise', 'kokkusaamise')
# 1   ('ebainimlik', 'ümberkäimine')
# 1   ('sotsiaaldemokraatlikule', 'päevalehele')
# 1   ('antud', 'intervjuus')
# 1   ('haavatavas', 'positsioonis')
# 1   ('uuel', 'asukohamaal')
# 1   ('kaasaegne', 'kontrollpunktidega')
# 1   ('valvatav', 'piir')
# 1   ('piiriülene', 'kuritegevus')
# 1   ('rohelist', 'piiri')
# 1   ('inimlikust', 'aspektist')
# 1   ('traagilist', 'saatust')
# 1   ('küünilist', 'himu')
# 1   ('suurte', 'inimhulkade')
# 1   ('eksistentsiaalse', 'kuluga')
# 1   ('punasest', 'joonest')
# 1   ('järgmisel', 'kuul')
# 1   ('parimal', 'juhul')
# 1   ('rahvusvaheliste', 'suhete')
# 1   ('saadud', 'teave')
# 1   ('kuritegelikud', 'ühendused')
# 1   ('rasket', 'olukorda')
# 1   ('esmast', 'vasikavaimustust')
# 1   ('väidetavate', 'sõjapõgenike')
# 1   ('heatahtliku', 'abistamise')
# 1   ('vähimatki', 'põhjust')
# 1   ('väljaöeldud', 'numbrile')
# 1   ('islamiseerumisevastane', 'aktivist')
# 1   ('teisipäevasel', 'kohtumisel')
# 1   ('võimalik', 'pagulasseisund')
# 1   ('põhjendatud', 'alus')
# 1   ('ohtlikuks', 'riigi')
# 1   ('süüdimõistev', 'kohtuotsus')
# 1   ('neljapäevastel', 'andmetel')
# 1   ('liigse', 'hulga')
# 1   ('elamisväärsena', 'hoidmiseks')
# 1   ('klassilisele', 'ebavõrdsusele')
# 1   ('tuginev', 'segregatsioon')
# 1   ('üldine', 'taust')
# 1   ('uusi', 'punkte')
# 1   ('laialdased', 'võimalused')
# 1   ('välismaiseid', 'islamiradikaale')
# 1   ('ühist', 'keelt')
# 1   ('liberaalsete', 'valitsuste')
# 1   ('sõjalise', 'piirivalve')
# 1   ('rahvusvahelisele', 'mõjule')
# 1   ('ühepoolsetest', 'sammudest')
# 1   ('kolmepoolsete', 'sammude')
# 1   ('negatiivsed', 'mõjud')
# 1   ('ajutine', 'tõke')
# 1   ('ebaseadusliku', 'piiriületuse')
# 1   ('looduslik', 'olustik')
# 1   ('ebaseaduslikku', 'piiriületust')
# 1   ('korralik', 'kodanik')
# 1   ('põrkuvad', 'õigused')
# 1   ('elavad', 'migrandid')
# 1   ('verise', 'noaga')
# 1   ('ringijooksvat', 'sisserändajat')
# 1   ('valgustatud', 'islamirevolutsionääriks')
# 1   ('ohtlikuks', 'kurjategijaks')
# 1   ('rahvusvaheliste', 'jõudude')
# 1   ('sealne', 'olukord')
# 1   ('võimaliku', 'rändevoo')
# 1   ('otsest', 'julgeolekuohtu')
# 1   ('multikultuursetes', 'riikides')
# 1   ('moodne', 'finantstehnoloogiafirma')
# 1   ('uus', 'kliendibaas')
# 1   ('võimalikele', 'karidele')
# 1   ('esitatud', 'taotluste')
# 1   ('avaliku', 'sektori')
# 1   ('sotsiaalse', 'ettevõtlusega')
# 1   ('kohalik', 'maffia')
# 1   ('rahastatavad', 'migrantide')
# 1   ('ksenofoobse', 'kivirünnaku')
# 1   ('saadetud', 'vastuses')
# 1   ('tuvastatud', 'illegaalide')
# 1   ('ebaseaduslikku', 'migranti')
# 1   ('rahvusvahelise', 'terrorirünnaku')
# 1   ('protsendiline', 'tõenäosus')
# 1   ('seksuaalsest', 'orientatsioonist')
# 1   ('suurt', 'sisserändesurvet')
# 1   ('varieeruvast', 'kultuurikontekstist')
# 1   ('olulistes', 'aspektides')
# 1   ('paha', 'sõna')
# 1   ('piisaval', 'tasemel')
# 1   ('majanduslikule', 'arengule')
# 1   ('demograafilisele', 'olukorrale')
# 1   ('karmimale', 'migratsioonipoliitikale')
# 1   ('tugev', 'piirikontroll')
# 1   ('olevat', 'sidemeid')
# 1   ('majanduslik', 'kahju')
# 1   ('värskes', 'artiklis')
# 1   ('pürgivaid', 'migrante')
# 1   ('tuntud', 'pühakojas')
# 1   ('ohvriterohkeim', 'rünnak')
# 1   ('põhjalikum', 'põgenikepoliitika')
# 1   ('merekõlbmatute', 'paatidega')
# 1   ('õigeks', 'ajaks')
# 1   ('alatuid', 'inimesi')
# 1   ('oluline', 'osa')
# 1   ('teatud', 'tingimustel')
# 1   ('viisavabale', 'reisimisele')
# 1   ('eduka', 'sisserändepoliitikaga')
# 1   ('numbrilist', 'ettepanekut')
# 1   ('ajutise', 'tööjõu')
# 1   ('ühine', 'pressikonverents')
# 1   ('peamisi', 'peatuspunkte')
# 1   ('kohustusliku', 'ümberpaigutamise')
# 1   ('esialgse', 'mehhanismi')
# 1   ('poliitiline', 'ideoloogia')
# 1   ('arenenud', 'maailmas')
# 1   ('vabu', 'töökäsi')
# 1   ('kavandatavaid', 'muudatusi')
# 1   ('tihedama', 'asustusega')
# 1   ('moslemivastaseid', 'videoid')
# 1   ('paremäärmusliku', 'organisatsiooni')
# 1   ('kohutavad', 'rassistid')
# 1   ('kohutav', 'vaesus')
# 1   ('ulatuva', 'kasumi')
# 1   ('uue', 'töökoha')
# 1   ('ametlik', 'põgenike')
# 1   ('illegaalse', 'läbirände')
# 1   ('määramata', 'ajaks')
# 1   ('riikidevaheline', 'piirikontroll')
# 1   ('vangistatud', 'džihadistid')
# 1   ('mõõdukaid', 'imaame')
# 1   ('mõõdukat', 'islamit')
# 1   ('illegaalsed', 'sisserändajad')
# 1   ('ulatuslikku', 'immigratsiooni')
# 1   ('tõsine', 'lõimumisülesanne')
# 1   ('liberaalset', 'demokraatiat')
# 1   ('konservatiivset', 'maailmavaadet')
# 1   ('euroopalikke', 'väärtusi')
# 1   ('kõlavaid', 'sõnu')
# 1   ('kontrollimatut', 'rändevoogu')
# 1   ('ühine', 'arusaam')
# 1   ('võimalik', 'hukkumine')
# 1   ('pealesunnitud', 'päästeaktsioonides')
# 1   ('rahvusvahelisi', 'päästmisreegleid')
# 1   ('vääramatust', 'jõust')
# 1   ('küünilisest', 'eludega')
# 1   ('digitaalseid', 'jälgi')
# 1   ('pikemaks', 'ajaks')
# 1   ('teatud', 'hüvesid')
# 1   ('suurt', 'tõusu')
# 1   ('riikliku', 'poliitika')
# 1   ('eurone', 'pagulase')
# 1   ('riikliku', 'julgoleku')
# 1   ('töötavad', 'ukrainlased')
# 1   ('vaimseid', 'väärtusi')
# 1   ('rassismivastasel', 'meeleavaldustel')
# 1   ('erinevast', 'vandalismi')
# 1   ('kuuluv', 'justiitsminister')
# 1   ('saavatest', 'immigrantidest')
# 1   ('suurt', 'pagulaste')
# 1   ('uut', 'põgenikelepet')
# 1   ('illegaalsed', 'migrandid')
# 1   ('töötavatelt', 'välismaalastelt')
# 1   ('demograafilisest', 'olukorrast')
# 1   ('kohustuslike', 'kvootide')
# 1   ('soovitud', 'kokkulepet')
# 1   ('ringirändavad', 'illegaalid')
# 1   ('rahvuskonservatiivse', 'erakonnana')
# 1   ('tumedanahalised', 'inimesed')
# 1   ('saabunud', 'riigipeade')
# 1   ('vastasel', 'meeleavaldusel')
# 1   ('seotud', 'valitsustüli')
# 1   ('erinevates', 'kanalites')
# 1   ('tulenevad', 'probleemid')
# 1   ('üldine', 'arvamus')
# 1   ('vastupidine', 'valitsuse')
# 1   ('aetava', 'poliitikaga')
# 1   ('vähemal', 'määral')
# 1   ('rahvuslikud', 'jõud')
# 1   ('tähtsatest', 'ametitest')
# 1   ('aktuaalne', 'kaamera')
# 1   ('kodumaise', 'toiduta')
# 1   ('endine', 'siseminister')
# 1   ('immigratsioonivastase', 'partei')
# 1   ('mittekuuluva', 'riigi')
# 1   ('suure', 'hulga')
# 1   ('tagasilükatud', 'varjupaigataotlejate')
# 1   ('massilisest', 'sisserändest')
# 1   ('vajalikke', 'menetlustoiminguid')
# 1   ('lõhestavast', 'immigratsioonipoliitikast')
# 1   ('kohalikud', 'elanikud')
# 1   ('legaalsed', 'meetmed')
# 1   ('vanad', 'meetmed')
# 1   ('suunatud', 'pagulaskriisiga')
# 1   ('ebaseaduslikul', 'rändel')
# 1   ('ebaseaduslikul', 'piiriületusel')
# 1   ('võimalik', 'koalitsioon')
# 1   ('vajalikuks', 'renditööjõu')
# 1   ('täpsemat', 'reguleerimist')
# 1   ('riiklike', 'meetmetega')
# 1   ('passiivsete', 'inimeste')
# 1   ('legaalseks', 'immigratsiooniks')
# 1   ('piiramatu', 'võõrtööjõu')
# 1   ('otseseks', 'põhjuseks')
# 1   ('suures', 'osas')
# 1   ('massilisest', 'sissevoolust')
# 1   ('seotud', 'kulude')
# 1   ('jõhker', 'kuritegu')
# 1   ('erinevatele', 'arvamustele')
# 1   ('töötud', 'immigrandid')
# 1   ('puudutavaid', 'punkte')
# 1   ('kohalikud', 'võimud')
# 1   ('ohvriterohkeid', 'rünnakuid')
# 1   ('arvukad', 'sisserändajad')
# 1   ('laiem', 'liikumisruum')
# 1   ('poliitilise', 'kõne')
# 1   ('poliitilises', 'kõnes')
# 1   ('rassistliku', 'vihakõnega')
# 1   ('sügavaid', 'probleeme')
# 1   ('homovastane', 'kõne')
# 1   ('võrdväärne', 'ligipääs')
# 1   ('järgmine', 'küsimus')
# 1   ('valdav', 'enamik')
# 1   ('vahetus', 'naabruses')
# 1   ('vaestes', 'riikides')
# 1   ('ülekoormatud', 'põgenikelaagrites')
# 1   ('kõrge', 'ametnik')
# 1   ('uueks', 'nähtuseks')
# 1   ('seisvatest', 'teemadest')
# 1   ('kõrgeim', 'näitaja')
# 1   ('üleriigilise', 'suuroperatsiooni')
# 1   ('kriminaalse', 'minevikuga')
# 1   ('saabuvate', 'immigrantide')
# 1   ('kohaliku', 'elaniku')
# 1   ('seotud', 'probleemide')
# 1   ('stabiilsem', 'raamistik')
# 1   ('allkirjastatud', 'leppe')
# 1   ('saabuvate', 'inimeste')
# 1   ('kohustuslikke', 'kvoote')
# 1   ('võimatu', 'ellu')
# 1   ('teisene', 'migratsioon')
# 1   ('uued', 'migratsioonireformid')
# 1   ('avaldatud', 'andmete')
# 1   ('varasemale', 'piirangute')
# 1   ('tugineva', 'sisserände')
# 1   ('täitmata', 'õppekava')
# 1   ('antava', 'elamisloa')
# 1   ('nõutavas', 'ulatuses')
# 1   ('suure', 'töötusmäära')
# 1   ('süstemaatilisest', 'rassismist')
# 1   ('kiiremas', 'tempos')
# 1   ('relvastatud', 'sissetungi')
# 1   ('tahtliku', 'eskalatsioonina')
# 1   ('vahelisel', 'piiril')
# 1   ('võimalikuks', 'migrandikriisiks')
# 1   ('avalikus', 'teenistuses')
# 1   ('ebaseadusliku', 'tööjõu')
# 1   ('pika', 'laua')
# 1   ('väärikas', 'palk')
# 1   ('pidavad', 'inimesed')

# %%
adj_noun_list = []

for i, row in data.iterrows():

  if row["stanceConsolidated"] >= 3:
    continue

  prev_pos, prev_word = "-", "-"
  for pos, word in zip(row["morph_analysis"].partofspeech, row["morph_analysis"].words.text):
    pos = pos[0]
    word = word.lower()
    if prev_pos in "ACU" and pos in "S":
      adj_noun_list += [(prev_word, word)]
    prev_pos = pos
    prev_word = word

against_pairs = FreqDist(adj_noun_list)

# %%
for pair, count in against_pairs.most_common():
  print(f"{count: <3} {pair}")
# Out:
# 8   ('illegaalsete', 'immigrantide')
# 8   ('odava', 'tööjõu')
# 7   ('konservatiivne', 'rahvaerakond')
# 4   ('massilise', 'sisserände')
# 4   ('uute', 'uudiste')
# 4   ('illegaalse', 'immigratsiooni')
# 3   ('uus', 'valitsus')
# 3   ('uued', 'uudised')
# 3   ('illegaalseid', 'immigrante')
# 3   ('suur', 'probleem')
# 3   ('pikka', 'aega')
# 3   ('kristliku', 'taustaga')
# 3   ('ebaseaduslikke', 'migrante')
# 3   ('euroopalike', 'väärtuste')
# 3   ('kogu', 'aeg')
# 3   ('paremat', 'elu')
# 3   ('täie', 'rauaga')
# 3   ('pikemat', 'aega')
# 2   ('kogu', 'maailma')
# 2   ('suurt', 'hulka')
# 2   ('massiline', 'immigratsioon')
# 2   ('liberaalses', 'ühiskonnas')
# 2   ('tohutul', 'hulgal')
# 2   ('saabunud', 'põgenike')
# 2   ('poliitilise', 'islami')
# 2   ('ebaseadusliku', 'migratsiooni')
# 2   ('negatiivne', 'mõju')
# 2   ('tänuväärset', 'tööd')
# 2   ('viimasel', 'ajal')
# 2   ('poliitiline', 'nõunik')
# 2   ('liberaalse', 'demokraatia')
# 2   ('tugeva', 'surve')
# 2   ('suures', 'osas')
# 2   ('demograafilisi', 'probleeme')
# 2   ('hea', 'elu')
# 2   ('noored', 'mehed')
# 2   ('võõraste', 'kultuuride')
# 2   ('tohutud', 'summad')
# 2   ('valgel', 'liival')
# 2   ('noored', 'naised')
# 2   ('laias', 'laastus')
# 2   ('liberaalses', 'maailmas')
# 2   ('kogu', 'maailmas')
# 2   ('massiline', 'sisseränne')
# 2   ('suurem', 'osa')
# 2   ('kogu', 'maailm')
# 2   ('valge', 'rassi')
# 2   ('parema', 'elu')
# 2   ('terve', 'mõistusega')
# 2   ('avatud', 'uste')
# 2   ('rahvuslike', 'huvide')
# 2   ('viimastel', 'aastatel')
# 2   ('suurimas', 'linnas')
# 2   ('sinine', 'äratus')
# 2   ('illegaalsed', 'migrandid')
# 2   ('range', 'immigratsioonipoliitika')
# 2   ('ebaseaduslik', 'migratsioon')
# 1   ('omad', 'inimesed')
# 1   ('võõraste', 'sisserändest')
# 1   ('paarituhandelise', 'sisserände')
# 1   ('edasine', 'väljasuretamine')
# 1   ('uus', 'sundkollektiviseerimine')
# 1   ('ajalooline', 'maakaart')
# 1   ('asjatut', 'sõkeldamist')
# 1   ('sõgedat', 'sekeldamist')
# 1   ('jätkuv', 'kuuletumine')
# 1   ('jätkuvast', 'sissetoomisest')
# 1   ('sissetoodud', 'õnneõngitsejate')
# 1   ('ausatele', 'kodanikele')
# 1   ('pagulas-poliitilse', 'ajupesu')
# 1   ('ideoloogiline', 'totalitarism')
# 1   ('teisipäevased', 'pommiplahvatused')
# 1   ('progressiivsed', 'sallivuslased')
# 1   ('kontrollimatu', 'sisserände')
# 1   ('tahtvate', 'migrantide')
# 1   ('kuku', 'raadio')
# 1   ('löövat', 'võõrtööjõu')
# 1   ('tühiseks', 'pidamise')
# 1   ('kindlat', 'teadmist')
# 1   ('vahendatud', 'teabega')
# 1   ('majanduslikus', 'sõltumatuses')
# 1   ('inimlike', 'aspektidega')
# 1   ('kaugete', 'teemade')
# 1   ('halb', 'otsus')
# 1   ('proletaarsel', 'moel')
# 1   ('kõrgharitud', 'tehnokraat')
# 1   ('tohutu', 'võit')
# 1   ('antidemokraatlike', 'sammudega')
# 1   ('verise', 'kodusõja')
# 1   ('käesoleva', 'migratsioonikriisi')
# 1   ('liberaalne', 'kultuurieliit')
# 1   ('poliitilise', 'juhi')
# 1   ('valitaval', 'erakonnal')
# 1   ('aus', 'plaan')
# 1   ('vasakpoolsed', 'poliitikad')
# 1   ('õigele', 'teele')
# 1   ('õige', 'rahvuskonservatiiv')
# 1   ('vägivaldne', 'meeleavalduste')
# 1   ('22-aastase', 'iraaklasest')
# 1   ('23-aastase', 'süürlasest')
# 1   ('35-aastane', 'sakslane')
# 1   ('peamist', 'ohu')
# 1   ('siinseid', 'pagulasi')
# 1   ('isikliku', 'rändekriisi')
# 1   ('langeva', 'koormuse')
# 1   ('reedene', 'uudis')
# 1   ('sealsetest', 'rassikonfliktidest')
# 1   ('madal', 'sündimus')
# 1   ('traditsiooniliste', 'pereväärtuste')
# 1   ('võõraste', 'väärtushinnangute')
# 1   ('erinevatel', 'põhjustel')
# 1   ('sealses', 'ühiskonnas')
# 1   ('kogu', 'sallivusleer')
# 1   ('vähimagi', 'kahtluseta')
# 1   ('rassilise', 'võrdsuse')
# 1   ('ilmunud', 'raamatus')
# 1   ('õõvastava', 'täpsusega')
# 1   ('elukutselisi', 'protesteerijaid')
# 1   ('viibivad', 'migrandid')
# 1   ('serveeritav', 'ideoloogia')
# 1   ('tõeliseks', 'koletiseks')
# 1   ('suurt', 'islamikogukonda')
# 1   ('õige', 'tegu')
# 1   ('poliitiline', 'korrektsus')
# 1   ('demograafiline', 'mõju')
# 1   ('kultuurilist', 'identiteeti')
# 1   ('majanduslik', 'mõju')
# 1   ('eelmise', 'aasta')
# 1   ('mustanahalise', 'laiba')
# 1   ('erinevad', 'uudisteagentuurid')
# 1   ('sarnaseid', 'videoid')
# 1   ('massilist', 'pealetungi')
# 1   ('pikkust', 'menetlust')
# 1   ('globalistlike', 'ringkondade')
# 1   ('ehtsaim', 'libauudise')
# 1   ('euroopalikes', 'väärtustes')
# 1   ('multikultuurse', 'ühiskonna')
# 1   ('mõistusevastase', 'piirini')
# 1   ('põhiseaduslikule', 'korrale')
# 1   ('põhjalik', 'töö')
# 1   ('huvitav', 'lugemine')
# 1   ('aktiivsed', 'migratsioonitoetajad')
# 1   ('globalistlike', 'arengutega')
# 1   ('ideoloogiline', 'aktiivsus')
# 1   ('järjekordse', 'hoobi')
# 1   ('valgete', 'väljaütlemisi')
# 1   ('negroidse', 'rassi')
# 1   ('kurje', 'sõnu')
# 1   ('odavatest', 'paskvillidest')
# 1   ('rassistlike', 'rünnakute')
# 1   ('eri', 'riikides')
# 1   ('vasakäärmuslikud', 'jõud')
# 1   ('illegaalsed', 'sisserändajad')
# 1   ('sisulisest', 'orjatööst')
# 1   ('rahvuslik', 'erakond')
# 1   ('läänelikus', 'ruumisšariaadiseaduste')
# 1   ('põhineva', 'kuritegevuse')
# 1   ('võõraste', 'õigus')
# 1   ('sotsiaalset', 'olukorda')
# 1   ('suletud', 'sadamate')
# 1   ('ranged', 'karistused')
# 1   ('uutest', 'asulatest')
# 1   ('uued', 'juutidest')
# 1   ('põliste', 'araablaste')
# 1   ('kristlike', 'demokraatide')
# 1   ('sissetulevatele', 'põgenikele')
# 1   ('noorest', 'jeziidi')
# 1   ('pikka', 'seksiorjatari')
# 1   ('analoogne', 'jutt')
# 1   ('pagulasvastasel', 'lehel')
# 1   ('ametlik', 'pressiesindaja')
# 1   ('valimatu', 'süürlaste')
# 1   ('kibedaid', 'vilju')
# 1   ('õnnetud', 'ohvrid')
# 1   ('teadlik', 'tausta')
# 1   ('seitsmeprotsendist', 'toetust')
# 1   ('poliitilisi', 'oponente')
# 1   ('kakskeelsed', 'koolid')
# 1   ('vihkavat', 'olukorda')
# 1   ('vastavatele', 'asutustele')
# 1   ('mõtlevaid', 'inimesi')
# 1   ('rassistlikust', 'riigist')
# 1   ('saabuvaid', 'välismaalasi')
# 1   ('21-aastasel', 'süürlasel')
# 1   ('ebaseaduslikel', 'migrantidel')
# 1   ('ebapuhas', 'loom')
# 1   ('kasvav', 'sisseränne')
# 1   ('peetavatele', 'koertele')
# 1   ('alanud', 'koerte')
# 1   ('valimatu', 'tapmine')
# 1   ('jõhker', 'oht')
# 1   ('allaneelava', 'islami')
# 1   ('kummaline', 'intsident')
# 1   ('illegaalset', 'migranti')
# 1   ('globaalse', 'antiglobalismiga')
# 1   ('ehtsaim', 'vihaõhutus')
# 1   ('iseseisva', 'riigi')
# 1   ('hiljutises', 'kõnes')
# 1   ('solidaarne', 'riikidega')
# 1   ('kohustusliku', 'ümberjagamispoliitikaga')
# 1   ('selge', 'sõnum')
# 1   ('seotud', 'immigrantide')
# 1   ('siinsele', 'tööturule')
# 1   ('suuremate', 'vastuolude')
# 1   ('immigratsioonivastase', 'poliitiku')
# 1   ('ranget', 'migratsiooniseadust')
# 1   ('suuremad', 'võimalused')
# 1   ('kogu', 'info')
# 1   ('tundmatut', 'migranti')
# 1   ('nõudvat', 'aktivisti')
# 1   ('rahvuslikke', 'väärtusi')
# 1   ('lühinägelikele', 'uuendajatele')
# 1   ('valelikus', 'liberaalnarratiivis')
# 1   ('hukatuslik', 'multikultuuristumine')
# 1   ('viimane', 'aeg')
# 1   ('illegaalsete', 'migrantide')
# 1   ('ebaõnnestunud', 'tegevuse')
# 1   ('korraldatud', 'korralagedusest')
# 1   ('suuremaid', 'kohti')
# 1   ('põhjendamatut', 'tööjõu')
# 1   ('globaalse', 'rändepaktiga')
# 1   ('rahvusliku', 'julgeoleku')
# 1   ('veidrat', 'migratsioonipoliitikat')
# 1   ('suuri', 'liikmesriike')
# 1   ('liigse', 'upsakuse')
# 1   ('poputava', 'riigi')
# 1   ('süütuid', 'inimesi')
# 1   ('ühtse', 'katuse')
# 1   ('diplomaatilise', 'staatuse')
# 1   ('töötavate', 'välismaalaste')
# 1   ('ebaseaduslikke', 'sissesõiduvõimalusi')
# 1   ('ebaseadusliku', 'rände')
# 1   ('kõrged', 'pagulaskvoodid')
# 1   ('tõsisema', 'multikulti')
# 1   ('negatiivne', 'rändesaldo')
# 1   ('lühiajaliste', 'võõrtöölistega')
# 1   ('järjekindla', 'rahvastiku')
# 1   ('moraalse', 'relativismi')
# 1   ('korruptiivse', 'ringkäenduse')
# 1   ('küünilise', 'majanduspoliitikaga')
# 1   ('vaesema', 'riigi')
# 1   ('omal', 'jõul')
# 1   ('otseses', 'uppumisohus')
# 1   ('jube', 'migratsiooni')
# 1   ('valjud', 'hääled')
# 1   ('ohtlikule', 'dokumendile')
# 1   ('globalistlikust', 'ruumist')
# 1   ('kõrgem', 'oht')
# 1   ('olemasolevatele', 'probleemidele')
# 1   ('uued', 'probleemid')
# 1   ('vaba', 'mõtlemise')
# 1   ('uhkete', 'autode')
# 1   ('seksuaalse', 'vabaduse')
# 1   ('kohusetundetu', 'mõttestiiliga')
# 1   ('teatud', 'aja')
# 1   ('head', 'nägu')
# 1   ('ilmselge', 'hübriidsõda')
# 1   ('ääretu', 'anarhismiga')
# 1   ('ainus', 'võimalus')
# 1   ('demokraatlikus', 'riigis')
# 1   ('võimas', 'ühendus')
# 1   ('vanas', 'maailmas')
# 1   ('otsusekindla', 'poliitikaga')
# 1   ('globalistlik', 'võimueliit')
# 1   ('seotud', 'migratsiooni')
# 1   ('madalas', 'tööhõives')
# 1   ('kultuurilises', 'sobimatuses')
# 1   ('kristliku', 'maailma')
# 1   ('kaasnevates', 'probleemides')
# 1   ('vasakäärmuslike', 'tegelastega')
# 1   ('rahvuskonservatiivsete', 'jõudude')
# 1   ('kuritahtliku', 'immigratsioonipoliitika')
# 1   ('kriitilist', 'meelt')
# 1   ('õige', 'sõnaga')
# 1   ('haritud', 'spetsialistide')
# 1   ('immigratsioonivastane', 'valitsus')
# 1   ('suurema', 'arvu')
# 1   ('globaalses', 'rändepaktis')
# 1   ('demokraatliku', 'riigi')
# 1   ('olulisemaks', 'õiguseks')
# 1   ('poliitilisi', 'suunised')
# 1   ('vabad', 'käed')
# 1   ('ränga', 'šoki')
# 1   ('keelava', 'seaduse')
# 1   ('ühiskondlikku', 'autoriteeti')
# 1   ('kohalikelt', 'töö')
# 1   ('suurte', 'kompsudega')
# 1   ('paduislamistlikust', 'riigist')
# 1   ('venekeelsesse', 'töökeskkonda')
# 1   ('seaduslike', 'enesepiirangute')
# 1   ('kaugetest', 'kultuuridest')
# 1   ('järgmine', 'rändepakti')
# 1   ('realistlik', 'ohustsenaarium')
# 1   ('kaugest', 'kultuuriruumist')
# 1   ('tulevate', 'immigrantidega')
# 1   ('vastuoluline', 'isik')
# 1   ('skandaalse', 'rahvastehävitaja')
# 1   ('omaaegse', 'interrinde')
# 1   ('kalduvat', 'migrandirühma')
# 1   ('laiema', 'taustata')
# 1   ('jube', 'kriket')
# 1   ('selgeks', 'aluste')
# 1   ('juriidiline', 'staatus')
# 1   ('olulisemad', 'sammud')
# 1   ('siduvate', 'rahvahääletuste')
# 1   ('kindla', 'käega')
# 1   ('ähvardav', 'immigratsioon')
# 1   ('rahvuslik', 'kodumaa')
# 1   ('automaatse', 'tagasisaatmise')
# 1   ('kogu', 'härrassotside')
# 1   ('endine', 'siseminister')
# 1   ('lühikese', 'ajaga')
# 1   ('massilist', 'migratsiooni')
# 1   ('praegune', 'vasakvalitsus')
# 1   ('vastupidise', 'eesmärgiga')
# 1   ('võõrad', 'kombed')
# 1   ('olmelise', 'kaose')
# 1   ('majandusliku', 'pinge')
# 1   ('iseseisva', 'välispoliitika')
# 1   ('vajaminev', 'raha')
# 1   ('pidevate', 'kärbete')
# 1   ('elavatele', 'välismaalastele')
# 1   ('sätestatud', 'ülempiir')
# 1   ('tugev', 'rahvustunnetus')
# 1   ('negatiivse', 'varjundiga')
# 1   ('peamine', 'turvalisusrisk')
# 1   ('keerulisse', 'olukorda')
# 1   ('valguvate', 'moslemist')
# 1   ('juhtiva', 'erakonna')
# 1   ('suvise', 'kongressi')
# 1   ('järgsel', 'pressikonverentsil')
# 1   ('olulisem', 'probleem')
# 1   ('vähimatki', 'ainu')
# 1   ('globalistliku', 'ideoloogia')
# 1   ('suurimas', 'ohus')
# 1   ('illegaalne', 'immigratsioon')
# 1   ('kohalikud', 'inimesed')
# 1   ('mullused', 'rahutused')
# 1   ('35-aastase', 'sakslase')
# 1   ('konservatiivset', 'immigratsioonipoliitikat')
# 1   ('rahvusvahelise', 'rändekava')
# 1   ('püsivat', 'tööd')
# 1   ('seisvaid', 'väljakutseid')
# 1   ('ühiskondliku', 'sidususe')
# 1   ('võimas', 'tõusulaine')
# 1   ('agressiivsete', 'rünnakute')
# 1   ('kaasnevate', 'õuduste')
# 1   ('ühiskondlik', 'stabiilsus')
# 1   ('reaalseid', 'samme')
# 1   ('avastatud', 'põgenikelaevad')
# 1   ('nõukogudeaegse', 'venestamise')
# 1   ('sedasorti', 'jutt')
# 1   ('nimelisel', 'festivalil')
# 1   ('multikultuurne', 'linnaosa')
# 1   ('vastasel', 'korral')
# 1   ('illegaalne', 'migratsioon')
# 1   ('erinevaid', 'liikmesriike')
# 1   ('sarnastes', 'olukordades')
# 1   ('mõistuspäraste', 'lahenduste')
# 1   ('kohustuslikke', 'migratsioonikvoote')
# 1   ('multikultuurses', 'keskkonnas')
# 1   ('suur', 'immigratsioon')
# 1   ('mustanahaline', 'ingel')
# 1   ('riiklik', 'rahastus')
# 1   ('vabatahtlik', 'importimine')
# 1   ('pikk', 'praktika')
# 1   ('jõukas', 'ärimees')
# 1   ('suurt', 'asja')
# 1   ('akadeemilist', 'taset')
# 1   ('venekeelsesse', 'keskkonda')
# 1   ('tänased', 'viljad')
# 1   ('meestevihkajalik', 'feminism')
# 1   ('traditsioonilise', 'perekonna')
# 1   ('vaimse', 'küpsuse')
# 1   ('küsitava', 'väärtusega')
# 1   ('globalistlike', 'isandate')
# 1   ('vana', 'elu')
# 1   ('rikkad', 'naftamaad')
# 1   ('hea', 'meelega')
# 1   ('lähtuvast', 'rändesurvest')
# 1   ('tõsise', 'migrantide')
# 1   ('peamised', 'islamistide')
# 1   ('suunatud', 'kristluse')
# 1   ('hiljemasse', 'aega')
# 1   ('väldanud', 'rekonkista')
# 1   ('uuele', 'ringile')
# 1   ('puudutavad', 'töö-')
# 1   ('vasakliberaalses', 'ühiskonnas')
# 1   ('loodud', 'olukord')
# 1   ('pahatahtlik', 'viha')
# 1   ('eelmisel', 'nädalal')
# 1   ('karmi', 'pagulaspoliitikaga')
# 1   ('uus', 'märk')
# 1   ('piiramatul', 'hulgal')
# 1   ('täieliku', 'lahustamiseni')
# 1   ('võidukaid', 'vägesid')
# 1   ('kuulekateks', 'alamateks')
# 1   ('globalistliku', 'isikuga')
# 1   ('lihtsustatud', 'korras')
# 1   ('rahvusvahelisel', 'tasandil')
# 1   ('ostetud', 'asi')
# 1   ('kopsaka', 'valuraha')
# 1   ('grupiviisilise', 'vägistamise')
# 1   ('mõnekuulise', 'vanglakaristuse')
# 1   ('sealsete', 'julgeolekuekspertide')
# 1   ('kasvava', 'seksuaalkuritegevuse')
# 1   ('rassistlikke', 'eelarvamusi')
# 1   ('avaldatud', 'uudist')
# 1   ('teaduslike', 'aruteludeta')
# 1   ('lihtne', 'vahet')
# 1   ('liberaalne', 'eliit')
# 1   ('suur', 'vastasseis')
# 1   ('kohalikud', 'valimised')
# 1   ('geograafiliseks', 'mõisteks')
# 1   ('nimetatud', 'probleem')
# 1   ('permanentse', 'probleemiga')
# 1   ('edasine', 'jutt')
# 1   ('esitatud', 'kavadele')
# 1   ('massiline', 'sissetoomine')
# 1   ('suurel', 'määral')
# 1   ('avaldatud', 'arvamusküsitluse')
# 1   ('edastatud', 'info')
# 1   ('poolset', 'pagulaskvooti')
# 1   ('antavaid', 'toetusi')
# 1   ('sotsiaalsete', 'tagatiste')
# 1   ('seadusandliku', 'võimu')
# 1   ('edasine', 'koondumine')
# 1   ('tihedama', 'liidu')
# 1   ('ühtne', 'rahanduspoliitika')
# 1   ('korraliku', 'piirikontrolli')
# 1   ('terveid', 'elurajoone')
# 1   ('juhitud', 'välisministeerium')
# 1   ('liituvad', 'riigid')
# 1   ('minevatest', 'hiigelsummadest')
# 1   ('vasakliberaalses', 'massimeedias')
# 1   ('õnnetute', 'abistamine')
# 1   ('tormavaid', 'rändlejaid')
# 1   ('uusi', 'põhjuseid')
# 1   ('valgeid', 'rassistideks')
# 1   ('järgmise', 'katastroofini')
# 1   ('demograafilist', 'olukorda')
# 1   ('poliitkorrektne', 'it-mees')
# 1   ('luterliku', 'kiriku')
# 1   ('uued', 'tuuled')
# 1   ('vasakliberaalse', 'globalismi')
# 1   ('võitlevad', 'mõttepolitseinikud')
# 1   ('vasakliberaalsed', 'meediaraisakullid')
# 1   ('eileõhtune', 'postitus')
# 1   ('kahepalgeliste', 'silmakirjatsejatega')
# 1   ('möödunud', 'sajandil')
# 1   ('poliitilise', 'malakana')
# 1   ('tänasel', 'päeval')
# 1   ('tapetavatele', 'eurooplastele')
# 1   ('uut', 'paadiretke')
# 1   ('poliitilise', 'korrektsuse')
# 1   ('vasakpoolse', 'ideoloogia')
# 1   ('meeletu', 'reproduktiivsusega')
# 1   ('konservatiivsete', 'jõudude')
# 1   ('euroopalik', 'elanikkond')
# 1   ('jätkuv', 'rändekriis')
# 1   ('välise', 'ohuna')
# 1   ('suuremat', 'muret')
# 1   ('vasakliberaalne', 'meedia')
# 1   ('parempoolsete', 'maskide')
# 1   ('marksistlikud', 'liberaalid')
# 1   ('tohutu', 'põgenikearmee')
# 1   ('lähemas', 'tulevikus')
# 1   ('võõraste', 'kasuks')
# 1   ('sealne', 'liiklus')
# 1   ('pingelise', 'liiklusega')
# 1   ('globalismivastased', 'jõud')
# 1   ('mõtlevate', 'jõududega')
# 1   ('igakülgset', 'arutelu')
# 1   ('täieliku', 'peatamise')
# 1   ('rahvusvaheliste', 'abiorganisatsioonide')
# 1   ('odava', 'võõrtööjõu')
# 1   ('madalapalgaliseks', 'riigiks')
# 1   ('teemalisel', 'debatil')
# 1   ('kristlikke', 'sümboleid')
# 1   ('salliv', 'ühiskond')
# 1   ('samasooliste', 'abieluõigust')
# 1   ('käival', 'määral')
# 1   ('habras', 'tasakaal')
# 1   ('tõstvat', 'pead')
# 1   ('raskest', 'elust')
# 1   ('rääkiva', 'saate')
# 1   ('suitsulõhnalised', 'meeleavaldused')
# 1   ('sooviv', 'vasakliberaal')
# 1   ('ennastnautiva', 'kõne')
# 1   ('skandaalne', 'miljardär')
# 1   ('mõjukaid', 'internetikeskkondi')
# 1   ('totalitaarsete', 'jälgimisvõrgustike')
# 1   ('heas', 'vormis')
# 1   ('ammustest', 'aegadest')
# 1   ('kasvavat', 'migrandimassi')
# 1   ('negatiivse', 'narratiivi')
# 1   ('asustatud', 'piirkondadest')
# 1   ('arvukad', 'kogukonnad')
# 1   ('toitvaks', 'allikaks')
# 1   ('tervemõistusliku', 'järelduse')
# 1   ('kontrollimatu', 'immigratsioon')
# 1   ('positiivseid', 'reaktsioone')
# 1   ('võrreldaval', 'alpiriigil')
# 1   ('vasakliberaalne', 'ideoloogia')
# 1   ('sotsiaalsed', 'konstruktsioonid')
# 1   ('teaduslik', 'taust')
# 1   ('suuri', 'kottidega')
# 1   ('aktuaalne', 'kaamera')
# 1   ('uuest', 'õppeaastast')
# 1   ('rõhuvate', 'riikidega')
# 1   ('endistest', 'koloniaalmaadest')
# 1   ('tublit', 'inimest')
# 1   ('närustes', 'tingimustes')
# 1   ('kiire', 'lahkumise')
# 1   ('suure', 'loo')
# 1   ('suuremat', 'peavalu')
# 1   ('õõnestavale', 'tegevusele')
# 1   ('tulevale', 'islamile')
# 1   ('innovaatilise', 'riigi')
# 1   ('kallist', 'tehnoloogiat')
# 1   ('illegaalsed', 'põgenikud')
# 1   ('ideoloogilisi', 'multikultiplaane')
# 1   ('seotud', 'probleeme')
# 1   ('järgmisel', 'nädalal')
# 1   ('28-liikmelisse', 'ühendusse')
# 1   ('saabuva', 'põgenikevoolu')
# 1   ('poliitilise', 'areenile')
# 1   ('massiliseks', 'vastuvõtmiseks')
# 1   ('praeguse', 'süsteemi')
# 1   ('sedalaadi', 'eksperiment')
# 1   ('kogu', 'rändekriis')
# 1   ('repressiivsetest', 'meetmetest')
# 1   ('kogu', 'pakt')
# 1   ('salakavalat', 'immigratsioonipumpa')
# 1   ('säästva', 'arengu')
# 1   ('huvitav', 'nähtus')
# 1   ('ägedast', 'vastuseisust')
# 1   ('pika', 'plaaniga')
# 1   ('loputav', 'multikulti')
# 1   ('ohtliku', 'sisserände')
# 1   ('erapooletut', 'kompetentsi')
# 1   ('meeletute', 'pingete')
# 1   ('uue', 'politseiposti')
# 1   ('uute', 'kärbete')
# 1   ('riiklikule', 'julgeolekule')
# 1   ('suurt', 'ohtu')
# 1   ('kujutavate', 'välismaalaste')
# 1   ('suurema', 'koostöö')
# 1   ('rangemad', 'karistused')
# 1   ('juhitud', 'rahvusriikide')
# 1   ('karmile', 'migratsioonipoliitikale')
# 1   ('mängiv', 'populist')
# 1   ('kohtulikud', 'karistused')
# 1   ('toetava', 'meedia')
# 1   ('tõelist', 'antisemitismi')
# 1   ('esmaspäevases', 'usutluses')
# 1   ('teatud', 'separatism')
# 1   ('praeguses', 'olukorras')
# 1   ('suurest', 'võitlusest')
# 1   ('muudetud', 'kohustuseks')
# 1   ('ainsaks', 'kannatajaks')
# 1   ('uut', 'tööjõudu')
# 1   ('riiklik', 'tagasirändeagentuur')
# 1   ('lahutamatu', 'osa')
# 1   ('kultuurilist', 'kehandit')
# 1   ('rohkearvulise', 'moslemikogukonna')
# 1   ('soodustavaks', 'multikultimaaks')
# 1   ('paljulapseliste', 'migrandiperede')
# 1   ('kontrollimatu', 'migrantide')
# 1   ('täielik', 'hoolimatus')
# 1   ('võrdse', 'tööorjuse')
# 1   ('teaduslik', 'maailmavaade')
# 1   ('tugevad', 'neegrid')
# 1   ('tühine', 'lootus')
# 1   ('hallikaspruuni', 'globaliseeritud')
# 1   ('mustale', 'rassismile')
# 1   ('rassistlike', 'tunnusjoontega')
# 1   ('kuuma', 'liini')
# 1   ('illegaalsele', 'rändele')
# 1   ('kõnealune', 'juhtum')
# 1   ('paras', 'pähkel')
# 1   ('kohalikest', 'abistajatest')
# 1   ('fanaatilisemad', 'multikulti')
# 1   ('lubamatu', 'rassism')
# 1   ('koostatud', 'uuringust')
# 1   ('kohalikus', 'restoranis')
# 1   ('kogu', 'maailmast')
# 1   ('laiem', 'pilt')
# 1   ('lõppematu', 'süükompleksi')
# 1   ('seotud', 'häbi')
# 1   ('terve', 'linnatäie')
# 1   ('suures', 'kirjas')
# 1   ('liberaalse', 'ideoloogia')
# 1   ('kohustuslikuks', 'muutmise')
# 1   ('süstemaatiline', 'rahvusriikide')
# 1   ('pakutav', 'summa')
# 1   ('erilise', 'töökuse')
# 1   ('erilist', 'pistmist')
# 1   ('uusi', 'migrante')
# 1   ('elavat', 'fantaasiat')
# 1   ('ohtlikku', 'elementi')
# 1   ('paremäärmuslikust', 'protestiparteist')
# 1   ('poliitilise', 'liikumise')
# 1   ('valitud', 'esindajaid')
# 1   ('uut', 'piirangute')
# 1   ('algelised', 'fraasid')
# 1   ('homoseksuaalsest-multikultuursest', 'õnnest')
# 1   ('lugupeetud', 'inimesed')
# 1   ('efektiivsest', 'immigratsioonipumbast')
# 1   ('ilmselget', 'ebakompetentsust')
# 1   ('arvukatest', 'eranditest')
# 1   ('tülikad', 'sisserändajad')
# 1   ('tõendava', 'pildi')
# 1   ('positiivse', 'näitaja')
# 1   ('massilist', 'immigratsiooni')
# 1   ('potentsiaalsetele', 'riiki')
# 1   ('rahvuslikus', 'kultuuriruumis')
# 1   ('kremli-meelsed', 'globalistid')
# 1   ('suurte', 'sotsiaaltoetustega')
# 1   ('omal', 'kulul')
# 1   ('objektiivsetel', 'faktidel')
# 1   ('moraalsetel', 'põhimõtetel')
# 1   ('poliitilise', 'võimu')
# 1   ('kultuurilise', 'allakäigu')
# 1   ('rekordkõrge', 'sisserände')
# 1   ('hiiglaslikke', 'kasumeid')
# 1   ('umbkeelsed', 'välismaalased')
# 1   ('inetul', 'moel')
# 1   ('ainus', 'koht')
# 1   ('feministlik', 'naisõiguslus')
# 1   ('liberaalne', 'kultuuriruum')
# 1   ('viimase', 'aja')
# 1   ('maailmakaubandusalaseid', 'läbirääkimisi')
# 1   ('vasakpoolsete', 'keskkonna-')
# 1   ('antifa-sarnased', 'äärmusorganisatsioonid')
# 1   ('kõvade', 'sotsiaalprobleemide')
# 1   ('keskendunud', 'multikultuursuse')
# 1   ('traditsioonilise', 'pere')
# 1   ('kriminaalsed', 'immigrandid')
# 1   ('suure', 'probleemi')
# 1   ('tänane', 'ajakirjandus')
# 1   ('konkreetsele', 'isikule')
# 1   ('sarnaseid', 'kahtlustusi')
# 1   ('esitatud', 'migratsiooni')
# 1   ('toetavate', 'aktivistide')
# 1   ('sarnast', 'taktikat')
# 1   ('vigaseid', 'kaarte')
# 1   ('pealesurutav', 'moslemite')
# 1   ('suurele', 'pinnale')
# 1   ('globalistliku', 'maailma')
# 1   ('suurima', 'vaenlase')
# 1   ('heakskiitvate', 'otsustega')
# 1   ('lõppenud', 'pussitamises')
# 1   ('eelmisel', 'aastal')
# 1   ('rassistliku', 'tänavavägivalla')
# 1   ('vägivaldsete', 'kuritegude')
# 1   ('illegaalsed', 'immigrandid')
# 1   ('kuuluv', 'alus')
# 1   ('eilse', 'vao')
# 1   ('föderaalse', 'julgeolekuteenistuse')
# 1   ('terroristliku', 'ideoloogia')
# 1   ('kontrollivate', 'ametnike')
# 1   ('25-aastaseid', 'mehi')
# 1   ('kopsaka', 'summa')
# 1   ('mõõdukas', 'moslem')
# 1   ('euroopalikke', 'väärtusi')
# 1   ('sooneutraalseid', 'olevusi')
# 1   ('ülinapis', 'nahkriietuses')
# 1   ('lahtised', 'piirid')
# 1   ('viimastel', 'parlamendivalimistel')
# 1   ('konservatiivse', 'rahvaerakonna')
# 1   ('värviliste', 'isikute')
# 1   ('laiad', 'rahvahulgad')
# 1   ('massilist', 'sisselubamist')
# 1   ('valitseva', 'eliidi')
# 1   ('ehtsas', 'rahvusriigis')
# 1   ('ümbritsevast', 'keskkonnastglobalist')
# 1   ('ühiskondlikus', 'elus')
# 1   ('mõistlik', 'mõte')
# 1   ('jõukas', 'elu')
# 1   ('paratamatu', 'kaasnähtus')
# 1   ('absoluutne', 'enamus')
# 1   ('vajalik', 'välistööjõud')
# 1   ('tehnoloogilist', 'arengut')
# 1   ('külma', 'sõja')
# 1   ('radikaalse', 'islamiterrori')
# 1   ('karmiks', 'sisserände')
# 1   ('ideoloogiline', 'test')
# 1   ('keskaegsed', 'tavad')
# 1   ('teravaid', 'konflikte')
# 1   ('jõhkras', 'mõrvas')
# 1   ('hiljutises', 'arvamusloos')
# 1   ('sugused', 'tegelased')
# 1   ('varastavate', 'pagulastega')
# 1   ('lihtne', 'arusaamatus')
# 1   ('karmi', 'vägivallaga')
# 1   ('süvenevast', 'solvumiskultuurist')
# 1   ('negatiivset', 'väljendist')
# 1   ('täies', 'elujõus')
# 1   ('pika', 'aja')
# 1   ('kiiremas', 'korras')
# 1   ('ühiskondlikud', 'suhted')
# 1   ('uus', 'eliit')
# 1   ('valitud', 'vabariiklane')
# 1   ('illegaalset', 'immigranti')
# 1   ('sotsiaalliberaalne', 'valitsusliit')
# 1   ('sunduslik', 'vastuvõtt')
# 1   ('hea', 'sõnaga')
# 1   ('olevat', 'eeskuju')
# 1   ('sõjaväelised', 'struktuurid')
# 1   ('elektroonilise', 'varustusega')
# 1   ('migrandipaatide', 'rahva')
# 1   ('oluline', 'saavutus')
# 1   ('allaheitliku', 'immigratsioonipoliitika')
# 1   ('kontrollitav', 'rahvaste')
# 1   ('ohtrate', 'pervesrssustega')
# 1   ('elav', 'süürlane')
# 1   ('elav', 'nigeerlane')
# 1   ('elavatele', 'migrantidele')
# 1   ('ülbetele', 'neegritele')
# 1   ('paljukannatanud', 'rahva')
# 1   ('eri', 'kodukeelte')
# 1   ('liitva', 'kooli')
# 1   ('suur', 'väljakutse')
# 1   ('kogu', 'dokument')
# 1   ('koostatud', 'kantseliidis')
# 1   ('positiivseid', 'arenguid')
# 1   ('suurema', 'kõnelejate')
# 1   ('väikese', 'rahvaarvu')
# 1   ('ehtne', 'piraatlus')
# 1   ('suuri', 'rahasid')
# 1   ('elavate', 'migrantide')
# 1   ('väikese', 'arvukusega')
# 1   ('suurim', 'mure')
# 1   ('võimaliku', 'rändekriisi')
# 1   ('südantlõhestavaid', 'lugusid')
# 1   ('õnnetutest', 'migrantidest')
# 1   ('rahvusvahelise', 'inimkaubanduse')
# 1   ('hullem', 'alternatiiv')
# 1   ('ilkuvatesse', 'liberaalidesse')
# 1   ('lärmakate', 'vähemuste')
# 1   ('tarbetuid', 'sooideoloogiaid')
# 1   ('pluralistlikus', 'ühiskonnas')
# 1   ('renegaatlik', 'kamp')
# 1   ('hoidev', 'maarahvas')
# 1   ('sallivad', 'multikultuurlased')
# 1   ('liberaalne', 'migratsioonipoliitika')
# 1   ('hävitav', 'põlisrahvaste')
# 1   ('jabura', 'loogika')
# 1   ('ebatarviliku', 'õiguse')
# 1   ('kohaliku', 'politseivormiga')
# 1   ('võrdväärne', 'liige')
# 1   ('sõjalised', 'liitlased')
# 1   ('parempoolsed', 'opositsioonierakonnad')
# 1   ('avatud', 'asüülipoliitikat')
# 1   ('illegaalse', 'immigratsioonivoo')
# 1   ('täidesaatva', 'korralduse')
# 1   ('siinsesse', 'tänavapilti')
# 1   ('ilmunud', 'võõrad')
# 1   ('väheesindusliku', 'olemusega')
# 1   ('nüüdseks', 'mõistusele')
# 1   ('uue', 'rändetee')
# 1   ('valge', 'sõnul')
# 1   ('avantüristlik', 'immigratsiooni')
# 1   ('teisejärguliseks', 'pisendamine')
# 1   ('poliitilise', 'migratsiooni')
# 1   ('ühtse', 'tegevuse')
# 1   ('meeleheitlikust', 'soovist')
# 1   ('senisele', 'sisserändepoliitikale')
# 1   ('kohalike', 'sotsiaalsüsteemide')
# 1   ('pretensioonikad', 'loodrid')
# 1   ('riiklikku', 'süsteemi')
# 1   ('suurim', 'probleem')
# 1   ('külalislahkemate', 'eurooplaste')
# 1   ('vastast', 'vägivalda')
# 1   ('idapoolsetest', 'riikidest')
# 1   ('illegaalsest', 'rändest')
# 1   ('demograafiline', 'kriis')
# 1   ('suur', 'sündimus')
# 1   ('schengeni-ülese', 'peatamisklausli')
# 1   ('kohene', 'kehtestamine')
# 1   ('parim', 'viis')
# 1   ('traditsiooniliste', 'väärtuste')
# 1   ('suunatud', 'globalismi')
# 1   ('ebaõige', 'käsitlus')
# 1   ('heade', 'inimeste')
# 1   ('meeletu', 'hulk')
# 1   ('kogu', 'heategevuse')
# 1   ('kohalik', 'rahvas')
# 1   ('uus', 'video')
# 1   ('suuremat', 'pilti')
# 1   ('täiskasvanud', 'inimesed')
# 1   ('täielikud', 'globalistid')
# 1   ('multikultuurseks', 'muutmisel')
# 1   ('ainsaks', 'võimaluseks')
# 1   ('poliitiline', 'integratsioon')
# 1   ('kõrgete', 'esindajate')
# 1   ('algatatud', 'plaani')
# 1   ('hea', 'meel')
# 1   ('hull', 'asi')
# 1   ('senise', 'elu')
# 1   ('täielikku', 'muutmist')
# 1   ('vägistamisohtlikud', 'getod')
# 1   ('uusi', 'moslemi-immigrante')
# 1   ('venekeelset', 'intervjuud')
# 1   ('illegaalset', 'immigratsiooni')
# 1   ('ohtlikum', 'naaber')
# 1   ('juurtetud', 'välismaalased')
# 1   ('väidetav', 'poliitpõgenik')
# 1   ('püha', 'keskme')
# 1   ('võõra', 'õue')
# 1   ('kohustuslik', 'poliitkorrektsus')
# 1   ('tituleeritud', 'vasakäärmuslaste')
# 1   ('uus', 'rändemarsruut')
# 1   ('võiduka', 'erakonna')
# 1   ('iga-aastasel', 'suurkogu')
# 1   ('üleeuroopalist', 'liitu')
# 1   ('vabu', 'liikumisi')
# 1   ('kohalik', 'meedia')
# 1   ('tulvavat', 'põgenikevoolu')
# 1   ('massilise', 'seadusetuseni')
# 1   ('tänast', 'immigratsioonipoliitikat')
# 1   ('sealsed', 'sisserännanute')
# 1   ('kuritegelike', 'jõukude')
# 1   ('omavaheliste', 'arveteklaarimistega')
# 1   ('kriminaalsete', 'organisatsioonidega')
# 1   ('elav', 'hindu')
# 1   ('korraldatav', 'võimu')
# 1   ('massilise', 'ehitamise')
# 1   ('pidev', 'suurenemine')
# 1   ('heast-paremat', 'ilma')
# 1   ('õigeid', 'momente')
# 1   ('ilusa', 'jutu')
# 1   ('peidetud', 'lõksudest')
# 1   ('vihasele', 'venelasele')
# 1   ('väidetavat', 'plaani')
# 1   ('suurte', 'raskuste')
# 1   ('füüsiline', 'kaitse')
# 1   ('näiline', 'jõukus')
# 1   ('võõraste', 'vastuvõtmine')
# 1   ('majanduslikel', 'kaalutlustel')
# 1   ('rohelise', 'tee')
# 1   ('põhineva', 'ühiskonna')
# 1   ('kodanikupõhist', 'riiki')
# 1   ('tänapäevastes', 'neegrite')
# 1   ('rahumeelseid', 'kodanikke')
# 1   ('redigeerimata', 'ülekandmine')
# 1   ('eestikeelsetesse', 'uudistesse')
# 1   ('viimasena', 'mägedes')
# 1   ('vanema', 'marokolasega')
# 1   ('viimane', 'variant')
# 1   ('tellitud', 'uuring')
# 1   ('suureks', 'tööjõu')
# 1   ('puhtas', 'maakeeles')
# 1   ('pooldavate', 'ettepanekute')
# 1   ('sõlmitud', 'kokkuleppest')
# 1   ('madalamad', 'palgad')
# 1   ('erinevatel', 'andmetel')
# 1   ('õige', 'nimega')
# 1   ('ilmselge', 'inimkaubandusega')
# 1   ('tohutuid', 'summasid')
# 1   ('põhiliseks', 'sihtpunktiks')
# 1   ('zimbabvelastest', 'põgenikke')
# 1   ('konservatiivsetest', 'erakondadest')
# 1   ('riikideülest', 'koostööd')
# 1   ('massilisele', 'moslemitest')
# 1   ('terved', 'linnaosad')
# 1   ('immigratsioonivastaste', 'jõududega')
# 1   ('suveräänsete', 'rahvusriikide')
# 1   ('kristlikku', 'kultuuri')
# 1   ('valdav', 'enamik')
# 1   ('suveräänse', 'poliitika')
# 1   ('lõpliku', 'föderaliseerimise')
# 1   ('multikultuurse', 'keskkonna')
# 1   ('toimuva', 'rahvastiku')
# 1   ('anonüümsemale', 'kivimaastikule')
# 1   ('positiivse', 'kuvandi')
# 1   ('töötavate', 'inimeste')
# 1   ('kohutavaid', 'teateid')
# 1   ('tõsisesse', 'ohtu')
# 1   ('saabunud', 'ukrainlane')
# 1   ('vähene', 'raha')
# 1   ('mittetootvatele', 'pagulastele')
# 1   ('seotud', 'arengumaadest')
# 1   ('kohustusliku', 'ümberjagamisprogrammiga')
# 1   ('sotsiaalset', 'katastroofi')
# 1   ('valitseva', 'partei')
# 1   ('suured', 'rahutused')
# 1   ('lahedam', 'mees')
# 1   ('ägedam', 'kutt')
# 1   ('uues', 'asupaigas')
# 1   ('algatatud', 'allkirjade')
# 1   ('hämarates', 'telgitagustes')
# 1   ('tohutud', 'rahad')
# 1   ('suure', 'migrantide')
# 1   ('valdav', 'enamus')
# 1   ('juhtivaid', 'vabariiklastest')
# 1   ('vokaalseim', 'toetaja')
# 1   ('tühiseid', 'karistusi')
# 1   ('ilmunud', 'artiklis')
# 1   ('heategevuslike', 'fondide')
# 1   ('kehvast', 'olukorrast')
# 1   ('kasvavast', 'mõjust')
# 1   ('riiklikul', 'tasemel')
# 1   ('aetav', 'poliitika')
# 1   ('kallis', 'neeger')
# 1   ('vastikus', 'pagulaskeeles')
# 1   ('nimetatud', 'terminiga')
# 1   ('sotsiaalse', 'turvalisuse')
# 1   ('väiksem', 'summa')
# 1   ('eelmise', 'valitsuse')
# 1   ('keskaegses', 'vägivallakultuses')
# 1   ('noorest', 'neegrist')
# 1   ('parempoolne', 'valitsus')
# 1   ('suuremaks', 'ohuks')
# 1   ('status', 'quo’le')
# 1   ('muretu', 'elu')
# 1   ('arvukad', 'sisserändajad')
# 1   ('tõkestav', 'tegevus')
# 1   ('tegelik', 'viis')
# 1   ('nihkuvat', 'islamiterrorit')
# 1   ('töötatud', 'kodakondsuse')
# 1   ('rahvusvahelise', 'kaitse')
# 1   ('konservatiivne', 'valitsus')
# 1   ('tehtud', 'postituses')
# 1   ('üle-euroopalist', 'allkirjade')
# 1   ('valge', 'rass')
# 1   ('suuri', 'raskusi')
# 1   ('pakutud', 'migrandikorje')
# 1   ('eelmisel', 'pühapäeval')
# 1   ('endistele', 'sotsialismimaadele')
# 1   ('võõraste', 'immigrantide')
# 1   ('sunduslik', 'vastuvõtmine')
# 1   ('kontrollimatu', 'saabumine')
# 1   ('sarnane', 'massiimmigratsiooniga')
# 1   ('mesimagusa', 'elu')
# 1   ('massilise', 'islamikogukonna')
# 1   ('vasakäärmuslike', 'ühendustega')
# 1   ('omatehtud', 'leegiheitjatega')
# 1   ('kõrgete', 'tarade')
# 1   ('vastuvõtnud', 'rahva')
# 1   ('kogu', 'maailmalt')
# 1   ('põhiseadusliku', 'korra')
# 1   ('rahvusvaheline', 'lepe')
# 1   ('ülemaailmsete', 'probleemide')
# 1   ('rahvuslikku', 'enesemääramisõigust')
# 1   ('ohustava', 'globaliseerumise')
# 1   ('parempopulistliku', 'rahvusrinde')
# 1   ('saabuvate', 'migrantide')
# 1   ('halvad', 'tagajärjed')
# 1   ('täitva', 'reformierakondlasest')
# 1   ('eestikeelsest', 'haridusest')
# 1   ('täiendav', 'loovutamine')
# 1   ('liberaalse', 'tsensuuri')
# 1   ('riiklikuks', 'poliitikaks')
# 1   ('üleeuroopalise', 'immigratsioonipoliitika')
# 1   ('uute', 'majandust')
# 1   ('tegevate', 'maksude')
# 1   ('välismaisele', 'odavtööjõule')
# 1   ('globalistlik', 'agenda')
# 1   ('ränki', 'kuritegusid')
# 1   ('riknev', 'pagulaspoliitika')
# 1   ('suurepäraseks', 'vahendiks')
# 1   ('liberaalses', 'leeris')
# 1   ('kunagise', 'orjakaubanduse')
# 1   ('tänases', 'maailmas')
# 1   ('agressiivne', 'kogukond')
# 1   ('poliitkorrektse', 'migratsiooni')
# 1   ('suur', 'viga')
# 1   ('suuremat', 'kasu')
# 1   ('seotud', 'inimesi')
# 1   ('välismaalastevastaste', 'rünnakutega')
# 1   ('suur', 'osa')
# 1   ('kulgevat', 'marsruuti')
# 1   ('majanduslikus', 'mõttes')
# 1   ('välispoliitilise', 'kursi')
# 1   ('iseseisvamat', 'poliitikat')
# 1   ('potentsiaalsete', 'migrantide')
# 1   ('piiramatu', 'jätkumisega')
# 1   ('piiramatu', 'massiimmigratsiooniga')
# 1   ('drastilised', 'muutused')
# 1   ('peamine', 'eesmärk')
# 1   ('suurem', 'pahalane')
# 1   ('multikultuurne', 'president')
# 1   ('internatsionaalne', 'partei')
# 1   ('kogu', 'elu')
# 1   ('immigratsioonivastase', 'jõu')
# 1   ('toimuvaid', 'protsesse')
# 1   ('aastatepikkuse', 'multikulti-propaganda')
# 1   ('kohustuslikus', 'korras')
# 1   ('olevad', 'eestlased')
# 1   ('kristliku', 'kultuuritaustaga')
# 1   ('mustad', 'aafriklased')
# 1   ('kitsarinnaline', 'rassism')
# 1   ('repressiivsest', 'iseloomust')
# 1   ('ülepääsenud', 'laagritesse')
# 1   ('suuremaks', 'koormaks')
# 1   ('täies', 'tööjõus')
# 1   ('noort', 'neegrit')
# 1   ('ausa', 'tööga')
# 1   ('progressiivses', 'maailmas')
# 1   ('tuntud', 'kriminaaliga')
# 1   ('täpsem', 'ülevaade')
# 1   ('terve', 'rea')
# 1   ('sõjalisi', 'avantüüre')
# 1   ('siinsed', 'tuhatkond')
# 1   ('katastroofilise', 'vea')
# 1   ('eiravad', 'immigrandid')
# 1   ('sisemise', 'turvatunde')
# 1   ('mustanahaline', 'eestlane')
# 1   ('kohalikud', 'venelased')
# 1   ('mõistlikud', 'poliitikud')
# 1   ('suured', 'araablaste')
# 1   ('vältimatu', 'eelduse')
# 1   ('peatse', 'kaose')
# 1   ('pidurdav', 'impulss')
# 1   ('kaasnevale', 'islamiterrorismile')
# 1   ('tuntud', 'sisserändetaustaga')
# 1   ('puudutavates', 'välismaalaste')
# 1   ('kõrge', 'sisserände')
# 1   ('ebademokraatlikku', 'valitsust')
# 1   ('olulisi', 'migratsiooni')
# 1   ('piiravaid', 'seadusi')
# 1   ('ametlikest', 'kanalitest')
# 1   ('riiklikust', 'jaotussüsteemist')
# 1   ('seotud', 'hirme')
# 1   ('migratsioonivastane', 'kodanikuühendus')
# 1   ('tugevnev', 'immigratsioonisurve')
# 1   ('kiire', 'vananemine')
# 1   ('meeletu', 'surve')
# 1   ('ümberjaotatavad', 'sotsiaalabi')
# 1   ('kõrge', 'maksukoormusega')
# 1   ('vaene', 'maa')
# 1   ('jõuka', 'elu')
# 1   ('mustanahalisel', 'migrandil')
# 1   ('seksuaalne', 'ahistamine')
# 1   ('iseseisva', 'rahvusriigina')
# 1   ('valge', 'mees')
# 1   ('nõutavat', 'ühisvastutust')
# 1   ('adekvaatse', 'valmisoleku')
# 1   ('kõikvõimalike', 'inimkaubitsejate')
# 1   ('rahvusreeturlikud', 'ettevõtjad')
# 1   ('asustatud', 'piirkondades')
# 1   ('iseloomulik', 'kividega')
# 1   ('igavesest', 'õnnest')
# 1   ('moslemiusulise', 'uiguuri')
# 1   ('uusi', 'immigrante')
# 1   ('lõtva', 'immigratsioonipoliitikat')
# 1   ('kohalikele', 'kohustuseks')
# 1   ('kohustuslikku', 'õppimist')
# 1   ('rahvusvahelises', 'keeles')
# 1   ('kohalike', 'protest')
# 1   ('lubatud', 'aja')
# 1   ('multikultuurne', 'europrovints')
# 1   ('multikultuurset', 'ühiksonda')
# 1   ('suur', 'kasv')
# 1   ('tehtud', 'kokkulepe')
# 1   ('saadetud', 'migrandi')
# 1   ('eelmisel', 'reedel')
# 1   ('endine', 'välisminister')
# 1   ('praegune', 'ksenofoob')
# 1   ('pealesurutavad', 'pagulaskvoodid')
# 1   ('kavandatavad', 'trahvid')
# 1   ('globalistlikuks', 'rahvaste')
# 1   ('uusi', 'pagulasi')
# 1   ('vastavaid', 'kohustusi')
# 1   ('rahvusvahelise', 'rändeorganisatsiooni')
# 1   ('tänavuse', 'aasta')
# 1   ('ohvriterohkeima', 'kuu')
# 1   ('rahvuslikku', 'identiteediliikumist')
# 1   ('süvenev', 'kaos')
# 1   ('massilise', 'immigrantide')
# 1   ('puhkenud', 'kaklusi')
# 1   ('17-aastane', 'paadipõgenik')
# 1   ('tänase', 'seisuga')
# 1   ('vandaalitsevate', 'noortekampadega')
# 1   ('kogu', 'ühiskonda')
# 1   ('tühjaksvarastatud', 'poodide')
# 1   ('sõbralikke', 'türklasi')
# 1   ('massiimmigratsioonivastasele', 'meeleavaldusele')
# 1   ('tänased', 'migrandid')
# 1   ('hästiriietatud', 'migrandid')
# 1   ('kohutavad', 'tagajärjed')
# 1   ('noored', 'kord')
# 1   ('paduusklikke', 'moslemeid')
# 1   ('tõsise', 'religiooniga')
# 1   ('kasvav', 'populaarsus')
# 1   ('homogeense', 'uuskogukonna')
# 1   ('põhinev', 'migrandikogukond')
# 1   ('märkimisväärset', 'kahju')
# 1   ('tehnoloogilist', 'mahajäämust')
# 1   ('kontrollimatu', 'immigratsioonilaine')
# 1   ('taoliste', 'neegrikampaaniatega')
# 1   ('kurjade', 'migrantide')
# 1   ('otsatute', 'hordidega')
# 1   ('sõjalist', 'allakäimist')
# 1   ('rumala', 'migratsioonipoliitikaga')
# 1   ('rändevastane', 'petitsioon')
# 1   ('illegaalse', 'migratsioonisurve')
# 1   ('hääletu', 'alistumine')
# 1   ('euroopalikku', 'ühiskonda')
# 1   ('odava', 'orjatööjõu')
# 1   ('suur', 'moslemikogukond')
# 1   ('lähedalasuval', 'mošeel')
# 1   ('kurikuulus', 'maine')
# 1   ('rahalist', 'toetust')
# 1   ('positiivset', 'vastust')
# 1   ('multikultuurses', 'ühiskonnas')
# 1   ('surnud', 'lapspõgenikud')
# 1   ('rassistlikke', 'solvanguid')
# 1   ('pretensioonikad', 'aafriklased')
# 1   ('peamisest', 'rändeteest')
# 1   ('legaalsed', 'immigrandid')
# 1   ('noorele', 'ameeriklasele')
# 1   ('vajuv', 'maa')
# 1   ('pruunide', 'kehade')
# 1   ('venekeelse', 'ruumi')
# 1   ('eestikeskse', 'ruumi')
# 1   ('põhilise', 'valijaskonna')
# 1   ('globalistlik-ateistliku', 'koorekihi')
# 1   ('mõtleva', 'poliitikute')
# 1   ('põhilistest', 'ettepanekutest')
# 1   ('keskmise', 'palgaga')
# 1   ('rõhuvatest', 'maadest')
# 1   ('laieneva', 'narkoäriga')
# 1   ('algatatud', 'eestlase')
# 1   ('illegaalse', 'migratsiooniga')
# 1   ('usinateks', 'liitlasteks')
# 1   ('suurimad', 'vihkajad')
# 1   ('käivat', 'immigrantide')
# 1   ('soositud', 'inimkaubandus')
# 1   ('hoiatavaid', 'tegureid')
# 1   ('hukkunud', 'ukrainlastest')
# 1   ('sotsiaalsed', 'garantiid')
# 1   ('ohtlik', 'seltskond')
# 1   ('kontrollimatule', 'voole')
# 1   ('kultuuriline', 'enesesalgamine')
# 1   ('kinkiv', 'kaljulaid')
# 1   ('külma', 'kliimasse')
# 1   ('troopilise', 'kodumaa')
# 1   ('võõraste', 'saareks')
# 1   ('tuntud', 'massimõrvarite')
# 1   ('tohutute', 'probleemide')
# 1   ('eksitavaks', 'plaani')
# 1   ('noore', 'itaallanna')
# 1   ('etnilisest', 'grupist')
# 1   ('globalistlik', 'ühikas')
# 1   ('venekeelne', 'keskkond')
# 1   ('ohustavaks', 'protsessiks')
# 1   ('toimuv', 'mitte-eestlaste')
# 1   ('siinse', 'välispäritolu')
# 1   ('kuritegelikust', 'praktikast')
# 1   ('saadetud', 'teates')
# 1   ('suure', 'hulga')
# 1   ('suurte', 'migrandikogukondade')
# 1   ('ühiskondlik', 'vastutustunne')
# 1   ('valulikku', 'kogemust')
# 1   ('välditavate', 'surmadeni')
# 1   ('tervele', 'reale')
# 1   ('väidetavatele', 'inimõigusrikkumistele')
# 1   ('globalistliku', 'poliitika')
# 1   ('parempoolsete', 'süü')
# 1   ('olevat', 'pagulasi')
# 1   ('naistevastane', 'vägivald')
# 1   ('suuremaks', 'süüks')
# 1   ('kahjulikku', 'rändelepet')
# 1   ('massiline', 'migratsioon')
# 1   ('järgnev', 'uudist')
# 1   ('ebaloomulik', 'nähtus')
# 1   ('omavate', 'inimestest')
# 1   ('etteulatuv', 'tolerantsus')
# 1   ('järelulatuv', 'andestus')
# 1   ('revolutsioonilistele', 'sotsidele')
# 1   ('vajalikuks', 'eestlasi')
# 1   ('rohelise', 'tule')
# 1   ('vastastes', 'ringkondades')
# 1   ('antud', 'intervjuus')
# 1   ('avalik', 'arvamus')
# 1   ('kogutud', 'allkirjad')
# 1   ('möödunud', 'nädalal')
# 1   ('rangem', 'julgeolekukontroll')
# 1   ('suurema', 'ohutasemega')
# 1   ('seotud', 'pagulastega')
# 1   ('varjamata', 'rassism')
# 1   ('ühise', 'rindena')
# 1   ('jätkuva', 'tsentraliseerimise')
# 1   ('erakorralisel', 'istungil')
# 1   ('alanud', 'ehitustööd')
# 1   ('juhitud', 'veokeid')
# 1   ('potentsiaalseks', 'massiimmigratsiooniks')
# 1   ('ebaseaduslikku', 'migratsiooni')
# 1   ('valge', 'rahvastik')
# 1   ('avalikus', 'ruumis')
# 1   ('tohutu', 'surve')
# 1   ('plahvatusliku', 'kasvu')
# 1   ('arvestatav', 'osa')
# 1   ('mitmekultuurilise', 'diasporaa')
# 1   ('immigratsioonivastane', 'partei')
# 1   ('rahvusvahelise', 'pahameeletormi')
# 1   ('kasutavaid', 'gaasipihusteid')
# 1   ('viimastel', 'nädalatel')
# 1   ('hiljutist', 'uudist')
# 1   ('riiklik', 'poliitika')
# 1   ('maapealset', 'põrgut')
# 1   ('inimsusevastane', 'kuritegu')
# 1   ('rahvusvaheline', 'kohus')
# 1   ('multikultuurse', 'biomassiga')
# 1   ('ülima', 'intensiivsusega')
# 1   ('globalistliku', 'suunitlusega')
# 1   ('orienteeritud', 'monstrumiks')
# 1   ('demokraatlikke', 'väärtusi')
# 1   ('jalutava', 'filmija')
# 1   ('kogenud', 'lääne')
# 1   ('hukatuslikku', 'globalismikurssi')
# 1   ('normaalse', 'elu')
# 1   ('otsene', 'käteväänamine')
# 1   ('salafistlikel', 'liikumistel')
# 1   ('naiivse', 'suhtumise')
# 1   ('kurikuulsamaid', 'juhtumeid')
# 1   ('võõramaised', 'töölised')
# 1   ('rassistlikest', 'eelarvamustest')
# 1   ('isikuvastaseid', 'kuritegusid')
# 1   ('sealne', 'rahvas')
# 1   ('minevate', 'kodusõdade')
# 1   ('liikuva', 'migrandikaravaniga')
# 1   ('sealsegi', 'heaoluühiskonna')
# 1   ('illegaalse', 'rände')
# 1   ('jahtivad', 'immigrandid')
# 1   ('ohtlikke', 'immigratsiooniseadusi')
# 1   ('ebaseaduslike', 'sisserändajate')
# 1   ('negatiivsed', 'mõjud')
# 1   ('massilise', 'kuritegevuse')
# 1   ('võimas', 'hoiatussignaal')
# 1   ('pettunud', 'eurooplasi')
# 1   ('estofoobse', 'homofiilia')
# 1   ('rikastava', 'mitmekesisusena')
# 1   ('venekeelseid', 'lasteaia-')
# 1   ('alalist', 'siinelamist')
# 1   ('venekeelne', 'kogukond')
# 1   ('kodumaisest', 'venevastasusest')
# 1   ('lööva', 'rassismi')
# 1   ('toimepandud', 'terroriaktid')
# 1   ('uusi', 'vihagruppe')
# 1   ('üldist', 'vihkamist')
# 1   ('euroopalikku', 'keskkonda')
# 1   ('potentsiaalseks', 'ohuks')
# 1   ('kergemaks', 'islami')
# 1   ('eelseisvateks', 'aastakümneteks')
# 1   ('priviligeeritud', 'elanikkonnakiht')
# 1   ('sealseid', 'seadusi')
# 1   ('potentsiaalsed', 'terroristid')
# 1   ('eelmise', 'aastaga')
# 1   ('pikemaks', 'ajaks')
# 1   ('negatiivne', 'tähendus')
# 1   ('sooneutraalsed', 'liiklusmärgid')
# 1   ('varjatud', 'keelu')
# 1   ('valged', 'rassistid')
# 1   ('möödunud', 'aastal')
# 1   ('tugeva', 'perekonna')
# 1   ('arutu', 'vabadus')
# 1   ('põhjendamatuid', 'avaldusi')
# 1   ('räige', 'islami')
# 1   ('loodud', 'portaal')
# 1   ('põhinev', 'kuritegevus')
# 1   ('kogu', 'riigisüsteem')
# 1   ('islamoobiavastase', 'võitluse')
# 1   ('uueks', 'normaalsuseks')
# 1   ('tervele', 'riigile')
# 1   ('ülerahvastatud', 'alus')
# 1   ('kinnised', 'piirid')
# 1   ('tõhusam', 'viis')
# 1   ('allaheitlikku', 'poliitikat')
# 1   ('poputavat', 'heatahtlikkust')
# 1   ('rassistliku', 'käitumise')
# 1   ('konservatiivne', 'ujumisriietus')
# 1   ('traditsioonilised', 'ühiskonnad')
# 1   ('ajaloolised', 'kooslused')
# 1   ('olevat', 'pead')
# 1   ('edasisele', 'integratsioonile')
# 1   ('tehtud', 'uuringust')
# 1   ('suurimad', 'erinevused')
# 1   ('etnilise', 'rühma')
# 1   ('uues', 'valitsuses')
# 1   ('paremad', 'tingimused')
# 1   ('ultraliberaalset', 'asüülipoliitikat')
# 1   ('võimsaid', 'sotsiaaltoetusi')
# 1   ('suurt', 'sissevoolu')
# 1   ('kaasnevaid', 'terroriprobleeme')
# 1   ('soodsaid', 'olusid')
# 1   ('üldine', 'suhtumine')
# 1   ('kristliku', 'kultuuriruumiga')
# 1   ('üleliigne', 'kuhjumine')
# 1   ('käpardlik', 'jõuetus')
# 1   ('järsku', 'tõusu')
# 1   ('punase', 'joone')
# 1   ('külastanud', 'ostjad')
# 1   ('inetule', 'vahejuhtumile')
# 1   ('mustanahaline', 'klient')
# 1   ('asotsiaalsete', 'eluviisidega')
# 1   ('räpase', 'suu')
# 1   ('läbikontrollimata', 'taustaga')
# 1   ('kindlaks', 'seisukohale')
# 1   ('viimase', 'aasta')
# 1   ('tundlikeks', 'piirkondadeks')
# 1   ('elavad', 'immigrandid')
# 1   ('hiljutisi', 'terrorirünnakuid')
# 1   ('juhtiv', 'liige')
# 1   ('julgeolekulisi', 'huvisid')
# 1   ('suurte', 'rahade')
# 1   ('viimaste', 'paadid')
# 1   ('ranget', 'poliitikat')
# 1   ('illegaalselt', 'riigis')
# 1   ('viibiva', 'inimese')
# 1   ('toetavaid', 'seisukohti')
# 1   ('peetud', 'islamiusu')
# 1   ('tohutud', 'vägivallapuhangud')
# 1   ('religioossel', 'pinnal')
# 1   ('terve', 'hulk')
# 1   ('endine', 'riigipea')
# 1   ('kohustuslikku', 'ümberpaigutamist')
# 1   ('immigratsioonivastased', 'vandenõuteoreetikud')
# 1   ('kohalike', 'omavalitsuste')
# 1   ('kubiseva', 'kirja')
# 1   ('elavaid', 'pereliikmeid')
# 1   ('praegune', 'eelnõu')
# 1   ('võõras', 'sisu')
# 1   ('ohtlikule', 'kodumaale')
# 1   ('põgenenud', 'pagulased')
# 1   ('abitud', 'olendid')
# 1   ('mõõdukad', 'islamistid')
# 1   ('huvitav', 'fakt')
# 1   ('sotsialistliku', 'partei')
# 1   ('feministlik', 'valitsus')
# 1   ('toimivast', 'masinavärgist')
# 1   ('normaalse', 'palga')
# 1   ('riiklike', 'kodulaenugarantiide')
# 1   ('noortele', 'peredele')
# 1   ('neljarealiseks', 'ehitamist')
# 1   ('arulagedatest', 'eurodirektiividest')
# 1   ('suveräänset', 'välispoliitikat')
# 1   ('lõdva', 'sisserände')
# 1   ('endise', 'nõukogude')
# 1   ('võimalike', 'valijate')
# 1   ('küüniline', 'pettus')
# 1   ('arvukaid', 'erandeid')
# 1   ('avalikku', 'manipuleerimist')
# 1   ('räige', 'tegelt')
# 1   ('sarnased', 'vägistamisjuhtumid')
# 1   ('kriitilise', 'piiri')
# 1   ('ühine', 'rändepaktiga')
# 1   ('tänane', 'koalitsioon')
# 1   ('vaba', 'riik')
# 1   ('vabaks', 'inimeseks')
# 1   ('teatud', 'mõtlemise')
# 1   ('seksuaalse', 'sättumuse')
# 1   ('islamiusulised', 'sisserändajad')
# 1   ('tulevatesse', 'aafriklastesse')
# 1   ('liigse', 'pehmusega')
# 1   ('määramata', 'ajaks')
# 1   ('üksikuid', 'immigrante')
# 1   ('tulevaid', 'põgenikke')
# 1   ('oleva', 'multikultuurilisuse')
# 1   ('teravad', 'probleemid')
# 1   ('vastuvõtvale', 'ühiskonnale')
# 1   ('langev', 'majanduskoorem')
# 1   ('ärksamad', 'inimesed')
# 1   ('ebaseaduslike', 'migrantidega')
# 1   ('absoluutse', 'enamuse')
# 1   ('rahvusvahelise', 'kriisi')
# 1   ('madal', 'iive')
# 1   ('praeguse', 'seisuga')
# 1   ('prognoositav', 'enamiku')
# 1   ('suuri', 'erimeelsusi')
# 1   ('viimaste', 'poputamine')
# 1   ('sotsiaalne', 'kandepind')
# 1   ('islamiusulisi', 'noori')
# 1   ('vaba', 'aega')
# 1   ('absoluutses', 'miinimumis')
# 1   ('immigratsioonisõbralikumates', 'riikides')
# 1   ('möödunud', 'esmaspäeval')
# 1   ('peetud', 'konverentsil')
# 1   ('järgmisel', 'aastal')
# 1   ('üle-euroopaline', 'partei')
# 1   ('võõraste', 'sissetoomisesse')
# 1   ('otseses', 'mõttes')
# 1   ('lahutavaid', 'asju')
# 1   ('arvukad', 'naispolitseinikud')
# 1   ('valimatule', 'immigratsioonile')
# 1   ('kaasaaitavad', 'kõrgkoolid')
# 1   ('suurima', 'ohuna')
# 1   ('etnilisest', 'eurooplusest')
# 1   ('globaalsest', 'kaubanduskeskusest')
# 1   ('kinnisel', 'territooriumil')
# 1   ('turvalise', 'valve')
# 1   ('eelmisel', 'nädalavahetusel')
# 1   ('parima', 'tulemuse')
# 1   ('immigratsioonivastast', 'kurssi')
# 1   ('vastakaid', 'reaktsioone')
# 1   ('venekeelsed', 'elanikud')
# 1   ('kõnelevad', 'inimesed')
# 1   ('sarnased', 'küsimustes')
# 1   ('erinevast', 'kultuuriruumist')
# 1   ('omal', 'initsiatiivil')
# 1   ('uue', 'immigratsioonikvoodi')
# 1   ('sõlmitud', 'lepingu')
# 1   ('sõlmitud', 'leping')
# 1   ('noori', 'mehi')
# 1   ('uute', 'põgenikelaagrite')
# 1   ('globaalsete', 'probleemide')
# 1   ('rahvuslikud', 'huvid')
# 1   ('suured', 'kogukonnad')
# 1   ('verisemast', 'äärmusorganisatsioonist')
# 1   ('tuhandelised', 'kogukonnad')
# 1   ('suur', 'arv')
# 1   ('täieliku', 'auditi')
# 1   ('toonase', 'eelnõu')
# 1   ('parima', 'maa')
# 1   ('suureks', 'ohuks')
# 1   ('suveräänne', 'õigus')
# 1   ('kaasnev', 'turvatunde')
# 1   ('konkreetseid', 'klausleid')
# 1   ('sisserändevastase', 'retoorikaga')
# 1   ('koduste', 'valijate')
# 1   ('immigratsioonivastane', 'liikumine')
# 1   ('kestvate', 'protestide')
# 1   ('välismaiste', 'juurtega')
# 1   ('võõrastel', 'jalg')
# 1   ('väikesed', 'neegrite')
# 1   ('ainus', 'erakond')
# 1   ('pikas', 'plaanis')
# 1   ('märatsevatel', 'moslemitel')
# 1   ('reeturlikel', 'liidritel')
# 1   ('kirjaoskamatuteks', 'soperdajateks')
# 1   ('heal', 'juhul')
# 1   ('halval', 'juhul')
# 1   ('kirjaoskamatud', 'soperdajad')
# 1   ('otseseid', 'provokatsioone')
# 1   ('massiline', 'vastuvõtmine')
# 1   ('lugematute', 'vägivalla')
# 1   ('uus', 'immigratsioonikanal')
# 1   ('võimukat', 'presidenti')
# 1   ('väliste', 'ohtude')
# 1   ('majandusliku', 'ebakindluse')
# 1   ('valged', 'vasakliberaalid')
# 1   ('toetatavad', 'revolutsioonid')
# 1   ('kohalikku', 'keelt')
# 1   ('toimuv', 'massiimmigratsioon')
# 1   ('potentsiaalse', 'mässutegevuse')
# 1   ('tohutu', 'eelise')
# 1   ('suur', 'tööpuudus')
# 1   ('kohalikud', 'jordaanlased')
# 1   ('hädas', 'süürlased')
# 1   ('kesisema', 'palga')
# 1   ('kõrge', 'moraaliga')
# 1   ('laiapõhjalise', 'riigikaitsega')
# 1   ('suurem', 'oht')
# 1   ('seostatud', 'riideid')
# 1   ('järgnev', 'pilapilt')
# 1   ('ksenofoobsed', 'rünnakud')
# 1   ('islamivastaste', 'liikumiste')
# 1   ('ühine', 'mure')
# 1   ('patriarhaalne', 'ühiskond')
# 1   ('ebatootliku', 'põlluharimise')
# 1   ('alternatiivse', 'toimetus')
# 1   ('vasakäärmuslikest', 'ideedest')
# 1   ('pakatavatel', 'globalistidel')
# 1   ('taoline', 'saastaväljaande')
# 1   ('ametlike', 'piiripunktide')
# 1   ('hääbuvad', 'aafriklaste')
# 1   ('ükskõikne', 'suhtumine')
# 1   ('massilise', 'sissetoomisega')
# 1   ('väärilise', 'palga')
# 1   ('kurdimeelse', 'erakonna')
# 1   ('konkreetne', 'ukrainlane')
# 1   ('uuelt', 'kodumaalt')
# 1   ('eelnenud', 'mõrv')
# 1   ('võõramaise', 'võit')
# 1   ('rahvuskonservatiivse', 'erakonna')
# 1   ('sõlmitud', 'kokkulepet')
# 1   ('poliitilised', 'jõud')
# 1   ('ründava', 'kampaania')
# 1   ('isiklikul', 'tasandil')
# 1   ('praegune', 'olukord')
# 1   ('hukatuslikule', 'reisile')
# 1   ('mustade', 'artistide')
# 1   ('etniliste', 'mõjutustega')
# 1   ('rassistlike', 'vihakõnedena')
# 1   ('hiljutisel', 'poliitikute')
# 1   ('ksenofoobsest', 'maast')
# 1   ('suur', 'oht')
# 1   ('töötavad', 'vietnamlased')
# 1   ('poliitilisest', 'käekirjast')
# 1   ('suure', 'reklaamiga')
# 1   ('selge', 'seisukoht')
# 1   ('illegaalsele', 'sisserändele')
# 1   ('peatuvaid', 'migrante')
# 1   ('padupunane', 'segment')
# 1   ('hullumeelset', 'maksupoliitikat')
# 1   ('võõrviha', 'ilminguid')
# 1   ('valmis', 'abikaasa')
# 1   ('multikultuurne', 'ühiskond')
# 1   ('kohalike', 'maksude')
# 1   ('avalik', 'saladus')
# 1   ('sügavas', 'kriisis')
# 1   ('probleemne', 'linnaosa')
# 1   ('kõrge', 'tööpuudus')
# 1   ('hiljutine', 'uudis')
# 1   ('mustanahaline', 'lesbist')
# 1   ('varasem', 'kogemus')
# 1   ('juhitud', 'valitsusel')
# 1   ('vastuvõetavate', 'pagulaste')
# 1   ('ajutine', 'laager')
# 1   ('tavapärane', 'asi')
# 1   ('tõelised', 'vaenlased')
# 1   ('peamisi', 'teemasid')
# 1   ('mobiliseeriv', 'faktor')
# 1   ('ühese', 'sõnumiga')
# 1   ('poliitilist', 'asüüli')
# 1   ('poliitilised', 'alternatiivid')
# 1   ('valitsevad', 'sotsiaaldemokraadid')
# 1   ('poliitiline', 'jõud')
# 1   ('riiklike', 'institutsioonide')
# 1   ('aktiivsed', 'inimesed')
# 1   ('selget', 'vastujõudu')
# 1   ('globalistliku', 'eliidi')
# 1   ('pikaajalised', 'lõimumisprobleemid')
# 1   ('rasketest', 'kuritegudest')
# 1   ('ametlik', 'statistika')
# 1   ('öise', 'jalutuskäigu')
# 1   ('suurema', 'võimaluse')
# 1   ('liberaalsete', 'kesk-')
# 1   ('siinse', 'majanduse')
# 1   ('illegaalse', 'rändega')
# 1   ('tark', 'sisseränne')
# 1   ('avaldatud', 'tõlge')
# 1   ('rahvusvaheliste', 'organisatsioonide')
# 1   ('venekeelsetes', 'massiteabevahendites')
# 1   ('avaldatud', 'artiklitele')
# 1   ('alandavad', 'ukrainlaste')
# 1   ('negatiivset', 'imagot')
# 1   ('ajutist', 'asüüli')
# 1   ('sündivad', 'lapsed')
# 1   ('kasvavas', 'trendis')
# 1   ('juriidilistele', 'isikutele')
# 1   ('rangemad', 'vanglakaristused')
# 1   ('toimetavatele', 'inimestele')
# 1   ('vaimseteks', 'invaliidideks')
# 1   ('normaalsed', 'inimesed')
# 1   ('ülerahvastatud', 'alused')
# 1   ('ohtlikule', 'teekonnale')
# 1   ('tegelik', 'huvi')
# 1   ('rahvusvahelise', 'tähelepanu')
# 1   ('range', 'valve')
# 1   ('täielik', 'kontroll')
# 1   ('kehva', 'aluspõhjaga')
# 1   ('katvaid', 'naisi')
# 1   ('praegused', 'pagulased')
# 1   ('valgete', 'näitlejate')
# 1   ('erinevad', 'kogukonnad')
# 1   ('olevat', 'tegevuskava')
# 1   ('keskealist', 'meest')
# 1   ('alandava', 'moslemimehe')
# 1   ('otsese', 'terroriaktiga')
# 1   ('tuntuim', 'migrandilinnaosa')
# 1   ('praegustele', 'juhtidele')
# 1   ('migratsioonivaenulikuma', 'juhina')
# 1   ('targem', 'tee')
# 1   ('kasvav', 'number')
# 1   ('üleküllastunud', 'põhjanaabrite')
# 1   ('asuvaid', 'neegreid')
# 1   ('efektiivse', 'naturaliseerimisena')
# 1   ('edukas', 'integratsioon')
# 1   ('kiire', 'vähenemine')
# 1   ('eduka', 'integratsioonina')
# 1   ('seniseid', 'tingimusi')
# 1   ('tulenevate', 'riskide')
# 1   ('mustade', 'grillpeost')
# 1   ('kangelaslikku', 'ajalugu')
# 1   ('veriste', 'repressioonide')
# 1   ('kannatanud', 'ungarlased')
# 1   ('suunduvate', 'immigrantide')
# 1   ('üksmeelsest', 'halvakspanust')
# 1   ('rahvuslike', 'jõudude')
# 1   ('musta', 'rassi')
# 1   ('mõtlevaid', 'kodanikke')
# 1   ('kohaliku', 'rahva')
# 1   ('määratud', 'kohustus')
# 1   ('19-aastane', 'afgaani')
# 1   ('turvalist', 'kodu')
# 1   ('prii', 'elu')
# 1   ('tulevaid', 'neegreid')
# 1   ('feministlik-sotsialistlik', 'valitsus')
# 1   ('ebaseaduslikku', 'sisserändajat')
# 1   ('kogu', 'sõda')
# 1   ('mustanahaliste', 'valitsuste')
# 1   ('vasakliberaalse', 'režiimi')
# 1   ('truu', 'teener')
# 1   ('ideoloogilist', 'raamistikku')
# 1   ('ohtliku', 'tendentsiga')
# 1   ('eelnevate', 'sajandite')
# 1   ('tehtud', 'ülekohtu')
# 1   ('totaalne', 'föderaliseerumine')
# 1   ('ühtse', 'migratsiooni-')
# 1   ('totalitaarse', 'režiimiga')
# 1   ('kergema', 'vastupanu')
# 1   ('lihtsa', 'elu')
# 1   ('suurest', 'rahast')
# 1   ('ajutisele', 'tööjõule')
# 1   ('karmid', 'reeglid')
# 1   ('praegused', 'sündmused')
# 1   ('ajalooline', 'vaen')
# 1   ('tulevaseks', 'ülemuseks')
# 1   ('suure', 'osakaalu')
# 1   ('antud', 'riigi')
# 1   ('kasvava', 'sisserändega')
# 1   ('täis', 'hirmu')
# 1   ('otsest', 'kontakti')
# 1   ('suunatud', 'aktsiooniga')
# 1   ('vastastikune', 'relvastumine')
# 1   ('rassistlikke', 'märkusi')
# 1   ('endine', 'piirivalvur')
# 1   ('suvalised', 'rändajad')
# 1   ('kasvav', 'sisserände-taustaga')
# 1   ('tabava', 'nime')
# 1   ('jubedate', 'suguvendade')
# 1   ('lähtuvas', 'massimmigratsioonis')
# 1   ('teravaima', 'esinemise')
# 1   ('teiseses', 'rändes')
# 1   ('uus', 'eurooplane')
# 1   ('sõjakat', 'islamit')
# 1   ('musta', 'rassismi')
# 1   ('valgete', 'kolonisaatorite')
# 1   ('vaenulike', 'venelaste')
# 1   ('suured', 'probleemid')
# 1   ('raske', 'koorma')
# 1   ('mustale', 'ukse')
# 1   ('ülim', 'ilming')
# 1   ('mustanahaliste', 'väljatõrjumiseks')
# 1   ('agressiivsed', 'sisserändajad')
# 1   ('puudutavaid', 'otsuseid')
# 1   ('õigeks', 'pool')
# 1   ('suurt', 'tähelepanu')
# 1   ('negatiivseid', 'reaktsioone')
# 1   ('taotlevad', 'otsused')
# 1   ('positiivsema', 'hinnangu')
# 1   ('juhtinud', 'tähelepanu')
# 1   ('väikese', 'palga')
# 1   ('keskmise', 'palga')
# 1   ('elavate', 'inimeste')
# 1   ('valdavad', 'pühasõdalased')
# 1   ('asuvas', 'valitsuse')
# 1   ('peetavas', 'põgenikelaagris')
# 1   ('ideoloogilistest', 'käsitlustest')

# %%
adj_noun_list = []
for i, row in data.iterrows():

  if row["stanceConsolidated"] <= 3:
    continue

  prev_pos, prev_word = "-", "-"
  for pos, word in zip(row["morph_analysis"].partofspeech, row["morph_analysis"].words.text):
    pos = pos[0]
    word = word.lower()
    if prev_pos in "ACU" and pos in "S":
      adj_noun_list += [(prev_word, word)]
    prev_pos = pos
    prev_word = word

supportive_pairs = FreqDist(adj_noun_list)

# %%
for pair, count in supportive_pairs.most_common():
  print(f"{count: <3} {pair}")
# Out:
# 3   ('ebaseadusliku', 'rände')
# 3   ('rahvusvahelist', 'kaitset')
# 2   ('rahvusvahelise', 'rändekava')
# 2   ('soolise', 'võrdõiguslikkuse')
# 2   ('avatud', 'algus')
# 2   ('salliva', 'õpikeskkonna')
# 2   ('kogu', 'maailmas')
# 2   ('suure', 'panuse')
# 2   ('globaalses', 'ränderaamistikus')
# 2   ('rassilise', 'diskrimineerimise')
# 2   ('kohalikud', 'inimesed')
# 2   ('ühise', 'tegevuskava')
# 2   ('rahvusvahelise', 'kaitse')
# 2   ('viibivad', 'välismaalased')
# 2   ('rahvusvaheline', 'rändeorganisatsioon')
# 2   ('lühiajalise', 'töötamise')
# 2   ('käesoleva', 'aasta')
# 2   ('sinine', 'äratus')
# 2   ('globaalne', 'ränderaamistik')
# 1   ('seotud', 'lood')
# 1   ('suurimaks', 'ohuks')
# 1   ('avatud', 'ühiskonnale')
# 1   ('avatud', 'näiteks')
# 1   ('migratsioonivastaseid', 'meeleolusid')
# 1   ('rassistlike', 'intsidentide')
# 1   ('viimastel', 'aastatel')
# 1   ('suure', 'hulga')
# 1   ('ksenofoobne', 'propaganda')
# 1   ('suurendavaid', 'välismaalaste')
# 1   ('siinsesse', 'arengusse')
# 1   ('seotud', 'kulud')
# 1   ('diplomeeritud', 'spetsialistina')
# 1   ('laia', 'maailma')
# 1   ('pikemat', 'aega')
# 1   ('erinevate', 'oskuste')
# 1   ('ühiseid', 'väärtusi')
# 1   ('töötutele', 'põllumajanduses')
# 1   ('pisike', 'näidismudel')
# 1   ('erinev', 'nahavärv')
# 1   ('normaalne', 'nähtus')
# 1   ('reaktsioonilisi', 'arusaamu')
# 1   ('pimeda', 'järjekindlusega')
# 1   ('avaramad', 'väljavaated')
# 1   ('võimalikuks', 'motiiviks')
# 1   ('väljapaistvamaid', 'vastaseid')
# 1   ('omaalgatuslikud', 'jõugud')
# 1   ('viibivaid', 'välismaalasi')
# 1   ('kogu', 'ühiskonna')
# 1   ('erinevates', 'ministeeriumides')
# 1   ('viimasel', 'ajal')
# 1   ('adekvaatne', 'põhjus')
# 1   ('inimlikku', 'immigratsioonisüsteemi')
# 1   ('lähtuva', 'rände')
# 1   ('suure', 'lisandväärtusega')
# 1   ('lihtsustatud', 'muudatustega')
# 1   ('kavandatud', 'muudatused')
# 1   ('ainus', 'välismaalane')
# 1   ('õilsa', 'jälje')
# 1   ('puudutavate', 'otsuste')
# 1   ('suuremat', 'avamist')
# 1   ('uuel', 'nädalal')
# 1   ('nõukogudeaegset', 'multifilmi')
# 1   ('kogu', 'mets')
# 1   ('intersooliste', 'inimeste')
# 1   ('teadlikusse', 'tõstmisele')
# 1   ('rändevastastel', 'protestidel')
# 1   ('tõupuhas', 'antisemiit')
# 1   ('tuntud', 'ettevõtjaid')
# 1   ('edukaid', 'inimesi')
# 1   ('kvalifitseeritud', 'töökäsi')
# 1   ('eelmise', 'öö')
# 1   ('rassistlikud', 'meeleavaldused')
# 1   ('uut', 'jaotuskava')
# 1   ('tõstatatud', 'tagasirändeagentuuri')
# 1   ('uue', 'valitsuse')
# 1   ('oluline', 'märksõna')
# 1   ('muutuvate', 'seaduste')
# 1   ('ruudulise', 'särgikaeluse')
# 1   ('viimase', 'aja')
# 1   ('põgenenud', 'rohingja')
# 1   ('saabunud', 'pagulaspered')
# 1   ('väiksemate', 'linnade')
# 1   ('kritiseerivatel', 'erakondadel')
# 1   ('ühine', 'asi')
# 1   ('varases', 'faasis')
# 1   ('vajalike', 'hooajatöötajate')
# 1   ('rahvusvahelistes', 'vetes')
# 1   ('geograafilise', 'asukoha')
# 1   ('rassistlikud', 'seisukohad')
# 1   ('rassistlikud', 'ideed')
# 1   ('tuntud', 'tõusuteel')
# 1   ('oleva', 'ideoloogia')
# 1   ('puhtama', 'rassi')
# 1   ('ehtsad', 'rassistid')
# 1   ('püstitatud', 'parteitelkide')
# 1   ('omapoolse', 'kinnituse')
# 1   ('allkirjastatud', 'korraldus')
# 1   ('keelualused', 'isikud')
# 1   ('enim', 'põgenikke')
# 1   ('rassistlik', 'solvang')
# 1   ('täie', 'põhjalikkusega')
# 1   ('täie', 'rangusega')
# 1   ('kogu', 'põllumajandussektor')
# 1   ('läbiviidud', 'uuring')
# 1   ('suuremates', 'piimakarjades')
# 1   ('eestikeelse', 'õppe')
# 1   ('kiiremat', 'tegutsemist')
# 1   ('alaealiste', 'põgenike')
# 1   ('normaalsete', 'elutingimuste')
# 1   ('seonduvad', 'hirmud')
# 1   ('eduka', 'integratsiooni')
# 1   ('täidesaatva', 'korraldusega')
# 1   ('ebaseaduslikku', 'sisserännet')
# 1   ('kohalikud', 'külaelanikud')
# 1   ('nõukogudeaegset', 'korterit')
# 1   ('traagiline', 'saatus')
# 1   ('arukat', 'debatti')
# 1   ('eestikeelse', 'kõrghariduse')
# 1   ('asustatud', 'pagulast')
# 1   ('negatiivne', 'meelestatus')
# 1   ('värske', 'uuringu')
# 1   ('ilmuvas', 'augustinumbris')
# 1   ('ühise', 'laua')
# 1   ('ühisele', 'kokkuleppele')
# 1   ('vajalikud', 'juuni')
# 1   ('arvuliste', 'eesmärkide')
# 1   ('kõrgem', 'eesmärk')
# 1   ('saabunud', 'varjupaigataotlejad')
# 1   ('paiknevatele', 'süürlastele')
# 1   ('algne', 'mõte')
# 1   ('mustanahaliste', 'elu')
# 1   ('heal', 'juhul')
# 1   ('positiivseid', 'kombeid')
# 1   ('lihtsustatud', 'elamisluba')
# 1   ('loodud', 'ettevõtte')
# 1   ('ksenofoobset', 'motiivi')
# 1   ('raskendava', 'asjaoluna')
# 1   ('suuri', 'jamasid')
# 1   ('reisivaid', 'noori')
# 1   ('eri', 'rassidest')
# 1   ('maailmavaatelise', 'taustaga')
# 1   ('lihtsustatud', 'korras')
# 1   ('tegelevad', 'välismaalased')
# 1   ('lojaalse', 'kodanikkonna')
# 1   ('kehtivate', 'elamislubade')
# 1   ('euroopaliku', 'eluviisi')
# 1   ('euroopalik', 'eluviis')
# 1   ('kvaliteetset', 'meediaväljaannete')
# 1   ('internetipõhist', 'teavet')
# 1   ('seotud', 'küsimustes')
# 1   ('eetilistesse', 'teavitamisstandarditesse')
# 1   ('olulise', 'toetuse')
# 1   ('suunatud', 'sallimatust')
# 1   ('sätestatud', 'eesmärke')
# 1   ('seaduslikku', 'rännet')
# 1   ('kogunenud', 'laagritesse')
# 1   ('suurima', 'piirikriisi')
# 1   ('negatiivne', 'mõju')
# 1   ('ranget', 'lugupidamist')
# 1   ('rahvusvahelise', 'mereõiguse')
# 1   ('pärinevas', 'kirjas')
# 1   ('eelmise', 'aasta')
# 1   ('toimuval', 'üritusel')
# 1   ('näidatavate', 'filmide')
# 1   ('inimliku', 'poole')
# 1   ('aktsepteeritavad', 'rassismi')
# 1   ('laiemale', 'maailmaharidusele')
# 1   ('infotehnoloogiline', 'areng')
# 1   ('massilise', 'tööjõu')
# 1   ('saabunud', 'sihtriiki')
# 1   ('tehtavad', 'toimingud')
# 1   ('adekvaatset', 'infot')
# 1   ('uued', 'sillad')
# 1   ('vasakpoolsed', 'meelt')
# 1   ('kinnitamata', 'andmetel')
# 1   ('vajalikke', 'ettevalmistusi')
# 1   ('ebaseaduslike', 'piiriületuste')
# 1   ('massiivne', 'ümberasustamisprogramm')
# 1   ('uue', 'strateegia')
# 1   ('tõhusamale', 'abi')
# 1   ('täies', 'mahus')
# 1   ('kõikehõlmavaid', 'protsesse')
# 1   ('ulatuslikke', 'reparatsioonimeetmeid')
# 1   ('päevasel', 'ajal')
# 1   ('tavalised', 'linnaosad')
# 1   ('riiklike', 'huvide')
# 1   ('riiklike', 'huvidega')
# 1   ('kohalike', 'raevu')
# 1   ('saabuvatele', 'varjupaigataotlejatele')
# 1   ('kindlad', 'kriteeriumid')
# 1   ('tagakiusatud', 'moslemitega')
# 1   ('sallivamalt', 'moslemitesse')
# 1   ('avaldatud', 'küsitluste')
# 1   ('viimaseks', 'tähtajaks')
# 1   ('vastasel', 'korral')
# 1   ('antud', 'võimu')
# 1   ('vastuvaidlematu', 'tõena')
# 1   ('saadetava', 'raha')
# 1   ('suurima', 'osa')
# 1   ('paremäärmuslikelt', 'jõududelt')
# 1   ('seotud', 'maksud')
# 1   ('põhinevat', 'ebavõrdsust')
# 1   ('uute', 'sõnadega')
# 1   ('esitatud', 'versioonis')
# 1   ('rassismivastaseid', 'seisukohti')
# 1   ('jätkusuutlikke', 'lahendusi')
# 1   ('praegustele', 'rände-')
# 1   ('seotud', 'päritolu-,')
# 1   ('ainsatki', 'pagulast')
# 1   ('kokkulepitud', 'menetlusele')
# 1   ('valmis', 'tööle')
# 1   ('erialase', 'ettevalmistuseta')
# 1   ('seitsmest', 'elamisloa')
# 1   ('vastav', 'haridus')
# 1   ('saabuvatele', 'põgenikele')
# 1   ('huvitav', 'lugemine')
# 1   ('suuremaks', 'katsumuseks')
# 1   ('isolatsionalistlik', 'poliitika')
# 1   ('tõesem', 'vabariiklaste')
# 1   ('roheliste', 'kaartide')
# 1   ('isolatsionistliku', 'poliitika')
# 1   ('illegaalset', 'sisserändajat')
# 1   ('tegeleva', 'grupi')
# 1   ('hea', 'võimaluse')
# 1   ('praeguse', 'seisuga')
# 1   ('pagevate', 'majandusmigrantide')
# 1   ('erialasel', 'ametikohale')
# 1   ('kiire', 'internet')
# 1   ('algaval', 'nädalal')
# 1   ('esitatud', 'välismaalaste')
# 1   ('esitatud', 'massiimmigratsiooni')
# 1   ('peamine', 'teema')
# 1   ('punane', 'rist')
# 1   ('uuele', 'kodumaale')
# 1   ('diplomaatilist', 'survet')
# 1   ('süstemaatilise', 'tagasisaatmisega')
# 1   ('paremat', 'elu')
# 1   ('rahvusvahelisele', 'õigusele')
# 1   ('uut', 'käitumisjuhist')
# 1   ('vähestel', 'aafriklastel')
# 1   ('antav', 'elamisluba')
# 1   ('naljaka', 'ettepanekuga')
# 1   ('kehtivaid', 'regulatsioone')
# 1   ('vananenud', 'rahvuslust')
# 1   ('uus', 'uudis')
# 1   ('rassilise', 'õigluse')
# 1   ('puhkenud', 'protestid')
# 1   ('esmatarvilik', 'pagulaslaagrites')
# 1   ('multikultuursesse', 'asumisse')
# 1   ('uueks', 'migratsiooniministriks')
# 1   ('püüdvate', 'põgenike')
# 1   ('meeletu', 'kontroll')
# 1   ('suurem', 'osa')
# 1   ('kindla', 'sooviga')
# 1   ('vajalik', 'keeletase')
# 1   ('järgmistel', 'juhtudel')
# 1   ('lubatud', 'aega')
# 1   ('parema', 'õpikeskkonna')
# 1   ('tugevatele', 'välisüliõpilastele')
# 1   ('erialast', 'tööd')
# 1   ('eelmisel', 'aastal')
# 1   ('peetavaid', 'pagulasi')
# 1   ('valitsusvälised', 'abiorganisatsioonid')
# 1   ('illegaalse', 'migrandi')
# 1   ('suur', 'kriis')
# 1   ('rabavate', 'võõrtöölisteta')
# 1   ('piirkondlikke', 'omavalitsusi')
# 1   ('mõõkhambuline', 'hord')
# 1   ('kannatanud', 'inimesi')
# 1   ('kehtiva', 'seaduse')
# 1   ('elaval', 'välismaalasel')
# 1   ('õnnetud', 'inimesed')
# 1   ('kalli', 'raha')
# 1   ('kurjad', 'kavatsused')
# 1   ('eri', 'nurkades')
# 1   ('eesseisvaid', 'väljakutseid')
# 1   ('vajavaid', 'inimesi')
# 1   ('rekordilise', 'numbri')
# 1   ('kasvava', 'ohu')
# 1   ('avatud', 'uste')
# 1   ('soovivate', 'riikide')
# 1   ('läbimõeldud', 'samm')
# 1   ('suures', 'pildis')
# 1   ('keskmist', 'palka')
# 1   ('kõrge', 'palganõue')
# 1   ('siinsel', 'ettevõtjal')
# 1   ('välismaisele', 'orjatööjõule')
# 1   ('mitteolenevatel', 'põhjustel')
# 1   ('sotsiaalse', 'seisundi')
# 1   ('piirkondlike', 'omavalitsuste')
# 1   ('tõhusamaks', 'koostööks')
# 1   ('uppuvast', 'kummipaadist')
# 1   ('pikema', 'jututa')
# 1   ('lihtsamaid', 'viise')
# 1   ('ohtrat', 'sotsiaalabi')
# 1   ('viimase', 'aasta')
# 1   ('massiline', 'immigratsioon')
# 1   ('uued', 'asüülitaotlused')
# 1   ('rindelähedased', 'asulad')
# 1   ('rasketes', 'oludes')
# 1   ('eakatele', 'inimestele')
# 1   ('noppimata', 'osa')
# 1   ('hilisemat', 'maasika')
# 1   ('kättesaadavat', 'andmestikku')
# 1   ('ainus', 'riik')
# 1   ('alalise', 'asüüli')
# 1   ('piirkondlikule', 'sotsiaal-')
# 1   ('kohalikku', 'ellu')
# 1   ('legaalsete', 'immigrantide')
# 1   ('populaarsed', 'välismaalaste')
# 1   ('miljardist', 'eurost')
# 1   ('vastavate', 'teenuste')
# 1   ('seaduslike', 'rändeteede')
# 1   ('põgenevate', 'inimeste')
# 1   ('suure', 'surve')
# 1   ('feministlik', 'valitsus')
# 1   ('tsentristlik', 'valitsus')
# 1   ('omal', 'initsiatiivil')
# 1   ('hõlmava', 'lahenduseni')
# 1   ('olemasolevad', 'kokkulepped')
# 1   ('poliitilise', 'otsuse')
# 1   ('kohustusliku', 'karantiinireeglita')
# 1   ('järgmistel', 'kuudel')
# 1   ('konfliktiäärsetele', 'elanikele')
# 1   ('kohaliku', 'politseiga')
# 1   ('ksenofoobsete', 'valimistulemuste')
# 1   ('avatud', 'ühiskonna')
# 1   ('positiivset', 'efekti')
# 1   ('negatiivset', 'efekti')
# 1   ('majanduslikud', 'argumendid')
# 1   ('asjatundlike', 'hooajatööliste')
# 1   ('turvalist', 'koju')
# 1   ('roheliste', 'esindaja')
# 1   ('seisvatesse', 'hotellidesse')
# 1   ('terve', 'hulk')
# 1   ('seisvaid', 'hotelle')
# 1   ('globalistliku', 'ideoloogia')
# 1   ('töötlevale', 'tööstusele')
# 1   ('mitmekilomeetrine', 'supisaba')
# 1   ('pretensioonitu', 'kokkupuude')
# 1   ('õppiv', 'välistudeng')
# 1   ('armsa', 'maarjamaa')
# 1   ('suurt', 'kriisi')
# 1   ('olulisim', 'väärtus')
# 1   ('võrdsed', 'võimalused')
# 1   ('seksuaalsest', 'sättumusest')
# 1   ('osaliseks', 'taastumiseks')
# 1   ('lubatud', 'pendelränne')
# 1   ('paraja', 'kaose')
# 1   ('esmane', 'korralduskeskus')
# 1   ('sõbralikele', 'inimestele')
# 1   ('kasutajasõbralikele', 'e-teenustele')
# 1   ('vabatahtlikku', 'naasmist')
# 1   ('tõsist', 'muret')
# 1   ('vajavat', 'pagulast')
# 1   ('noorte', 'immigrantide')
# 1   ('globaalset', 'valitsemist')
# 1   ('nimetatud', 'riikides')
# 1   ('seotud', 'tööjõu')
# 1   ('piisava', 'tööjõuvaru')
# 1   ('suur', 'arutelu')
# 1   ('ajutise', 'elamisloaga')
# 1   ('täpsed', 'üksikasjad')
# 1   ('ainus', 'viis')
# 1   ('sealse', 'siseministri')
# 1   ('seaduslikel', 'alustel')
# 1   ('pädevate', 'ametiasutuste')
# 1   ('tegelev', 'tööandja')
# 1   ('neljaliikmelise', 'piiriametnike')
# 1   ('suuremaks', 'probleemiks')
# 1   ('senise', 'valitsuse')
# 1   ('lubatud', 'töötamise')
# 1   ('liigkõrgete', 'palgakriteeriumide')
# 1   ('lõunapoolsetele', 'kaaslastele')
# 1   ('suurte', 'põgenikevoogudega')
# 1   ('liberaalne', 'partei')
# 1   ('täispalgalisi', 'töötajaid')
# 1   ('lõppenud', 'siseministrite')
# 1   ('erakorralisel', 'kohtumisel')
# 1   ('operatiivse', 'koostöö')
# 1   ('väiksemate', 'tööjõukulude')
# 1   ('sotsiaalsete', 'kulude')
# 1   ('odav', 'ühiselamu')
# 1   ('kohalikud', 'elanikud')
# 1   ('oluliseks', 'rändesurve')
# 1   ('olevate', 'liikmesriikide')
# 1   ('toimiv', 'välispoliitika')
# 1   ('asuvate', 'põgenikelaagrite')
# 1   ('konkreetsetest', 'tegevustest')
# 1   ('levivat', 'teadmatust')
# 1   ('ostetud', 'maski')
# 1   ('riiklikule', 'tööjõuagentuurile')
# 1   ('uutel', 'tulijatel')
# 1   ('käimasoleva', 'vooru')
# 1   ('mustanahaliste', 'õiguste')
# 1   ('võitlevale', 'liikumisele')
# 1   ('sobiv', 'integratsioonipoliitika')
# 1   ('rassismivastased', 'strateegiad')
# 1   ('poliitiline', 'osalemine')
# 1   ('avalikku', 'esindatust')
# 1   ('head', 'eeskuju')
# 1   ('avaliku', 'elu')
# 1   ('koostatud', 'majadusnäitajate')
# 1   ('olulisemad', 'majandusnäitajad')
# 1   ('positiivses', 'korrelatsioonis')
# 1   ('praegune', 'valitsus')
# 1   ('oodatud', 'välisüliõpilased')
# 1   ('vaba', 'ränne')
# 1   ('väärikaks', 'töörändeks')
# 1   ('liidusiseste', 'riigipiiride')
# 1   ('religioosset', 'vihavaenu')
# 1   ('praegust', 'põgenikevoolu')
# 1   ('praeguseks', 'paika')
# 1   ('nüüdseks', 'koju')
# 1   ('viibivasse', 'välismaalasesse')
# 1   ('erinevad', 'kultuurid')
# 1   ('illegaalseid', 'piirületusi')
# 1   ('kinnised', 'migrantsioonikeskused')
# 1   ('hiiglaslikule', 'rändekriisile')
# 1   ('alaseid', 'probleeme')
# 1   ('esinevate', 'eristamiste')
# 1   ('elavate', 'inimeste')
# 1   ('saabuvate', 'kvoodipagulaste')
# 1   ('fundamentaalset', 'põhimõtet')
# 1   ('suveräänne', 'õigus')
# 1   ('rahvusvahelise', 'õigusega')
# 1   ('lihtsam', 'kodumaale')
# 1   ('globaalse', 'ränderaamistiku')
# 1   ('loomulik', 'iive')
# 1   ('kasvav', 'sisseränne')
# 1   ('tagasilükatud', 'asüülitaotlustega')
# 1   ('efektiivsemaks', 'päritoluriiki')
# 1   ('üleilmse', 'rändeprobleemi')
# 1   ('laiahaardeliseks', 'rände')
# 1   ('haritud', 'välismaalased')
# 1   ('kogu', 'majandust')
# 1   ('aktuaalne', 'kaamera')
# 1   ('sobiva', 'üürikorteri')
# 1   ('uute', 'laagrite')
# 1   ('saabuvatest', 'põgenikest')
# 1   ('kehtiv', 'viisa')
# 1   ('suureks', 'abiks')
# 1   ('möödunud', 'nädalal')
# 1   ('saabuvate', 'põgenike')
# 1   ('võrdsemaks', 'jagamiseks')
# 1   ('uus', 'elu')
# 1   ('kohalik', 'abiline')
# 1   ('kohalikke', 'kontakte')
# 1   ('piiratud', 'määral')
# 1   ('vähesel', 'määral')
# 1   ('seotud', 'probleemidega')
# 1   ('piiramatu', 'ränne')
# 1   ('piiratud', 'arvu')
# 1   ('positiivset', 'otsust')
# 1   ('tähtajalise', 'elamisloa')
# 1   ('vananeva', 'elanikkonnaga')
# 1   ('praeguse', 'põgenikekriisi')
# 1   ('kiireid', 'samme')
# 1   ('üleeestilisele', 'tähelepanule')
# 1   ('suurema', 'mänguväljaku')
# 1   ('kohalike', 'elanike')
# 1   ('ebaseaduslikud', 'sisserändajad')
# 1   ('suurusest', 'paketist')
# 1   ('uusi', 'kulusid')
# 1   ('juhitavas', 'mässutõrjeoperatsioonis')
# 1   ('ebaseadusliku', 'immigratsiooni')
# 1   ('tulev', 'põgenikevool')
# 1   ('haritud', 'välismaalasi')
# 1   ('püsiva', 'elukoha')
# 1   ('vajavad', 'inimesed')
# 1   ('jõudvatele', 'inimestele')
# 1   ('individuaalsed', 'elamispinnad')
# 1   ('kasvava', 'tähtsusega')
# 1   ('möödunud', 'detsembri')
# 1   ('saabunud', 'põgenikepere')
# 1   ('kasvav', 'majandus')
# 1   ('uusi', 'firmasid')
# 1   ('legaalsel', 'teel')
# 1   ('erinevaid', 'sihtrühmi')
# 1   ('rahumeelse', 'kogunemise')
# 1   ('ingliskeelsed', 'õppekavad')
# 1   ('eri', 'paikadest')
# 1   ('omavaheline', 'suhtlus')
# 1   ('suuremale', 'osale')
# 1   ('töötavatest', 'dokumentideta')
# 1   ('pakutud', 'keele-')
# 1   ('elavatele', 'välismaalastele')
# 1   ('rassistliku', 'rünnaku')
# 1   ('kindlad', 'tegevusstrateegiad')
# 1   ('üksikutes', 'koolides')
# 1   ('suurematesse', 'keskustesse')
# 1   ('rahvusvahelistesse', 'koolidesse')
# 1   ('igapäevasest', 'õppeprotsessist')
# 1   ('mitmekesises', 'õpikeskkonnas')
# 1   ('tänast', 'immigratsioonilainet')
# 1   ('senist', 'asüülipoliiitikat')
# 1   ('uusi', 'pagulasmasse')
# 1   ('septembrikuises', 'intervjuus')
# 1   ('saabuvatele', 'asüülitaotlejatele')
# 1   ('suur', 'toetaja')
# 1   ('tuleva', 'aasta')
# 1   ('võimalike', 'elukohtadena')
# 1   ('vajalikud', 'teenused')
# 1   ('arenenud', 'maailmas')
# 1   ('kohalike', 'omavalitsuste')
# 1   ('seadusliku', 'rände')
# 1   ('globaalse', 'tööturu')
# 1   ('kaasavat', 'integratsioonipoliitikat')
# 1   ('helgesse', 'tulevikku')
# 1   ('vabatahtliku', 'mehhanismiga')
# 1   ('avaldatud', 'intervjuus')
# 1   ('puudutav', 'leping')
# 1   ('tõsistele', 'jõupingutustele')
# 1   ('usuline', 'mitmekesisus')
# 1   ('salliv', 'õpikeskkond')
# 1   ('multikultuurse', 'ühiskonna')
# 1   ('massilist', 'sissevedu')
# 1   ('rassistlikku', 'sisu')
# 1   ('ulatusliku', 'sisserände')
# 1   ('olulisemaks', 'faktoriks')
# 1   ('illegaalse', 'migratsiooni')
# 1   ('illegaalse', 'rände')
# 1   ('suure', 'osa')
# 1   ('rahvusvahelist', 'õpikeskkonda')
# 1   ('erilist', 'tähelepanu')
# 1   ('järgmised', 'punktid')
# 1   ('mittediskrimineerivat', 'juurdepääsu')
# 1   ('olemasolevate', 'seaduste')
# 1   ('puhtaid', 'asju')
# 1   ('järgmisel', 'nädala')
# 1   ('eelnevat', 'arvesse')
# 1   ('massiline', 'tung')
# 1   ('uus', 'president')
# 1   ('karmid', 'piirangud')
# 1   ('olulised', 'teemad')
# 1   ('etnilise', 'kuuluvuse')
# 1   ('seksuaalse', 'sättumuse')
# 1   ('puudutavad', 'küsimused')
# 1   ('teisejärgulise', 'staatusega')
# 1   ('kiire', 'keeleõpe')
# 1   ('sobiv', 'töökoht')
# 1   ('võimalik', 'koju')

# %%
neg_lemma = []
pos_lemma = []
neu_lemma = []

for (first, second), count in against_pairs.most_common():
  if "immigra" in second or "rän" in second:
    print(first, end=", ")
    text = Text(first).tag_layer()
    lemma = text.morph_analysis.lemma[0][0]
    neg_lemma += [lemma]

print()
print()

for (first, second), count in supportive_pairs.most_common():
  if "immigra" in second or 'rän' in second:
    print(first, end=", ")
    text = Text(first).tag_layer()
    lemma = text.morph_analysis.lemma[0][0]
    print(lemma, end=", ")
    pos_lemma += [lemma]

print()
print()

for (first, second), count in neutral_pairs.most_common():
  if "immigra" in second or 'rän' in second:
    print(first, end=", ")
    text = Text(first).tag_layer()
    lemma = text.morph_analysis.lemma[0][0]
    print(lemma, end=", ")
    neu_lemma += [lemma]
# Out:
# illegaalsete, massilise, illegaalse, illegaalseid, massiline, massiline, range, võõraste, paarituhandelise, kontrollimatu, isikliku, illegaalsed, kasvav, seotud, globaalse, ebaseadusliku, negatiivne, kuritahtliku, globaalses, järgmine, tulevate, ähvardav, illegaalne, konservatiivset, rahvusvahelise, suur, lähtuvast, tormavaid, jätkuv, kontrollimatu, kogu, salakavalat, ohtliku, riiklik, illegaalsele, efektiivsest, tülikad, massilist, rekordkõrge, kriminaalsed, illegaalsed, karmiks, illegaalset, allaheitliku, võimaliku, illegaalse, uue, avantüristlik, senisele, illegaalsest, uusi, illegaalset, uus, tänast, sealsed, arvukad, võõraste, sarnane, üleeuroopalise, piiramatu, eiravad, tuntud, kõrge, tugevnev, uusi, lõtva, rahvusvahelise, massilise, kontrollimatu, peamisest, legaalsed, käivat, kahjulikku, potentsiaalseks, illegaalse, jahtivad, ohtlikke, ebaseaduslike, elavad, lõdva, ühine, islamiusulised, üksikuid, valimatule, uue, uus, toimuv, illegaalsele, illegaalse, tark, suunduvate, ebaseaduslikku, kasvava, suvalised, kasvav, lähtuvas, teiseses, agressiivsed,
#
# ebaseadusliku, ebaseaduslik, rahvusvahelise, rahvusvaheline, globaalses, globaalne, rahvusvaheline, rahvusvaheline, globaalne, globaalne, inimlikku, inimlik, lähtuva, lähtuv, tõstatatud, tõstatatud, ebaseaduslikku, ebaseaduslik, seaduslikku, seaduslik, praegustele, praegune, illegaalset, illegaalne, esitatud, esitatud, massiline, massiline, legaalsete, legaalne, seaduslike, seaduslik, lubatud, lubatud, noorte, noor, oluliseks, oluline, vaba, vaba, väärikaks, väärikas, hiiglaslikule, hiiglaslik, globaalse, globaalne, kasvav, kasvav, üleilmse, üleilmne, laiahaardeliseks, laiahaardeline, piiramatu, piiramatu, ebaseaduslikud, ebaseaduslik, ebaseadusliku, ebaseaduslik, tänast, tänane, seadusliku, seaduslik, ulatusliku, ulatuslik, illegaalse, illegaalne,
#
# ebaseadusliku, ebaseaduslik, illegaalse, illegaalne, ebaseadusliku, ebaseaduslik, illegaalsele, illegaalne, võimaliku, võimalik, illegaalsed, illegaalne, illegaalseid, illegaalne, illegaalsete, illegaalne, ebaseaduslikke, ebaseaduslik, illegaalsetele, illegaalne, illegaalset, illegaalne, ebaseaduslik, ebaseaduslik, ühtset, ühtne, illegaalsete, illegaalne, illegaalset, illegaalne, tavalisest, tavaline, kõrgema, kõrgem, suure, suur, positiivne, positiivne, negatiivse, negatiivne, 14-17-aastastele, 14, karmi, karm, suurema, suurem, illegaalse, illegaalne, peamised, peamine, ebaseadusliku, ebaseaduslik, suletud, suletud, uus, uus, ebaseaduslike, ebaseaduslik, suuremahulise, suuremahuline, saabunud, saabunud, küündiva, küündiv, jääva, jääv, mitteametlikeks, mitteametlik, sõlmitud, sõlmitud, võtva, võttev, tulevate, tulev, illegaalse, illegaalne, ebaseaduslik, ebaseaduslik, eiravat, eirav, napi, napp, suurem, suurem, illegaalse, illegaalne, kolmapäevasele, kolmapäevane, saabunud, saabunud, illegaalsele, illegaalne, praeguse, praegune, ametliku, ametlik, rahvusvaheline, rahvusvaheline, pretsedenditu, pretsedenditu, kontrollimatud, kontrollimatu, karme, karm, haritute, haritud, positiivse, positiivne, plaanitav, plaanitav, lõputu, lõputu, alanud, alanud, hoogsam, hoogsam, parempoolsed, parempoolne, tänane, tänane, uue, uus, mitteseaduslike, mitteseaduslik, tulevatele, tulev, ebaseaduslikku, ebaseaduslik, ebaseaduslikku, ebaseaduslik, tormavatele, tormav, globaalse, globaalne, saabuva, saabuv, suunatud, suunatud, globaalse, globaalne, ebaseaduslike, ebaseaduslik, ebaseaduslikud, ebaseaduslik, globaalne, globaalne, ebaseadusliku, ebaseaduslik, nüüdseks, nüüdne, illegaalsele, illegaalne, globaalne, globaalne, võõraid, võõras, teatavate, teatav, okupatsiooniaegse, okupatsiooniaegne, suur, suur, uue, uus, iseseisvat, iseseisev, ebaseaduslikku, ebaseaduslik, ebaseaduslikku, ebaseaduslik, föderaalsele, föderaalne, ebaseaduslikku, ebaseaduslik, tihedaim, tihedaim, ringijooksvat, ringijooksva, võimaliku, võimalik, suurt, suur, eduka, edukas, illegaalse, illegaalne, illegaalsed, illegaalne, ulatuslikku, ulatuslik, kontrollimatut, kontrollimatu, saavatest, saav, massilisest, massiline, lõhestavast, lõhestav, ebaseaduslikul, ebaseaduslik, legaalseks, legaalne, töötud, töötu, arvukad, arvukas, saabuvate, saabuv, tugineva, tuginev,

# %%
# remove duplicates and ambiguous adjectives
neg_lemma = set(neg_lemma) - set(neu_lemma)
pos_lemma = set(pos_lemma) - set(neu_lemma)

# %%
intersection = neg_lemma.intersection(pos_lemma)
print(intersection)
# Out:
# {'lähtuv', 'kasvav', 'piiramatu'}

# %%
# remove adjectives that were both in negative and positive
neg_lemma -= intersection
pos_lemma -= intersection

# %%
negs = sorted(list(set(neg_lemma)))
for neg in negs:
  print(neg, end=", ")
# Out:
# agressiivne, allaheitlik, avantüristlik, efektiivne, elama, isiklik, islamiusuline, jahtiv, järgmine, jätkuv, kahjulik, kogu, konservatiivne, kriminaalne, kuritahtlik, käiv, kõrge, lõtv, ohtlik, paarituhandeline, potentsiaalne, range, rekordkõrge, riiklik, salakaval, sarnane, sealne, senine, seotud, suunduv, suvaline, tark, teisene, toimuv, tugevnev, tuntud, tülikas, valimatu, ähvardav, ühine, üksik, üleeuroopaline,

# %%
poss = sorted(list(set(pos_lemma)))
for pos in poss:
  print(pos, end=", ")
# Out:
# esitatud, hiiglaslik, inimlik, laiahaardeline, lubatud, noor, oluline, seaduslik, tõstatatud, vaba, väärikas, üleilmne,

# %%
def framing_bias(morph_layer, wordlist=[]):
  lemmas = list(morph_layer.lemma)
  lemma_list = [lemma[0].lower() for lemma in lemmas if lemma[0] not in stopword_list and len(lemma[0]) >= 2]
  lemma_string = " ".join(lemma_list)

  if "immigra" in lemma_string or "rän" in lemma_string:
    for word in wordlist:
      if word in lemma_string:
        return 1

  return 0

# %%
data["framing_against"] = data["morph_analysis"].apply(framing_bias, wordlist=negs)
data["framing_support"] = data["morph_analysis"].apply(framing_bias, wordlist=poss)

# %%
data[data["framing_against"] == 1]["stance"].value_counts()
# Out:
# stance
# against       144
# neutral        92
# supportive     31
# Name: count, dtype: int64

# %%
data[data["framing_support"] == 1]["stance"].value_counts()
# Out:
# stance
# neutral       60
# against       43
# supportive    33
# Name: count, dtype: int64

# %%
# download file (google drive)
from google.colab import drive
from google.colab import files

drive.mount("/content/drive")
data.to_csv("/content/drive/MyDrive/EstonianStanceDetection/notebooks/data.csv", index=False)
# files.download("data.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# local
data.to_csv("data.csv", index=False)
